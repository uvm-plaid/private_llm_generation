# %%
# import json
# import pandas as pd
# import matplotlib.pyplot as plt
# from gliner import GLiNER

# # Load the GLiNER PII model
# model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# # Function to detect PII
# def detect_pii(text, labels):
#     entities = model.predict_entities(text, labels)
#     return entities

# # Define the PII labels
# pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
#               "credit card number", "social security number", "health insurance id number", 
#               "date of birth", "mobile phone number", "bank account number", "medication", 
#               "cpf", "driver's license number", "tax identification number", "medical condition", 
#               "identity card number", "national id number", "ip address", "email address", "iban", 
#               "credit card expiration date", "username", "health insurance number", "registration number", 
#               "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
#               "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
#               "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
#               "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
#               "transaction number", "national health insurance number", "cvc", "birth certificate number", 
#               "train ticket number", "passport expiration date", "social_security_number"]

# # Function to load data from JSON file
# def load_data(filename):
#     with open(filename, 'r') as file:
#         data = json.load(file)
#     return data

# # Load data
# dpsgd_data = load_data('/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json')
# ours_data = load_data('/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json')

# # Extract instructions and outputs
# instructions = [item['instruction'] for item in dpsgd_data]
# dpsgd_outputs = [item['output'] for item in dpsgd_data]
# ours_outputs = [item['output'] for item in ours_data]

# # Detect PII in instructions and outputs
# pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
# pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
# pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

# # Function to count PII entities
# def count_pii_entities(entities):
#     return len(entities)

# # Count PII in instructions and outputs
# pii_counts_instructions = [count_pii_entities(entities) for entities in pii_instructions]
# pii_counts_dpsgd_outputs = [count_pii_entities(entities) for entities in pii_dpsgd_outputs]
# pii_counts_ours_outputs = [count_pii_entities(entities) for entities in pii_ours_outputs]

# # Analyze PII additions and drops
# pii_added_dpsgd = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_dpsgd_outputs)]
# pii_added_ours = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_ours_outputs)]

# # Prepare data for plotting
# freq_data = {
#     "Method": ["DPSGD", "Your Method"],
#     "PII Added": [sum(pii_added_dpsgd), sum(pii_added_ours)],
#     "PII Dropped": [-sum(pii_added_dpsgd), -sum(pii_added_ours)]  # Negative to represent drops
# }
# df = pd.DataFrame(freq_data)

# # Plot
# df.plot(x="Method", kind="bar", stacked=True, title="PII Additions and Drops")
# plt.show()

# %%
# import json
# import pandas as pd
# import matplotlib.pyplot as plt
# from gliner import GLiNER

# # Load the GLiNER PII model
# model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# # Function to detect PII
# def detect_pii(text, labels):
#     entities = model.predict_entities(text, labels)
#     return entities

# # Define the PII labels
# pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
#               "credit card number", "social security number", "health insurance id number", 
#               "date of birth", "mobile phone number", "bank account number", "medication", 
#               "cpf", "driver's license number", "tax identification number", "medical condition", 
#               "identity card number", "national id number", "ip address", "email address", "iban", 
#               "credit card expiration date", "username", "health insurance number", "registration number", 
#               "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
#               "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
#               "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
#               "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
#               "transaction number", "national health insurance number", "cvc", "birth certificate number", 
#               "train ticket number", "passport expiration date", "social_security_number"]

# # Function to load data from JSON file
# def load_data(filename):
#     with open(filename, 'r') as file:
#         data = json.load(file)
#     return data

# # Load data
# # dpsgd_data = load_data('dpsgd.json')
# # ours_data = load_data('ours.json')

# dpsgd_data = load_data('/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json')
# ours_data = load_data('/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json')


# # Extract instructions and outputs
# instructions = [item['instruction'] for item in dpsgd_data]
# dpsgd_outputs = [item['output'] for item in dpsgd_data]
# ours_outputs = [item['output'] for item in ours_data]

# # Detect PII in instructions and outputs
# pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
# pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
# pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

# # Function to count PII entities
# def count_pii_entities(entities):
#     return len(entities)

# # Count PII in instructions and outputs
# pii_counts_instructions = [count_pii_entities(entities) for entities in pii_instructions]
# pii_counts_dpsgd_outputs = [count_pii_entities(entities) for entities in pii_dpsgd_outputs]
# pii_counts_ours_outputs = [count_pii_entities(entities) for entities in pii_ours_outputs]

# # Analyze PII additions and drops
# pii_added_dpsgd = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_dpsgd_outputs)]
# pii_added_ours = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_ours_outputs)]

# # Print useful information
# print("PII counts in instructions:", pii_counts_instructions)
# print("PII counts in DPSGD outputs:", pii_counts_dpsgd_outputs)
# print("PII counts in your method outputs:", pii_counts_ours_outputs)
# print("PII added by DPSGD:", pii_added_dpsgd)
# print("PII added by your method:", pii_added_ours)

# # Prepare data for plotting
# freq_data = {
#     "Method": ["DPSGD", "Your Method"],
#     "PII Added": [sum(pii_added_dpsgd), sum(pii_added_ours)],
#     "PII Dropped": [-sum(pii_added_dpsgd), -sum(pii_added_ours)]  # Negative to represent drops
# }
# df = pd.DataFrame(freq_data)

# # Plot
# ax = df.plot(x="Method", kind="bar", stacked=True, title="PII Additions and Drops")
# plt.ylabel("Count")
# plt.tight_layout()

# # Save plot as PDF
# plt.savefig("pii_additions_and_drops.pdf", format='pdf', dpi=400)

# plt.show()

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from gliner import GLiNER
import argparse

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
    except KeyError as e:
        print(f"KeyError: {e}")
        entities = []
    return entities

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to count PII entities
def count_pii_entities(entities):
    return len(entities)

# Main function
def main(dpsgd_file, ours_file, output_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs, limit to first 5 examples
    instructions = [item['instruction'] for item in dpsgd_data[:5]]
    dpsgd_outputs = [item['output'] for item in dpsgd_data[:5]]
    ours_outputs = [item['output'] for item in ours_data[:5]]

    # Detect PII in instructions and outputs
    pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
    pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
    pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

    # Count PII in instructions and outputs
    pii_counts_instructions = [count_pii_entities(entities) for entities in pii_instructions]
    pii_counts_dpsgd_outputs = [count_pii_entities(entities) for entities in pii_dpsgd_outputs]
    pii_counts_ours_outputs = [count_pii_entities(entities) for entities in pii_ours_outputs]

    # Analyze PII additions and drops
    pii_added_dpsgd = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_dpsgd_outputs)]
    pii_added_ours = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_ours_outputs)]

    # Print useful information
    print("PII counts in instructions:", pii_counts_instructions)
    print("PII counts in DPSGD outputs:", pii_counts_dpsgd_outputs)
    print("PII counts in our method outputs:", pii_counts_ours_outputs)
    print("PII added by DPSGD:", pii_added_dpsgd)
    print("PII added by our method:", pii_added_ours)

    # Prepare data for plotting
    freq_data = {
        "Method": ["DPSGD", "Ours"],
        "PII Added": [sum(pii_added_dpsgd), sum(pii_added_ours)],
        "PII Dropped": [-sum(pii_added_dpsgd), -sum(pii_added_ours)]  # Negative to represent drops
    }
    df = pd.DataFrame(freq_data)

    # Plot
    ax = df.plot(x="Method", kind="bar", stacked=True, title="PII Additions and Drops")
    plt.ylabel("Count")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Evaluate PII additions and drops in generated text outputs.")
#     parser.add_argument("-d", "--dpsgd_file", type=str, required=True, help="Path to the DPSGD results JSON file.")
#     parser.add_argument("-o", "--ours_file", type=str, required=True, help="Path to our method results JSON file.")
#     parser.add_argument("-f", "--output_file", type=str, required=True, help="Path to save the output PDF file.")

#     args = parser.parse_args()
#     main(args.dpsgd_file, args.ours_file, args.output_file)

if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json'
    output_file = 'hallucinations_xsum.pdf'

    main(dpsgd_file, ours_file, output_file)
# Out:
# PII counts in instructions: [2, 13, 5, 7, 9]
# PII counts in DPSGD outputs: [3, 3, 4, 3, 5]
# PII counts in our method outputs: [3, 2, 3, 1, 3]
# PII added by DPSGD: [1, -10, -1, -4, -4]
# PII added by our method: [1, -11, -2, -6, -6]

# %%
# Out:
# python: can't open file '/gpfs1/home/k/n/kngongiv/Research/hallucination.py': [Errno 2] No such file or directory

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import argparse
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
    except KeyError as e:
        print(f"KeyError: {e}")
        entities = []
    return entities

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities
def count_pii_entities(entities):
    return len(entities)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs, limit to first 5 examples
    instructions = [item['instruction'] for item in dpsgd_data[:5]]
    dpsgd_outputs = [item['output'] for item in dpsgd_data[:5]]
    ours_outputs = [item['output'] for item in ours_data[:5]]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Count PII in instructions and outputs
    pii_counts_instructions = [count_pii_entities(entities) for entities in pii_instructions]
    pii_counts_dpsgd_outputs = [count_pii_entities(entities) for entities in pii_dpsgd_outputs]
    pii_counts_ours_outputs = [count_pii_entities(entities) for entities in pii_ours_outputs]

    # Analyze PII additions and drops
    pii_added_dpsgd = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_dpsgd_outputs)]
    pii_added_ours = [out - inp for inp, out in zip(pii_counts_instructions, pii_counts_ours_outputs)]
    pii_dropped_dpsgd = [inp - out for inp, out in zip(pii_counts_instructions, pii_counts_dpsgd_outputs)]
    pii_dropped_ours = [inp - out for inp, out in zip(pii_counts_instructions, pii_counts_ours_outputs)]

    
    print(f"pii_added_dpsgd: {sum(pii_added_dpsgd)}, \tpii_dropped_dpsgd: {sum(pii_dropped_dpsgd)},\npii_added_ours: {sum(pii_added_ours)}, \tpii_dropped_ours: {sum(pii_dropped_ours)}")

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [sum(pii_added_dpsgd), sum(pii_dropped_dpsgd), sum(pii_added_ours), sum(pii_dropped_ours)]
    })

    # Pivot data for stacked bar chart
    freq_data_pivot = freq_data.pivot(index='Method', columns='PII Type', values='Count')

    # Plot with seaborn
    sns.set(style="whitegrid")
    freq_data_pivot.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#5DADE2', '#E74C3C'])
    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Evaluate PII additions and drops in generated text outputs.")
    parser.add_argument("-d", "--dpsgd_file", type=str, required=True, help="Path to the DPSGD results JSON file.")
    parser.add_argument("-o", "--ours_file", type=str, required=True, help="Path to our method results JSON file.")
    parser.add_argument("-f", "--output_file", type=str, required=True, help="Path to save the output PDF file.")
    parser.add_argument("-s", "--save_file", type=str, required=True, help="Path to save the PII detection results.")

    args = parser.parse_args()
    main(args.dpsgd_file, args.ours_file, args.output_file, args.save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Evaluate PII additions and drops in generated text outputs.")
#     parser.add_argument("-d", "--dpsgd_file", type=str, required=True, help="Path to the DPSGD results JSON file.")
#     parser.add_argument("-o", "--ours_file", type=str, required=True, help="Path to our method results JSON file.")
#     parser.add_argument("-f", "--output_file", type=str, required=True, help="Path to save the output PDF file.")
#     parser.add_argument("-s", "--save_file", type=str, required=True, help="Path to save the PII detection results.")

#     args = parser.parse_args()
#     main(args.dpsgd_file, args.ours_file, args.output_file, args.save_file)


if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json'
    output_file = 'hallucinations_xsum.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# pii_added_dpsgd: -18, 	pii_dropped_dpsgd18,
# pii_added_ours -24, 	pii_dropped_ours24

# %% [markdown]
# **PII Added:** This is the count of PII entities present in the output but not in the input.
#
# **PII Dropped:** This is the count of PII entities present in the input but not in the output.
#
# The code converts the PII entities into a hashable form (using tuples of dictionary items) to enable set operations for computing added and dropped PII entities.

# %%
# import json
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import argparse
# from gliner import GLiNER

# # Load the GLiNER PII model
# model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# # Function to detect PII
# def detect_pii(text, labels):
#     try:
#         entities = model.predict_entities(text, labels)
#     except KeyError as e:
#         print(f"KeyError: {e}")
#         entities = []
#     return entities

# # Define the PII labels
# pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
#               "credit card number", "social security number", "health insurance id number", 
#               "date of birth", "mobile phone number", "bank account number", "medication", 
#               "cpf", "driver's license number", "tax identification number", "medical condition", 
#               "identity card number", "national id number", "ip address", "email address", "iban", 
#               "credit card expiration date", "username", "health insurance number", "registration number", 
#               "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
#               "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
#               "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
#               "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
#               "transaction number", "national health insurance number", "cvc", "birth certificate number", 
#               "train ticket number", "passport expiration date", "social_security_number"]

# # Function to load data from JSON file
# def load_data(filename):
#     with open(filename, 'r') as file:
#         data = json.load(file)
#     return data

# # Function to save PII detection results
# def save_pii_results(data, filename):
#     with open(filename, 'w') as file:
#         json.dump(data, file)

# # Function to load PII detection results
# def load_pii_results(filename):
#     try:
#         with open(filename, 'r') as file:
#             data = json.load(file)
#         return data
#     except FileNotFoundError:
#         return None

# # Function to count PII entities
# def count_pii_entities(entities):
#     return len(entities)

# # Function to convert PII entities to a hashable form
# def pii_to_hashable(entities):
#     return set(tuple(entity.items()) for entity in entities)

# # Function to count PII entities that are added or dropped
# def compute_pii_changes(original, modified):
#     original_set = pii_to_hashable(original)
#     modified_set = pii_to_hashable(modified)
#     added = modified_set - original_set
#     dropped = original_set - modified_set
#     return len(added), len(dropped)

# # Main function
# def main(dpsgd_file, ours_file, output_file, save_file):
#     # Load data
#     dpsgd_data = load_data(dpsgd_file)
#     ours_data = load_data(ours_file)

#     # Extract instructions and outputs
#     instructions = [item['instruction'] for item in dpsgd_data]
#     dpsgd_outputs = [item['output'] for item in dpsgd_data]
#     ours_outputs = [item['output'] for item in ours_data]

#     # Load or detect PII
#     pii_results = load_pii_results(save_file)
#     if not pii_results:
#         pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
#         pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
#         pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

#         pii_results = {
#             "pii_instructions": pii_instructions,
#             "pii_dpsgd_outputs": pii_dpsgd_outputs,
#             "pii_ours_outputs": pii_ours_outputs
#         }
#         save_pii_results(pii_results, save_file)
#     else:
#         pii_instructions = pii_results["pii_instructions"]
#         pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
#         pii_ours_outputs = pii_results["pii_ours_outputs"]

#     # Analyze PII additions and drops
#     pii_added_dpsgd, pii_dropped_dpsgd = 0, 0
#     pii_added_ours, pii_dropped_ours = 0, 0

#     for instr, dpsgd_out, ours_out in zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs):
#         added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
#         added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
#         pii_added_dpsgd += added_dpsgd
#         pii_dropped_dpsgd += dropped_dpsgd
#         pii_added_ours += added_ours
#         pii_dropped_ours += dropped_ours

#     print(f"pii_added_dpsgd: {pii_added_dpsgd}, \tpii_dropped_dpsgd: {pii_dropped_dpsgd},\npii_added_ours: {pii_added_ours}, \tpii_dropped_ours: {pii_dropped_ours}")

#     # Prepare data for plotting
#     freq_data = pd.DataFrame({
#         "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
#         "PII Type": ["Added", "Dropped", "Added", "Dropped"],
#         "Count": [pii_added_dpsgd, pii_dropped_dpsgd, pii_added_ours, pii_dropped_ours]
#     })

#     # Pivot data for stacked bar chart
#     freq_data_pivot = freq_data.pivot(index='Method', columns='PII Type', values='Count')

#     # Plot with seaborn
#     sns.set(style="whitegrid")
#     freq_data_pivot.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#5DADE2', '#E74C3C'])
#     plt.title("PII Additions and Drops")
#     plt.ylabel("Count")
#     plt.xlabel("Method")
#     plt.legend(title="PII Type", bbox_to_anchor=(1.05, 1), loc='upper left')
#     plt.tight_layout()

#     # Save plot as PDF
#     plt.savefig(output_file, format='pdf', dpi=400)

#     plt.show()

# # if __name__ == "__main__":
# #     parser = argparse.ArgumentParser(description="Evaluate PII additions and drops in generated text outputs.")
# #     parser.add_argument("-d", "--dpsgd_file", type=str, required=True, help="Path to the DPSGD results JSON file.")
# #     parser.add_argument("-o", "--ours_file", type=str, required=True, help="Path to our method results JSON file.")
# #     parser.add_argument("-f", "--output_file", type=str, required=True, help="Path to save the output PDF file.")
# #     parser.add_argument("-s", "--save_file", type=str, required=True, help="Path to save the PII detection results.")

# #     args = parser.parse_args()
# #     main(args.dpsgd_file, args.ours_file, args.output_file, args.save_file)

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import argparse
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
    except KeyError as e:
        print(f"KeyError: {e}")
        entities = []
    return entities

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities
def count_pii_entities(entities):
    return len(entities)

# Function to convert PII entities to a hashable form
def pii_to_hashable(entities):
    return set(tuple(entity.items()) for entity in entities)

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = pii_to_hashable(original)
    modified_set = pii_to_hashable(modified)
    added = modified_set - original_set
    dropped = original_set - modified_set
    return len(added), len(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    pii_added_dpsgd, pii_dropped_dpsgd = 0, 0
    pii_added_ours, pii_dropped_ours = 0, 0

    for instr, dpsgd_out, ours_out in zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        pii_added_dpsgd += added_dpsgd
        pii_dropped_dpsgd += dropped_dpsgd
        pii_added_ours += added_ours
        pii_dropped_ours += dropped_ours

    print(f"pii_added_dpsgd: {pii_added_dpsgd}, \tpii_dropped_dpsgd: {pii_dropped_dpsgd},\npii_added_ours: {pii_added_ours}, \tpii_dropped_ours: {pii_dropped_ours}")

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [pii_added_dpsgd, pii_dropped_dpsgd, pii_added_ours, pii_dropped_ours]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description="Evaluate PII additions and drops in generated text outputs.")
    parser.add_argument("-d", "--dpsgd_file", type=str, required=True, help="Path to the DPSGD results JSON file.")
    parser.add_argument("-o", "--ours_file", type=str, required=True, help="Path to our method results JSON file.")
    parser.add_argument("-f", "--output_file", type=str, required=True, help="Path to save the output PDF file.")
    parser.add_argument("-s", "--save_file", type=str, required=True, help="Path to save the PII detection results.")

    args = parser.parse_args()
    main(args.dpsgd_file, args.ours_file, args.output_file, args.save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json'
    output_file = 'hallucinations_xsum.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# pii_added_dpsgd: 18, 	pii_dropped_dpsgd: 36,
# pii_added_ours: 12, 	pii_dropped_ours: 36

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import argparse
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
    except KeyError as e:
        print(f"KeyError: {e}")
        entities = []
    return entities

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities
def count_pii_entities(entities):
    return len(entities)

# Function to convert PII entities to a hashable form
def pii_to_hashable(entities):
    return set(tuple(entity.items()) for entity in entities)

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = pii_to_hashable(original)
    modified_set = pii_to_hashable(modified)
    added = modified_set - original_set
    dropped = original_set - modified_set
    return len(added), len(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    pii_added_dpsgd, pii_dropped_dpsgd = 0, 0
    pii_added_ours, pii_dropped_ours = 0, 0

    for instr, dpsgd_out, ours_out in zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        pii_added_dpsgd += added_dpsgd
        pii_dropped_dpsgd += dropped_dpsgd
        pii_added_ours += added_ours
        pii_dropped_ours += dropped_ours

    print(f"pii_added_dpsgd: {pii_added_dpsgd}, \tpii_dropped_dpsgd: {pii_dropped_dpsgd},\npii_added_ours: {pii_added_ours}, \tpii_dropped_ours: {pii_dropped_ours}")

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [pii_added_dpsgd, pii_dropped_dpsgd, pii_added_ours, pii_dropped_ours]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = p.get_height()
        ax.annotate(format(height),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()


if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json'
    output_file = 'hallucinations_xsum.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)

# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Evaluate PII additions and drops in generated text outputs.")
#     parser.add_argument("-d", "--dpsgd_file", type=str, required=True, help="Path to the DPSGD results JSON file.")
#     parser.add_argument("-o", "--ours_file", type=str, required=True, help="Path to our method results JSON file.")
#     parser.add_argument("-f", "--output_file", type=str, required=True, help="Path to save the output PDF file.")
#     parser.add_argument("-s", "--save_file", type=str, required=True, help="Path to save the PII detection results.")

#     args = parser.parse_args()
#     main(args.dpsgd_file, args.ours_file, args.output_file, args.save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pii_added_dpsgd: 17597, 	pii_dropped_dpsgd: 49182,
# pii_added_ours: 15091, 	pii_dropped_ours: 49182

# %% [markdown]
# ### Understanding the Values Added and Dropped

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import argparse
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        return [entity['text'] for entity in entities]  # Extract only the text of the PII entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set(original)
    modified_set = set(modified)
    added = modified_set - original_set
    dropped = original_set - modified_set
    return list(added), list(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": dpsgd_out,
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": dpsgd_out,
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "Our Output": ours_outputs[idx],
                "Our PII Values": ours_out,
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "Our Output": ours_outputs[idx],
                "Our PII Values": ours_out,
                "Dropped PII": dropped
            })

    # Save added and dropped records to CSV files
    pd.DataFrame(dpsgd_added_records).to_csv("dpsgd_pii_added.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv("dpsgd_pii_dropped.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv("ours_pii_added.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv("ours_pii_dropped.csv", index=False)

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

# if __name__ == "__main__":
#     parser = argparse.ArgumentParser(description="Evaluate PII additions and drops in generated text outputs.")
#     parser.add_argument("-d", "--dpsgd_file", type=str, required=True, help="Path to the DPSGD results JSON file.")
#     parser.add_argument("-o", "--ours_file", type=str, required=True, help="Path to our method results JSON file.")
#     parser.add_argument("-f", "--output_file", type=str, required=True, help="Path to save the output PDF file.")
#     parser.add_argument("-s", "--save_file", type=str, required=True, help="Path to save the PII detection results.")

#     args = parser.parse_args()
#     main(args.dpsgd_file, args.ours_file, args.output_file, args.save_file)

if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json'
    output_file = 'hallucinations_xsum.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        return [entity['text'] for entity in entities]  # Extract only the text of the PII entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    def to_tuple(d):
        return tuple(sorted(d.items()))
    
    original_set = set(map(to_tuple, original))
    modified_set = set(map(to_tuple, modified))
    
    added = modified_set - original_set
    dropped = original_set - modified_set
    
    # Convert back to list of dictionaries
    added = [dict(item) for item in added]
    dropped = [dict(item) for item in dropped]
    
    return added, dropped

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": dpsgd_out,
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": dpsgd_out,
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "Our Output": ours_outputs[idx],
                "Our PII Values": ours_out,
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": instr,
                "Our Output": ours_outputs[idx],
                "Our PII Values": ours_out,
                "Dropped PII": dropped
            })

    # # Save added and dropped records to CSV files
    # pd.DataFrame(dpsgd_added_records).to_csv("dpsgd_pii_added.csv", index=False)
    # pd.DataFrame(dpsgd_dropped_records).to_csv("dpsgd_pii_dropped.csv", index=False)
    # pd.DataFrame(ours_added_records).to_csv("ours_pii_added.csv", index=False)
    # pd.DataFrame(ours_dropped_records).to_csv("ours_pii_dropped.csv", index=False)

    path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum"
    pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped.csv", index=False)


    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()


if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json'
    output_file = 'hallucinations_xsum.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        extracted_entities = [{'text': entity['text'], 'label': entity['label']} for entity in entities]
        print(f"Detected entities: {extracted_entities}")
        return extracted_entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set([item['text'] for item in original])
    modified_set = set([item['text'] for item in modified])
    added = modified_set - original_set
    dropped = original_set - modified_set
    return list(added), list(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Dropped PII": dropped
            })

    # Save added and dropped records to CSV files
    path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum"
    pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped.csv", index=False)

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("XSUM Dataset")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

# if __name__ == "__main__":
#     # Test setup for fixed file paths
#     dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
#     ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
#     output_file = 'hallucinations_mrpc.pdf'
#     save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

#     main(dpsgd_file, ours_file, output_file, save_file)

if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_results_xsum.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_results_xsum.json'
    output_file = 'hallucinations_xsum.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/xsum_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        extracted_entities = [{'text': entity['text'], 'label': entity['label']} for entity in entities]
        print(f"Detected entities: {extracted_entities}")
        return extracted_entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set([item['text'] for item in original])
    modified_set = set([item['text'] for item in modified])
    added = modified_set - original_set
    dropped = original_set - modified_set
    return list(added), list(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Dropped PII": dropped
            })

    # Save added and dropped records to CSV files
    path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/pubmed"
    pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped.csv", index=False)

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PubMed Dataset")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_pubmeds.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_pubmeds.json'
    output_file = 'hallucinations_pubmeds.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/pubmed_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# import json
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from gliner import GLiNER

# # Load the GLiNER PII model
# model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# # Function to detect PII
# def detect_pii(text, labels):
#     try:
#         entities = model.predict_entities(text, labels)
#         return [entity['text'] for entity in entities]  # Extract only the text of the PII entities
#     except KeyError as e:
#         print(f"KeyError: {e}")
#         return []

# # Define the PII labels
# pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
#               "credit card number", "social security number", "health insurance id number", 
#               "date of birth", "mobile phone number", "bank account number", "medication", 
#               "cpf", "driver's license number", "tax identification number", "medical condition", 
#               "identity card number", "national id number", "ip address", "email address", "iban", 
#               "credit card expiration date", "username", "health insurance number", "registration number", 
#               "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
#               "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
#               "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
#               "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
#               "transaction number", "national health insurance number", "cvc", "birth certificate number", 
#               "train ticket number", "passport expiration date", "social_security_number"]

# # Function to load data from JSON file
# def load_data(filename):
#     with open(filename, 'r') as file:
#         data = json.load(file)
#     return data

# # Function to save PII detection results
# def save_pii_results(data, filename):
#     with open(filename, 'w') as file:
#         json.dump(data, file)

# # Function to load PII detection results
# def load_pii_results(filename):
#     try:
#         with open(filename, 'r') as file:
#             data = json.load(file)
#         return data
#     except FileNotFoundError:
#         return None

# # Function to count PII entities that are added or dropped
# def compute_pii_changes(original, modified):
#     original_set = set(original)
#     modified_set = set(modified)
#     added = modified_set - original_set
#     dropped = original_set - modified_set
#     return list(added), list(dropped)

# # Main function
# def main(dpsgd_file, ours_file, output_file, save_file):
#     # Load data
#     dpsgd_data = load_data(dpsgd_file)
#     ours_data = load_data(ours_file)

#     # Extract instructions and outputs
#     instructions = [item['instruction'] for item in dpsgd_data]
#     dpsgd_outputs = [item['output'] for item in dpsgd_data]
#     ours_outputs = [item['output'] for item in ours_data]

#     # Load or detect PII
#     pii_results = load_pii_results(save_file)
#     if not pii_results:
#         pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
#         pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
#         pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

#         pii_results = {
#             "pii_instructions": pii_instructions,
#             "pii_dpsgd_outputs": pii_dpsgd_outputs,
#             "pii_ours_outputs": pii_ours_outputs
#         }
#         save_pii_results(pii_results, save_file)
#     else:
#         pii_instructions = pii_results["pii_instructions"]
#         pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
#         pii_ours_outputs = pii_results["pii_ours_outputs"]

#     # Analyze PII additions and drops
#     dpsgd_added_records = []
#     dpsgd_dropped_records = []
#     ours_added_records = []
#     ours_dropped_records = []

#     for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
#         added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
#         added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
#         for added in added_dpsgd:
#             dpsgd_added_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "DPSGD Output": dpsgd_outputs[idx],
#                 "DPSGD PII Values": dpsgd_out,
#                 "Added PII": added
#             })
        
#         for dropped in dropped_dpsgd:
#             dpsgd_dropped_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "DPSGD Output": dpsgd_outputs[idx],
#                 "DPSGD PII Values": dpsgd_out,
#                 "Dropped PII": dropped
#             })
        
#         for added in added_ours:
#             ours_added_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "Our Output": ours_outputs[idx],
#                 "Our PII Values": ours_out,
#                 "Added PII": added
#             })
        
#         for dropped in dropped_ours:
#             ours_dropped_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "Our Output": ours_outputs[idx],
#                 "Our PII Values": ours_out,
#                 "Dropped PII": dropped
#             })

#     # Save added and dropped records to CSV files
#     for record in dpsgd_added_records:
#         record['Original PII Values'] = [item for item in record['Original PII Values']]
#         record['DPSGD PII Values'] = [item for item in record['DPSGD PII Values']]
#     for record in dpsgd_dropped_records:
#         record['Original PII Values'] = [item for item in record['Original PII Values']]
#         record['DPSGD PII Values'] = [item for item in record['DPSGD PII Values']]
#     for record in ours_added_records:
#         record['Original PII Values'] = [item for item in record['Original PII Values']]
#         record['Our PII Values'] = [item for item in record['Our PII Values']]
#     for record in ours_dropped_records:
#         record['Original PII Values'] = [item for item in record['Original PII Values']]
#         record['Our PII Values'] = [item for item in record['Our PII Values']]

#     pd.DataFrame(dpsgd_added_records).to_csv("dpsgd_pii_added.csv", index=False)
#     pd.DataFrame(dpsgd_dropped_records).to_csv("dpsgd_pii_dropped.csv", index=False)
#     pd.DataFrame(ours_added_records).to_csv("ours_pii_added.csv", index=False)
#     pd.DataFrame(ours_dropped_records).to_csv("ours_pii_dropped.csv", index=False)

#     # Prepare data for plotting
#     freq_data = pd.DataFrame({
#         "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
#         "PII Type": ["Added", "Dropped", "Added", "Dropped"],
#         "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
#     })

#     # Plot with seaborn
#     sns.set(style="whitegrid")
#     plt.figure(figsize=(10, 6))

#     # Plotting bar chart
#     ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

#     # Annotate bars with actual numbers
#     for p in ax.patches:
#         height = int(p.get_height())
#         ax.annotate(format(height, 'd'),
#                     (p.get_x() + p.get_width() / 2., height),
#                     ha='center', va='center',
#                     xytext=(0, 9),
#                     textcoords='offset points')

#     plt.title("PII Additions and Drops")
#     plt.ylabel("Count")
#     plt.xlabel("Method")
#     plt.legend(title="PII Type")
#     plt.tight_layout()

#     # Save plot as PDF
#     plt.savefig(output_file, format='pdf', dpi=400)

#     plt.show()

# if __name__ == "__main__":
#     # Test setup for fixed file paths
#     dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
#     ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
#     output_file = 'hallucinations_mrpc.pdf'
#     save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

#     main(dpsgd_file, ours_file, output_file, save_file)

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        return [{'text': entity['text'], 'label': entity['label']} for entity in entities]
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set([item['text'] for item in original])
    modified_set = set([item['text'] for item in modified])
    added = modified_set - original_set
    dropped = original_set - modified_set
    return list(added), list(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Dropped PII": dropped
            })

    # # Save added and dropped records to CSV files
    # pd.DataFrame(dpsgd_added_records).to_csv("dpsgd_pii_added.csv", index=False)
    # pd.DataFrame(dpsgd_dropped_records).to_csv("dpsgd_pii_dropped.csv", index=False)
    # pd.DataFrame(ours_added_records).to_csv("ours_pii_added.csv", index=False)
    # pd.DataFrame(ours_dropped_records).to_csv("ours_pii_dropped.csv", index=False)

    path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"
    pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped.csv", index=False)


    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
    output_file = 'hallucinations_mrpc.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# import json
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import argparse
# from gliner import GLiNER

# # Load the GLiNER PII model
# model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# # Function to detect PII
# def detect_pii(text, labels):
#     try:
#         entities = model.predict_entities(text, labels)
#     except KeyError as e:
#         print(f"KeyError: {e}")
#         entities = []
#     return entities

# # Define the PII labels
# pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
#               "credit card number", "social security number", "health insurance id number", 
#               "date of birth", "mobile phone number", "bank account number", "medication", 
#               "cpf", "driver's license number", "tax identification number", "medical condition", 
#               "identity card number", "national id number", "ip address", "email address", "iban", 
#               "credit card expiration date", "username", "health insurance number", "registration number", 
#               "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
#               "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
#               "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
#               "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
#               "transaction number", "national health insurance number", "cvc", "birth certificate number", 
#               "train ticket number", "passport expiration date", "social_security_number"]

# # Function to load data from JSON file
# def load_data(filename):
#     with open(filename, 'r') as file:
#         data = json.load(file)
#     return data

# # Function to save PII detection results
# def save_pii_results(data, filename):
#     with open(filename, 'w') as file:
#         json.dump(data, file)

# # Function to load PII detection results
# def load_pii_results(filename):
#     try:
#         with open(filename, 'r') as file:
#             data = json.load(file)
#         return data
#     except FileNotFoundError:
#         return None

# # Function to convert PII entities to a hashable form
# def pii_to_hashable(entities):
#     return set(tuple(entity.items()) for entity in entities)

# # Function to count PII entities that are added or dropped
# def compute_pii_changes(original, modified):
#     original_set = pii_to_hashable(original)
#     modified_set = pii_to_hashable(modified)
#     added = modified_set - original_set
#     dropped = original_set - modified_set
#     return list(added), list(dropped)

# # Main function
# def main(dpsgd_file, ours_file, output_file, save_file):
#     # Load data
#     dpsgd_data = load_data(dpsgd_file)
#     ours_data = load_data(ours_file)

#     # Extract instructions and outputs
#     instructions = [item['instruction'] for item in dpsgd_data]
#     dpsgd_outputs = [item['output'] for item in dpsgd_data]
#     ours_outputs = [item['output'] for item in ours_data]

#     # Load or detect PII
#     pii_results = load_pii_results(save_file)
#     if not pii_results:
#         pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
#         pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
#         pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

#         pii_results = {
#             "pii_instructions": pii_instructions,
#             "pii_dpsgd_outputs": pii_dpsgd_outputs,
#             "pii_ours_outputs": pii_ours_outputs
#         }
#         save_pii_results(pii_results, save_file)
#     else:
#         pii_instructions = pii_results["pii_instructions"]
#         pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
#         pii_ours_outputs = pii_results["pii_ours_outputs"]

#     # Analyze PII additions and drops
#     dpsgd_added_records = []
#     dpsgd_dropped_records = []
#     ours_added_records = []
#     ours_dropped_records = []

#     for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
#         added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
#         added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
#         for added in added_dpsgd:
#             dpsgd_added_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "DPSGD Output": dpsgd_outputs[idx],
#                 "DPSGD PII Values": dpsgd_out,
#                 "Added PII": added
#             })
        
#         for dropped in dropped_dpsgd:
#             dpsgd_dropped_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "DPSGD Output": dpsgd_outputs[idx],
#                 "DPSGD PII Values": dpsgd_out,
#                 "Dropped PII": dropped
#             })
        
#         for added in added_ours:
#             ours_added_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "Our Output": ours_outputs[idx],
#                 "Our PII Values": ours_out,
#                 "Added PII": added
#             })
        
#         for dropped in dropped_ours:
#             ours_dropped_records.append({
#                 "Index": idx,
#                 "Original Example": instructions[idx],
#                 "Original PII Values": instr,
#                 "Our Output": ours_outputs[idx],
#                 "Our PII Values": ours_out,
#                 "Dropped PII": dropped
#             })

#     # Save added and dropped records to CSV files
#     path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"
#     pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added.csv", index=False)
#     pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped.csv", index=False)
#     pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added.csv", index=False)
#     pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped.csv", index=False)

#     # Prepare data for plotting
#     freq_data = pd.DataFrame({
#         "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
#         "PII Type": ["Added", "Dropped", "Added", "Dropped"],
#         "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
#     })

#     # Plot with seaborn
#     sns.set(style="whitegrid")
#     plt.figure(figsize=(10, 6))

#     # Plotting bar chart
#     ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

#     # Annotate bars with actual numbers
#     for p in ax.patches:
#         height = int(p.get_height())
#         ax.annotate(format(height, 'd'),
#                     (p.get_x() + p.get_width() / 2., height),
#                     ha='center', va='center',
#                     xytext=(0, 9),
#                     textcoords='offset points')

#     # plt.title("PII Additions and Drops")
#     plt.ylabel("Count")
#     plt.xlabel("Method")
#     plt.legend(title="PII Type")
#     plt.tight_layout()

#     # Save plot as PDF
#     plt.savefig(output_file, format='pdf', dpi=400)

#     plt.show()

# if __name__ == "__main__":
#     # Test setup for fixed file paths
#     dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
#     ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
#     output_file = 'hallucinations_mrpc.pdf'
#     save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

#     main(dpsgd_file, ours_file, output_file, save_file)

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        extracted_entities = [{'text': entity['text'], 'label': entity['label']} for entity in entities]
        print(f"Detected entities: {extracted_entities}")
        return extracted_entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set([item['text'] for item in original])
    modified_set = set([item['text'] for item in modified])
    added = modified_set - original_set
    dropped = original_set - modified_set
    return list(added), list(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Dropped PII": dropped
            })

    # Save added and dropped records to CSV files
    path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"
    pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped.csv", index=False)

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("MRPC")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
    output_file = 'hallucinations_mrpc.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        extracted_entities = [{'text': entity['text'], 'label': entity['label']} for entity in entities]
        print(f"Detected entities: {extracted_entities}")  # Print the extracted entities
        return extracted_entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set([item['text'] for item in original])
    modified_set = set([item['text'] for item in modified])
    added = modified_set - original_set
    dropped = original_set - modified_set
    print(f"Original: {original_set}, Modified: {modified_set}, Added: {added}, Dropped: {dropped}")
    return list(added), list(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Dropped PII": dropped
            })

    # Save added and dropped records to CSV files
    path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"
    pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped.csv", index=False)

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()

if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
    output_file = 'hallucinations_mrpc.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# Original: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Modified: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Added: set(), Dropped: set()
# Original: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Modified: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Added: set(), Dropped: set()
# Original: {"world 's two largest automakers"}, Modified: {'nissan', 'honda'}, Added: {'nissan', 'honda'}, Dropped: {"world 's two largest automakers"}
# Original: {"world 's two largest automakers"}, Modified: {'industry', "The world's two largest automakers"}, Added: {'industry', "The world's two largest automakers"}, Dropped: {"world 's two largest automakers"}
# Original: {'Centers for Disease Control and Prevention', 'measles'}, Modified: {'Centers for Disease Control and Prevention', 'mumps', 'measles'}, Added: {'mumps'}, Dropped: set()
# Original: {'Centers for Disease Control and Prevention', 'measles'}, Modified: {'measles'}, Added: set(), Dropped: {'Centers for Disease Control and Prevention'}
# Original: set(), Modified: {'u.s. senator'}, Added: {'u.s. senator'}, Dropped: set()
# Original: set(), Modified: {'National Weather Service'}, Added: {'National Weather Service'}, Dropped: set()
# Original: {'company'}, Modified: {'spokesman', 'company'}, Added: {'spokesman'}, Dropped: set()
# Original: {'company'}, Modified: {'company'}, Added: set(), Dropped: set()
# Original: {'he', 'settling companies', 'underwriters'}, Modified: {'he', 'settling companies', 'underwriters'}, Added: set(), Dropped: set()
# Original: {'he', 'settling companies', 'underwriters'}, Modified: {'he', 'settling companies', 'underwriters'}, Added: set(), Dropped: set()
# Original: {'Air Commodore Quaife', 'Hornets'}, Modified: {'Air Commodore Quaife', 'Air Force', 'Hornets'}, Added: {'Air Force'}, Dropped: set()
# Original: {'Air Commodore Quaife', 'Hornets'}, Modified: {'Air Commodore Quaife', 'Hornets'}, Added: set(), Dropped: set()
# Original: {'health department', 'Washington County'}, Modified: {'health department', 'man'}, Added: {'man'}, Dropped: {'Washington County'}
# Original: {'health department', 'Washington County'}, Modified: {'state health department', 'West Nile virus', 'man'}, Added: {'state health department', 'West Nile virus', 'man'}, Dropped: {'health department', 'Washington County'}
# Original: {'Moseley', 'senior aide'}, Modified: {'Moseley', 'senior aide', 'Mosey'}, Added: {'Mosey'}, Dropped: set()
# Original: {'Moseley', 'senior aide'}, Modified: {'Moseley', 'NATO', 'senior aide'}, Added: {'NATO'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'Consumers', 'cable operator'}, Modified: {'Consumers', 'cable operator'}, Added: set(), Dropped: set()
# Original: {'Consumers', 'cable operator'}, Modified: {'consumer', 'cable company'}, Added: {'consumer', 'cable company'}, Dropped: {'Consumers', 'cable operator'}
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'RealNetworks'}, Modified: {'RealNetworks'}, Added: set(), Dropped: set()
# Original: {'RealNetworks'}, Modified: {'RealNetworks'}, Added: set(), Dropped: set()
# Original: set(), Modified: {'South Korea', 'Hong Kong'}, Added: {'South Korea', 'Hong Kong'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'police', 'two of the victims', 'two'}, Modified: {'police', 'two of the victims', 'two'}, Added: set(), Dropped: set()
# Original: {'police', 'two of the victims', 'two'}, Modified: {'two victims', 'the other two', 'Police'}, Added: {'the other two', 'Police', 'two victims'}, Dropped: {'police', 'two of the victims', 'two'}
# Original: {'Ballmer', 'Microsoft', 'Linux'}, Modified: {'Steve Ballmer', 'microsoft', 'Microsoft'}, Added: {'Steve Ballmer', 'microsoft'}, Dropped: {'Ballmer', 'Linux'}
# Original: {'Ballmer', 'Microsoft', 'Linux'}, Modified: {'Ballmer', 'Microsoft', 'Linux'}, Added: set(), Dropped: set()
# Original: {'officials'}, Modified: {'spanish peacekeepers'}, Added: {'spanish peacekeepers'}, Dropped: {'officials'}
# Original: {'officials'}, Modified: {'charter plane', 'officials', '62 Spanish peacekeepers'}, Added: {'charter plane', '62 Spanish peacekeepers'}, Dropped: set()
# Original: {'Moroccan Interior Minister', 'Al Mustapha Sahel', 'Djihad Salafist'}, Modified: {'Moroccan Interior Minister', 'Al Mustapha Sahel', 'Djihad Salafist'}, Added: set(), Dropped: set()
# Original: {'Moroccan Interior Minister', 'Al Mustapha Sahel', 'Djihad Salafist'}, Modified: {'Moroccan Interior Minister Al Mustapha Sahel', 'Djihad Salafist'}, Added: {'Moroccan Interior Minister Al Mustapha Sahel'}, Dropped: {'Moroccan Interior Minister', 'Al Mustapha Sahel'}
# Original: {'HBO', 'David Chase', 'Chris Albrecht'}, Modified: {'HBO', 'David Chase', 'Chris Albrecht'}, Added: set(), Dropped: set()
# Original: {'HBO', 'David Chase', 'Chris Albrecht'}, Modified: {'HBO', 'David Chase', 'Chris Albrecht'}, Added: set(), Dropped: set()
# Original: {'new board', 'two'}, Modified: {'The two', 'they', 'board'}, Added: {'The two', 'they', 'board'}, Dropped: {'new board', 'two'}
# Original: {'new board', 'two'}, Modified: {'The two', 'board'}, Added: {'The two', 'board'}, Dropped: {'new board', 'two'}
# Original: {'judge', 'crack cocaine kingpin'}, Modified: {'judge', 'crack cocaine kingpin'}, Added: set(), Dropped: set()
# Original: {'judge', 'crack cocaine kingpin'}, Modified: {'California court', 'judge', 'crack cocaine kingpin'}, Added: {'California court'}, Dropped: set()
# Original: {'he', 'we', 'I'}, Modified: {'he', 'spokesman', 'we', 'I'}, Added: {'spokesman'}, Dropped: set()
# Original: {'he', 'we', 'I'}, Modified: {'he', 'I'}, Added: set(), Dropped: {'we'}
# Original: {'Senator Clinton'}, Modified: {'Senator Clinton'}, Added: set(), Dropped: set()
# Original: {'Senator Clinton'}, Modified: {'Clinton', 'Senator Clinton'}, Added: {'Clinton'}, Dropped: set()
# Original: {'construction companies', 'Federal agents'}, Modified: {'thief', 'federal agents', 'construction companies', 'Federal agents', 'u.s. construction firms'}, Added: {'thief', 'u.s. construction firms', 'federal agents'}, Dropped: set()
# Original: {'construction companies', 'Federal agents'}, Modified: {'U.S. Department of Justice', 'Federal agents'}, Added: {'U.S. Department of Justice'}, Dropped: {'construction companies'}
# Original: {'Comcast'}, Modified: {'comcast', 'Comcast'}, Added: {'comcast'}, Dropped: set()
# Original: {'Comcast'}, Modified: {'comcast', 'Comcast'}, Added: {'comcast'}, Dropped: set()
# Original: {'Toepfer', "O 'Donnell", 'Schofield'}, Modified: {'Toepfer', "O 'Donnell", 'Schofield'}, Added: set(), Dropped: set()
# Original: {'Toepfer', "O 'Donnell", 'Schofield'}, Modified: {'Toepfer', "O 'Donnell", 'Schofield'}, Added: set(), Dropped: set()
# Original: {'Cuban plane', 'man'}, Modified: {'Cuban plane', 'man'}, Added: set(), Dropped: set()
# Original: {'Cuban plane', 'man'}, Modified: {'The man'}, Added: {'The man'}, Dropped: {'Cuban plane', 'man'}
# Original: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Modified: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Added: set(), Dropped: set()
# Original: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Modified: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Added: set(), Dropped: set()
# Original: {'Aug. 28 , 1925', "O 'Connor", 'circus trapeze artists turned vaudevillians'}, Modified: {"o' Connor", 'circus trapeze artists turned vaudevillians', 'circus artists', "O 'Connor", 'Chicago, il'}, Added: {'circus artists', "o' Connor", 'Chicago, il'}, Dropped: {'Aug. 28 , 1925'}
# Original: {'Aug. 28 , 1925', "O 'Connor", 'circus trapeze artists turned vaudevillians'}, Modified: {'Aug. 28, 1925', "O 'Connor", 'circus performers'}, Added: {'Aug. 28, 1925', 'circus performers'}, Dropped: {'Aug. 28 , 1925', 'circus trapeze artists turned vaudevillians'}
# Original: {'Missouri', 'Ricky Clemons'}, Modified: {'Missouri', 'Ricky Clemons'}, Added: set(), Dropped: set()
# Original: {'Missouri', 'Ricky Clemons'}, Modified: {'Missouri', 'Ricky Clemons'}, Added: set(), Dropped: set()
# Original: {'Dynes', 'Atkinson'}, Modified: {'Dynes', 'Atkinson'}, Added: set(), Dropped: set()
# Original: {'Dynes', 'Atkinson'}, Modified: {'Dynes', 'Dyne', 'Atkinson'}, Added: {'Dyne'}, Dropped: set()
# Original: {'Hurriyet', 'unnamed senior Iraqi official'}, Modified: {'Hurriyet', 'unnamed senior Iraqi official'}, Added: set(), Dropped: set()
# Original: {'Hurriyet', 'unnamed senior Iraqi official'}, Modified: {'Iraqi official', 'Hurriyet'}, Added: {'Iraqi official'}, Dropped: {'unnamed senior Iraqi official'}
# Original: {'Thomas'}, Modified: {'Thomas', 'we'}, Added: {'we'}, Dropped: set()
# Original: {'Thomas'}, Modified: {'team', 'Thomas'}, Added: {'team'}, Dropped: set()
# Original: {'136.03 / 14'}, Modified: {'136.03/ 14'}, Added: {'136.03/ 14'}, Dropped: {'136.03 / 14'}
# Original: {'136.03 / 14'}, Modified: set(), Added: set(), Dropped: {'136.03 / 14'}
# Original: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Modified: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Added: set(), Dropped: set()
# Original: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Modified: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Added: set(), Dropped: set()
# Original: {'women', 'assailants', 'victims of rape'}, Modified: {'women', 'assailants', 'victims of rape'}, Added: set(), Dropped: set()
# Original: {'women', 'assailants', 'victims of rape'}, Modified: {'perpetrators', 'rape victims', 'The women'}, Added: {'The women', 'rape victims', 'perpetrators'}, Dropped: {'women', 'assailants', 'victims of rape'}
# Original: {'Cicutto', 'The National', 'AMP'}, Modified: {'Cicutto', 'The National', 'AMP'}, Added: set(), Dropped: set()
# Original: {'Cicutto', 'The National', 'AMP'}, Modified: {'Cicutto', 'the National', 'The National', 'AMP'}, Added: {'the National'}, Dropped: set()
# Original: {'Mr. Rowland', 'Commissioner Anson'}, Modified: {'Mr. Rowland', 'Commissioner Anson'}, Added: set(), Dropped: set()
# Original: {'Mr. Rowland', 'Commissioner Anson'}, Modified: {'Mr. Rowland', 'Commissioner Anson'}, Added: set(), Dropped: set()
# Original: {'PeopleSoft', 'Oracle'}, Modified: {'PeopleSoft', 'peoplesoft', 'Peoplesoft', 'eric taylor', 'Oracle'}, Added: {'Peoplesoft', 'eric taylor', 'peoplesoft'}, Dropped: set()
# Original: {'PeopleSoft', 'Oracle'}, Modified: {'PeopleSoft', 'Peoplesoft', 'Oracle'}, Added: {'Peoplesoft'}, Dropped: set()
# Original: {'April 28', 'Amir Muhammed Rasheed', 'Taha', 'U.S. forces'}, Modified: {'April 28', 'Amir Muhammed Rasheed', 'Taha', 'U.S. forces'}, Added: set(), Dropped: set()
# Original: {'April 28', 'Amir Muhammed Rasheed', 'Taha', 'U.S. forces'}, Modified: {'April 28', 'Amir Muhammed Rasheed', 'Taha', 'U.S. forces'}, Added: set(), Dropped: set()
# Original: {'Cisco'}, Modified: {'Cisco'}, Added: set(), Dropped: set()
# Original: {'Cisco'}, Modified: {'Cisco'}, Added: set(), Dropped: set()
# Original: {'Seven 20- and 21-year-old cadets', 'off-campus hotel room', 'police', 'two young women'}, Modified: {'seven 20- and 21-year-old cadets', 'police', 'off-campus hotel room', 'two young women'}, Added: {'seven 20- and 21-year-old cadets'}, Dropped: {'Seven 20- and 21-year-old cadets'}
# Original: {'Seven 20- and 21-year-old cadets', 'off-campus hotel room', 'police', 'two young women'}, Modified: {'police', 'seven cadets', 'two young women'}, Added: {'seven cadets'}, Dropped: {'Seven 20- and 21-year-old cadets', 'off-campus hotel room'}
# Original: {'Kanaan', 'Dixon'}, Modified: {'Kanaan', 'kanaa', 'Dixon'}, Added: {'kanaa'}, Dropped: set()
# Original: {'Kanaan', 'Dixon'}, Modified: {'Kanaan', 'Dixon'}, Added: set(), Dropped: set()
# Original: {'peanut farmers', 'Congress'}, Modified: {'october', 'senate', 'Congress'}, Added: {'october', 'senate'}, Dropped: {'peanut farmers'}
# Original: {'peanut farmers', 'Congress'}, Modified: {'Congress'}, Added: set(), Dropped: {'peanut farmers'}
# Original: {'U.S. Supreme Court', 'Moore'}, Modified: {'U.S. Supreme Court', 'u.s. supreme court', 'Moore'}, Added: {'u.s. supreme court'}, Dropped: set()
# Original: {'U.S. Supreme Court', 'Moore'}, Modified: {'Supreme Court', 'Moore'}, Added: {'Supreme Court'}, Dropped: {'U.S. Supreme Court'}
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: {"Standard & Poor's 500 Index"}, Added: {"Standard & Poor's 500 Index"}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'Standard & Poor'}, Modified: {'Standard & Poor'}, Added: set(), Dropped: set()
# Original: {'Standard & Poor'}, Modified: {'Standard & Poor'}, Added: set(), Dropped: set()
# Original: {'Chris Butler'}, Modified: {'Chris Butler'}, Added: set(), Dropped: set()
# Original: {'Chris Butler'}, Modified: {'Chris Butler'}, Added: set(), Dropped: set()
# Original: {'NYPD cops', 'Louima', 'Nicholas'}, Modified: {'NYPD cops', 'Louima', 'Nicholas'}, Added: set(), Dropped: set()
# Original: {'NYPD cops', 'Louima', 'Nicholas'}, Modified: {'NYPD', 'Louima', 'Nicholas'}, Added: {'NYPD'}, Dropped: {'NYPD cops'}
# Original: set(), Modified: {'suppository position', 'baby', 'uterus'}, Added: {'uterus', 'baby', 'suppository position'}, Dropped: set()
# Original: set(), Modified: {'baby'}, Added: {'baby'}, Dropped: set()
# Original: {'he', 'big base camp', 'I'}, Modified: {'he', 'I'}, Added: set(), Dropped: {'big base camp'}
# Original: {'he', 'big base camp', 'I'}, Modified: {'he', 'I'}, Added: set(), Dropped: {'big base camp'}
# Original: {'Kelly', 'She', 'Nora Somers', 'Anthony', 'Linda Hope'}, Modified: {'Linda Hope', 'Kelly', 'Nora Somers', 'Anthony'}, Added: set(), Dropped: {'She'}
# Original: {'Kelly', 'She', 'Nora Somers', 'Anthony', 'Linda Hope'}, Modified: {'She', 'He', 'his wife', 'his four children', 'her husband'}, Added: {'his four children', 'He', 'his wife', 'her husband'}, Dropped: {'Linda Hope', 'Kelly', 'Nora Somers', 'Anthony'}
# Original: {'former Italian prime minister'}, Modified: {'former Italian prime minister', 'former Prime Minister', 'Italian government', 'Italy'}, Added: {'former Prime Minister', 'Italian government', 'Italy'}, Dropped: set()
# Original: {'former Italian prime minister'}, Modified: {'The former Italian prime minister'}, Added: {'The former Italian prime minister'}, Dropped: {'former Italian prime minister'}
# Original: {'British Foreign Office', 'men', 'coalition authorities'}, Modified: {'detainees', 'british officials in iraq', 'British Foreign Office', 'men', 'coalition authorities in Iraq', 'British foreign office'}, Added: {'detainees', 'british officials in iraq', 'coalition authorities in Iraq', 'British foreign office'}, Dropped: {'coalition authorities'}
# Original: {'British Foreign Office', 'men', 'coalition authorities'}, Modified: {'Iraqi prison', 'British Foreign Office', 'men', 'British government'}, Added: {'Iraqi prison', 'British government'}, Dropped: {'coalition authorities'}
# Original: {'agency'}, Modified: {'NASA'}, Added: {'NASA'}, Dropped: {'agency'}
# Original: {'agency'}, Modified: {'agency'}, Added: set(), Dropped: set()
# Original: {'ISRAELI soldiers'}, Modified: {'ISRAELI soldiers', 'Isaalel', 'army'}, Added: {'Isaalel', 'army'}, Dropped: set()
# Original: {'ISRAELI soldiers'}, Modified: {'ISRAELI soldiers', 'US-backed peace plan'}, Added: {'US-backed peace plan'}, Dropped: set()
# Original: {'lawyer'}, Modified: {'he', 'lawyer'}, Added: {'he'}, Dropped: set()
# Original: {'lawyer'}, Modified: {'lawyer'}, Added: set(), Dropped: set()
# Original: {'economists', 'labor markets'}, Modified: {'economists', 'labor markets'}, Added: set(), Dropped: set()
# Original: {'economists', 'labor markets'}, Modified: {'Labor Department', 'labor market'}, Added: {'Labor Department', 'labor market'}, Dropped: {'economists', 'labor markets'}
# Original: {'two', 'Another body'}, Modified: {'third'}, Added: {'third'}, Dropped: {'two', 'Another body'}
# Original: {'two', 'Another body'}, Modified: {'two more bodies', 'local media', 'Another body'}, Added: {'two more bodies', 'local media'}, Dropped: {'two'}
# Original: {'Prince Nayef', 'interior minister'}, Modified: {'Prince Nayef', 'interior minister', 'ministry'}, Added: {'ministry'}, Dropped: set()
# Original: {'Prince Nayef', 'interior minister'}, Modified: {'Prince Nayef', 'ministry'}, Added: {'ministry'}, Dropped: {'interior minister'}
# Original: {'key al-Qaida operatives', 'organization'}, Modified: {'key operatives', 'al-Qaida members'}, Added: {'key operatives', 'al-Qaida members'}, Dropped: {'organization', 'key al-Qaida operatives'}
# Original: {'key al-Qaida operatives', 'organization'}, Modified: {'al-Qaida members'}, Added: {'al-Qaida members'}, Dropped: {'organization', 'key al-Qaida operatives'}
# Original: set(), Modified: {'judge', 'judges'}, Added: {'judge', 'judges'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'academy', 'woman'}, Modified: {'academy', 'woman'}, Added: set(), Dropped: set()
# Original: {'academy', 'woman'}, Modified: {'she', 'academy', 'students', 'woman'}, Added: {'she', 'students'}, Dropped: set()
# Original: {'EMC', 'Legato'}, Modified: {'EMC', 'Legato'}, Added: set(), Dropped: set()
# Original: {'EMC', 'Legato'}, Modified: {'EMC', 'Legatto', 'Legato'}, Added: {'Legatto'}, Dropped: set()
# Original: {'Greg Stuart', 'bureau'}, Modified: {'Greg Stuart', 'bureau'}, Added: set(), Dropped: set()
# Original: {'Greg Stuart', 'bureau'}, Modified: {'Greg Stuart', 'bureau'}, Added: set(), Dropped: set()
# Original: {'Kingston'}, Modified: {'Kingston'}, Added: set(), Dropped: set()
# Original: {'Kingston'}, Modified: {"Kingston's 67"}, Added: {"Kingston's 67"}, Dropped: {'Kingston'}
# Original: set(), Modified: {'he', 'younger boys', 'older boys', 'two of them'}, Added: {'he', 'younger boys', 'older boys', 'two of them'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'Thomas Ezzell', 'Kentucky newspaper', 'Ms Lafferty'}, Modified: {'Thomas Ezzell', 'Kentucky newspaper', 'Ms Lafferty'}, Added: set(), Dropped: set()
# Original: {'Thomas Ezzell', 'Kentucky newspaper', 'Ms Lafferty'}, Modified: {'Thomas Ezzell', 'Kentucky newspaper', 'Ms Lafferty'}, Added: set(), Dropped: set()
# Original: {'Canadian operations', 'Canadian Food Inspection Agency'}, Modified: {'Canadian beef processing facilities', 'Canadian operations', 'Canadian Food Inspection Agency'}, Added: {'Canadian beef processing facilities'}, Dropped: set()
# Original: {'Canadian operations', 'Canadian Food Inspection Agency'}, Modified: {'Canadian Food Inspection Agency (CFIA)', 'Canadian operations'}, Added: {'Canadian Food Inspection Agency (CFIA)'}, Dropped: {'Canadian Food Inspection Agency'}
# Original: {'U.S. Department of Agriculture', 'Agriculture ministers'}, Modified: {'U.S. Department of Agriculture', 'Agriculture ministers'}, Added: set(), Dropped: set()
# Original: {'U.S. Department of Agriculture', 'Agriculture ministers'}, Modified: {'U.S. Department of Agriculture (USDA)'}, Added: {'U.S. Department of Agriculture (USDA)'}, Dropped: {'U.S. Department of Agriculture', 'Agriculture ministers'}
# Original: {'Uruguayan UN peacekeepers', 'Mr Eckhard'}, Modified: {'he', 'UN peacekeepers'}, Added: {'he', 'UN peacekeepers'}, Dropped: {'Uruguayan UN peacekeepers', 'Mr Eckhard'}
# Original: {'Uruguayan UN peacekeepers', 'Mr Eckhard'}, Modified: {'UN peacekeepers', 'Eckhard'}, Added: {'UN peacekeepers', 'Eckhard'}, Dropped: {'Uruguayan UN peacekeepers', 'Mr Eckhard'}
# Original: {'New York Stock Exchange', 'Coke'}, Modified: {'New York Stock Exchange', 'Coca-cola', 'Coca-Cola', 'Coke'}, Added: {'Coca-Cola', 'Coca-cola'}, Dropped: set()
# Original: {'New York Stock Exchange', 'Coke'}, Modified: {'New York Stock Exchange', 'The Wall Street Journal', 'Coke'}, Added: {'The Wall Street Journal'}, Dropped: set()
# Original: {'Iraqi doctors', 'NASIRIYA , Iraq', 'Jessica Lynch'}, Modified: {'Jessica l Lynch', 'NASIRIYA, Iraq', 'Iraqi doctors', 'Jessica Lynch'}, Added: {'NASIRIYA, Iraq', 'Jessica l Lynch'}, Dropped: {'NASIRIYA , Iraq'}
# Original: {'Iraqi doctors', 'NASIRIYA , Iraq', 'Jessica Lynch'}, Modified: {'NASIRIYA, Iraq', 'Iraqi doctors', 'Jessica Lynch'}, Added: {'NASIRIYA, Iraq'}, Dropped: {'NASIRIYA , Iraq'}
# Original: {'stroke', 'people', 'scientists', 'heart attack', 'pill'}, Modified: {'stroke', 'people', 'scientists', 'heart attack', 'pill'}, Added: set(), Dropped: set()
# Original: {'stroke', 'people', 'scientists', 'heart attack', 'pill'}, Modified: {'heart disease', 'stroke', 'pill', 'Circulation Research'}, Added: {'heart disease', 'Circulation Research'}, Dropped: {'heart attack', 'people', 'scientists'}
# Original: {'Nasdaq', 'Amgen'}, Modified: {'Nasdaq', 'Amgen'}, Added: set(), Dropped: set()
# Original: {'Nasdaq', 'Amgen'}, Modified: {'Nasdaq', 'Amgen'}, Added: set(), Dropped: set()
# Original: {'United States', 'Saddam'}, Modified: {'the u.s.', 'Saddam'}, Added: {'the u.s.'}, Dropped: {'United States'}
# Original: {'United States', 'Saddam'}, Modified: {'government', 'United States', 'Saddam Hussein'}, Added: {'government', 'Saddam Hussein'}, Dropped: {'Saddam'}
# Original: {'SMS 2003', 'Customers'}, Modified: {'sms 2003', 'SMS 2003', 'Customers'}, Added: {'sms 2003'}, Dropped: set()
# Original: {'SMS 2003', 'Customers'}, Modified: {'Customers'}, Added: set(), Dropped: {'SMS 2003'}
# Original: set(), Modified: {'october 1'}, Added: {'october 1'}, Dropped: set()
# Original: set(), Modified: {'Dow Jones'}, Added: {'Dow Jones'}, Dropped: set()
# Original: {'she', 'Americans'}, Modified: {'he', 'she', 'Americans'}, Added: {'he'}, Dropped: set()
# Original: {'she', 'Americans'}, Modified: {'We', 'she', 'U.S.'}, Added: {'We', 'U.S.'}, Dropped: {'Americans'}
# Original: set(), Modified: {'MSN Messenger'}, Added: {'MSN Messenger'}, Dropped: set()
# Original: set(), Modified: {'Microsoft.com'}, Added: {'Microsoft.com'}, Dropped: set()
# Original: {'lieutenant governor', 'state', 'Shelley'}, Modified: {'elected gubernatorial candidate', 'lieutenant governor', 'Shelley'}, Added: {'elected gubernatorial candidate'}, Dropped: {'state'}
# Original: {'lieutenant governor', 'state', 'Shelley'}, Modified: {'lieutenant governor', 'Shelley'}, Added: set(), Dropped: {'state'}
# Original: {'Michael Fagan', 'Buckingham Palace'}, Modified: {'Buckingham Palace', 'intruder'}, Added: {'intruder'}, Dropped: {'Michael Fagan'}
# Original: {'Michael Fagan', 'Buckingham Palace'}, Modified: {'Michael Fagan'}, Added: set(), Dropped: {'Buckingham Palace'}
# Original: {'LendingTree'}, Modified: {'LendingTree', 'lendingtree'}, Added: {'lendingtree'}, Dropped: set()
# Original: {'LendingTree'}, Modified: {'LendingTree'}, Added: set(), Dropped: set()
# Original: {'Bergin', 'Carolyn', 'John'}, Modified: {'Bergin', 'Carolyn', 'John'}, Added: set(), Dropped: set()
# Original: {'Bergin', 'Carolyn', 'John'}, Modified: {'Bergin', 'Carolyn', 'John'}, Added: set(), Dropped: set()
# Original: {'FAA'}, Modified: {'FAA'}, Added: set(), Dropped: set()
# Original: {'FAA'}, Modified: {'FAA'}, Added: set(), Dropped: set()
# Original: {'network'}, Modified: {'Dateline', 'network', 'Nightly News', 'tv network'}, Added: {'Dateline', 'Nightly News', 'tv network'}, Dropped: set()
# Original: {'network'}, Modified: {'network'}, Added: set(), Dropped: set()
# Original: {'James'}, Modified: {'Cleveland Cavaliers', 'James'}, Added: {'Cleveland Cavaliers'}, Dropped: set()
# Original: {'James'}, Modified: {'Cavalier', 'Cavs', 'James'}, Added: {'Cavalier', 'Cavs'}, Dropped: set()
# Original: {'Russ Britt', 'CBS.MarketWatch.com'}, Modified: {'Russ Britt', 'CBS News. MarketWatch', 'CBS.MarketWatch.com'}, Added: {'CBS News. MarketWatch'}, Dropped: set()
# Original: {'Russ Britt', 'CBS.MarketWatch.com'}, Modified: {'Russ Britt', 'CBS', 'CBS.MarketWatch.com'}, Added: {'CBS'}, Dropped: set()
# Original: {'Goldman Sachs GS.N', 'Rabobank [ RABN.UL ]', 'ABN AMRO AAH.AS', 'ING ING.AS'}, Modified: {'Goldman Sachs GS.N', 'ABN AMRO ING.AS', 'Rabobank [ RABN.UL ]'}, Added: {'ABN AMRO ING.AS'}, Dropped: {'ABN AMRO AAH.AS', 'ING ING.AS'}
# Original: {'Goldman Sachs GS.N', 'Rabobank [ RABN.UL ]', 'ABN AMRO AAH.AS', 'ING ING.AS'}, Modified: {'Goldman Sachs GS.N', 'ING', 'ABN AMRO AAH.AS', 'Rabobank [ RABN.UL ]'}, Added: {'ING'}, Dropped: {'ING ING.AS'}
# Original: {'July 2002', 'WorldCom'}, Modified: {'july 2002', 'WorldCom'}, Added: {'july 2002'}, Dropped: {'July 2002'}
# Original: {'July 2002', 'WorldCom'}, Modified: {'July 2002', 'WorldCom'}, Added: set(), Dropped: set()
# Original: {'Raffles Hospital'}, Modified: {'monday', 'Raffles Hospital', 'they'}, Added: {'monday', 'they'}, Dropped: set()
# Original: {'Raffles Hospital'}, Modified: {'Raffles Hospital'}, Added: set(), Dropped: set()
# Original: {'Rich media'}, Modified: {'rich media', 'Rich media'}, Added: {'rich media'}, Dropped: set()
# Original: {'Rich media'}, Modified: {'Rich media'}, Added: set(), Dropped: set()
# Original: {'She', 'tired and unwell'}, Modified: {'specialist', 'she', 'She'}, Added: {'specialist', 'she'}, Dropped: {'tired and unwell'}
# Original: {'She', 'tired and unwell'}, Modified: {'she', 'tests were negative', 'She', 'feeling tired and unwell', 'doctor'}, Added: {'she', 'tests were negative', 'doctor', 'feeling tired and unwell'}, Dropped: {'tired and unwell'}
# Original: {'Supermarket chains', 'union leaders'}, Modified: {'Supermarket chains', 'Supermarket chain'}, Added: {'Supermarket chain'}, Dropped: {'union leaders'}
# Original: {'Supermarket chains', 'union leaders'}, Modified: {'unions', 'supermarket chains'}, Added: {'unions', 'supermarket chains'}, Dropped: {'Supermarket chains', 'union leaders'}
# Original: {'MGM', 'Liberty', 'NBC'}, Modified: {'MGM', 'Liberty', 'NBC'}, Added: set(), Dropped: set()
# Original: {'MGM', 'Liberty', 'NBC'}, Modified: {'MGM', 'Liberty', 'NBC'}, Added: set(), Dropped: set()
# Original: {'New York Stock Exchange'}, Modified: {'New York Stock Exchange'}, Added: set(), Dropped: set()
# Original: {'New York Stock Exchange'}, Modified: {'New York Stock Exchange'}, Added: set(), Dropped: set()
# Original: {'firm', 'Don Asper', 'Web site provider'}, Modified: {'firm', 'Don Asper', 'Web site provider'}, Added: set(), Dropped: set()
# Original: {'firm', 'Don Asper', 'Web site provider'}, Modified: {'firm', 'Don Asper', 'Web site provider'}, Added: set(), Dropped: set()
# Original: {'Hilsenrath', 'Klarman'}, Modified: {'Hilsenrath', 'Klarman'}, Added: set(), Dropped: set()
# Original: {'Hilsenrath', 'Klarman'}, Modified: {'Hilsenrath', 'Klarman'}, Added: set(), Dropped: set()
# Original: {'York', 'MTA'}, Modified: {'York', 'MTA', 'mta'}, Added: {'mta'}, Dropped: set()
# Original: {'York', 'MTA'}, Modified: {'York', 'MTA'}, Added: set(), Dropped: set()
# Original: set(), Modified: {'company'}, Added: {'company'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'Cheney', 'Barbour', 'Republican National Committee'}, Modified: {'Cheney', 'Barbour', 'rnc', 'Republican National Committee'}, Added: {'rnc'}, Dropped: set()
# Original: {'Cheney', 'Barbour', 'Republican National Committee'}, Modified: {'Cheney', 'White House', 'Barbour', 'Republican National Committee'}, Added: {'White House'}, Dropped: set()
# Original: {'magazine', "O 'Donnell"}, Modified: {'magazine', "O 'Donnell"}, Added: set(), Dropped: set()
# Original: {'magazine', "O 'Donnell"}, Modified: {'magazine', "O 'Donnell"}, Added: set(), Dropped: set()
# Original: set(), Modified: {'analysts', 'investors'}, Added: {'analysts', 'investors'}, Dropped: set()
# Original: set(), Modified: {'company', 'investors'}, Added: {'company', 'investors'}, Dropped: set()
# Original: {'Rocca', 'terrorist organisation', 'rebels'}, Modified: {'Rocca', 'terrorist organisation', 'rebels'}, Added: set(), Dropped: set()
# Original: {'Rocca', 'terrorist organisation', 'rebels'}, Modified: {'United States', 'Rocca', 'terrorist organization', 'rebels'}, Added: {'United States', 'terrorist organization'}, Dropped: {'terrorist organisation'}
# Original: {'federal Centers for Disease Control and Prevention'}, Modified: {'Centers for Disease Control and Prevention'}, Added: {'Centers for Disease Control and Prevention'}, Dropped: {'federal Centers for Disease Control and Prevention'}
# Original: {'federal Centers for Disease Control and Prevention'}, Modified: set(), Added: set(), Dropped: {'federal Centers for Disease Control and Prevention'}
# Original: set(), Modified: {'dow jones'}, Added: {'dow jones'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'Navy', 'two-term president'}, Modified: {'Navy', 'two-term president'}, Added: set(), Dropped: set()
# Original: {'Navy', 'two-term president'}, Modified: {'Navy', 'president'}, Added: {'president'}, Dropped: {'two-term president'}
# Original: {'We', 'we'}, Modified: {'We', 'we'}, Added: set(), Dropped: set()
# Original: {'We', 'we'}, Modified: {'pilot program', 'we'}, Added: {'pilot program'}, Dropped: {'We'}
# Original: {'lawmakers'}, Modified: {'spokesman', 'U.S. House of Representatives'}, Added: {'spokesman', 'U.S. House of Representatives'}, Dropped: {'lawmakers'}
# Original: {'lawmakers'}, Modified: {'legislature'}, Added: {'legislature'}, Dropped: {'lawmakers'}
# Original: {'Mr. Reed', 'our plans'}, Modified: {'Mr. Reed', 'We'}, Added: {'We'}, Dropped: {'our plans'}
# Original: {'Mr. Reed', 'our plans'}, Modified: {'White House', 'Pentagon', 'Reed'}, Added: {'White House', 'Pentagon', 'Reed'}, Dropped: {'Mr. Reed', 'our plans'}
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: {'Dow Jones Industrial Average', "Standard & Poor's 500 index"}, Added: {'Dow Jones Industrial Average', "Standard & Poor's 500 index"}, Dropped: set()
# Original: {'Supervisor', 'Best Minister', 'Scrimshaw', 'Ten Most Wanted'}, Modified: {'Best Minister'}, Added: set(), Dropped: {'Supervisor', 'Scrimshaw', 'Ten Most Wanted'}
# Original: {'Supervisor', 'Best Minister', 'Scrimshaw', 'Ten Most Wanted'}, Modified: {'Ten Most Wanted', 'Scrimshaw', 'Best Minister', 'Supervisor', 'Belmont field'}, Added: {'Belmont field'}, Dropped: set()
# Original: {'prisoner', 'Judge Gerald W. Heaney', 'authorities', 'medicated'}, Modified: {'Judge Gerald W. Heaney', 'ill', 'medicated', 'prisoner', 'patient', 'authorities'}, Added: {'ill', 'patient'}, Dropped: set()
# Original: {'prisoner', 'Judge Gerald W. Heaney', 'authorities', 'medicated'}, Modified: {'government', 'Judge Gerald W. Heaney', 'prisoner'}, Added: {'government'}, Dropped: {'authorities', 'medicated'}
# Original: {'Thomson First Call'}, Modified: {'Thomson First Call'}, Added: set(), Dropped: set()
# Original: {'Thomson First Call'}, Modified: {'Thomson First Call'}, Added: set(), Dropped: set()
# Original: {'IBMs'}, Modified: {'IBM', 'IBMs'}, Added: {'IBM'}, Dropped: set()
# Original: {'IBMs'}, Modified: {'IBMs'}, Added: set(), Dropped: set()
# Original: {'long-awaited sample-return flight', 'NASA'}, Modified: {'long-awaited sample-return flight', 'NASA'}, Added: set(), Dropped: set()
# Original: {'long-awaited sample-return flight', 'NASA'}, Modified: {'long-awaited sample-return flight', 'NASA'}, Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: {"Standard & Poor's 500 Index"}, Added: {"Standard & Poor's 500 Index"}, Dropped: set()
# Original: {'Mohammed Mohsen al-Zubaidi', 'Garner', 'coalition'}, Modified: {'Mohammed Mohsen al-Zubaidi', 'Garner', 'coalition'}, Added: set(), Dropped: set()
# Original: {'Mohammed Mohsen al-Zubaidi', 'Garner', 'coalition'}, Modified: {'Mohammed Mohsen al-Zubaidi', 'Garner', 'coalition'}, Added: set(), Dropped: set()
# Original: {'Nov. 7', 'Microsoft'}, Modified: {'shareholders of record', 'microsoft', 'Nov. 7', 'Microsoft'}, Added: {'shareholders of record', 'microsoft'}, Dropped: set()
# Original: {'Nov. 7', 'Microsoft'}, Modified: {'Microsoft'}, Added: set(), Dropped: {'Nov. 7'}
# Original: {'She', 'Cabinet'}, Modified: {'Cabinet', 'she'}, Added: {'she'}, Dropped: {'She'}
# Original: {'She', 'Cabinet'}, Modified: {'She', 'she'}, Added: {'she'}, Dropped: {'Cabinet'}
# Original: {'Democrat', 'Dean'}, Modified: {'Dean'}, Added: set(), Dropped: {'Democrat'}
# Original: {'Democrat', 'Dean'}, Modified: {'Democrat', 'Dean'}, Added: set(), Dropped: set()
# Original: {'jury', 'Quattrone'}, Modified: {'jury', 'Quattrone'}, Added: set(), Dropped: set()
# Original: {'jury', 'Quattrone'}, Modified: {'jury', 'Quattrone'}, Added: set(), Dropped: set()
# Original: {'I'}, Modified: {'Iraqi government', 'I'}, Added: {'Iraqi government'}, Dropped: set()
# Original: {'I'}, Modified: {'I'}, Added: set(), Dropped: set()
# Original: {'Albertsons', "Kroger 's Ralphs"}, Modified: {"Albertson' s and k rgers' chain", "Albertsons and Kroger's Ralphs chain"}, Added: {"Albertson' s and k rgers' chain", "Albertsons and Kroger's Ralphs chain"}, Dropped: {'Albertsons', "Kroger 's Ralphs"}
# Original: {'Albertsons', "Kroger 's Ralphs"}, Modified: {'Albertsons', "Kroger's Ralphs"}, Added: {"Kroger's Ralphs"}, Dropped: {"Kroger 's Ralphs"}
# Original: {'he'}, Modified: {'He', 'he', 'bone in the back of his left leg', 'right wrist', 'bones'}, Added: {'right wrist', 'bone in the back of his left leg', 'He', 'bones'}, Dropped: set()
# Original: {'he'}, Modified: {'broken bones in his wrist and elbow', 'The man', 'broken his right leg', 'broken elbow'}, Added: {'broken bones in his wrist and elbow', 'The man', 'broken his right leg', 'broken elbow'}, Dropped: {'he'}
# Original: {'Court Judge Robert Sweet', "McDonald 's"}, Modified: {"McDonald's", 'Judge Robert Sweet'}, Added: {'Judge Robert Sweet', "McDonald's"}, Dropped: {'Court Judge Robert Sweet', "McDonald 's"}
# Original: {'Court Judge Robert Sweet', "McDonald 's"}, Modified: {"McDonald's", "McDonald' s", 'Judge Robert Sweet'}, Added: {"McDonald' s", 'Judge Robert Sweet', "McDonald's"}, Dropped: {'Court Judge Robert Sweet', "McDonald 's"}
# Original: {'neighbor', 'woman'}, Modified: {'woman', 'A neighbor'}, Added: {'A neighbor'}, Dropped: {'neighbor'}
# Original: {'neighbor', 'woman'}, Modified: {'she', 'woman', 'A neighbor'}, Added: {'she', 'A neighbor'}, Dropped: {'neighbor'}
# Original: {'Pennsylvania'}, Modified: {'U.S. District Court for the Eastern District of Pennsylvania'}, Added: {'U.S. District Court for the Eastern District of Pennsylvania'}, Dropped: {'Pennsylvania'}
# Original: {'Pennsylvania'}, Modified: {'Pennsylvania'}, Added: set(), Dropped: set()
# Original: {'Southwest', '737s'}, Modified: {'Southwest', '737s'}, Added: set(), Dropped: set()
# Original: {'Southwest', '737s'}, Modified: {'Southwest'}, Added: set(), Dropped: {'737s'}
# Original: {'Intel Corp.'}, Modified: {'Intel Corp.', 'communications chip business', 'Intel'}, Added: {'communications chip business', 'Intel'}, Dropped: set()
# Original: {'Intel Corp.'}, Modified: {'Intel Corp.'}, Added: set(), Dropped: set()
# Original: {'South Korean Agriculture and Forestry Ministry'}, Modified: {'South Korean Ministry of Agriculture and Forestry', 's. korean ministry of agricultur,forestry, and forestry'}, Added: {'South Korean Ministry of Agriculture and Forestry', 's. korean ministry of agricultur,forestry, and forestry'}, Dropped: {'South Korean Agriculture and Forestry Ministry'}
# Original: {'South Korean Agriculture and Forestry Ministry'}, Modified: {'South Korean Ministry of Agriculture and Forestry'}, Added: {'South Korean Ministry of Agriculture and Forestry'}, Dropped: {'South Korean Agriculture and Forestry Ministry'}
# Original: {'Burke'}, Modified: {'Burke'}, Added: set(), Dropped: set()
# Original: {'Burke'}, Modified: {'Burke'}, Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'Domino'}, Modified: {'Domino'}, Added: set(), Dropped: set()
# Original: {'Domino'}, Modified: {'Domino'}, Added: set(), Dropped: set()
# Original: {'Nasdaq Composite Index .IXIC'}, Modified: {'1,492', 'Nasdaq Composite Index', 'nasdq composite index', 'S&P 500 Index', '2,448', '3,048'}, Added: {'Nasdaq Composite Index', '1,492', 'nasdq composite index', 'S&P 500 Index', '2,448', '3,048'}, Dropped: {'Nasdaq Composite Index .IXIC'}
# Original: {'Nasdaq Composite Index .IXIC'}, Modified: {'Nasdaq Composite Index.IXIC'}, Added: {'Nasdaq Composite Index.IXIC'}, Dropped: {'Nasdaq Composite Index .IXIC'}
# Original: {'SCO'}, Modified: {'spokesman', 'SCO', 'company', 'Sequent representatives'}, Added: {'spokesman', 'company', 'Sequent representatives'}, Dropped: set()
# Original: {'SCO'}, Modified: {'SCO'}, Added: set(), Dropped: set()
# Original: {'Bill Curry', 'CCAG', 'Rowland'}, Modified: {'Bill Curry', 'ccga', 'CCAG', 'Rowland'}, Added: {'ccga'}, Dropped: set()
# Original: {'Bill Curry', 'CCAG', 'Rowland'}, Modified: {'Bill Curry', 'CCAG', 'Rowland'}, Added: set(), Dropped: set()
# Original: {'Science'}, Modified: {'Universite de Buenos Aires', 'Instituto de Ciencia y Tecnologa de las Naciones Unidas', 'University of California, San Diego'}, Added: {'Universite de Buenos Aires', 'Instituto de Ciencia y Tecnologa de las Naciones Unidas', 'University of California, San Diego'}, Dropped: {'Science'}
# Original: {'Science'}, Modified: {'Science'}, Added: set(), Dropped: set()
# Original: {'Pierre Pettigrew', 'panel'}, Modified: {'Pierre Pettigrew', 'panel'}, Added: set(), Dropped: set()
# Original: {'Pierre Pettigrew', 'panel'}, Modified: {'Pierre Pettigrew', 'panel'}, Added: set(), Dropped: set()
# Original: {'Saddam Hussein', 'Kay', 'US intelligence'}, Modified: {'Saddam Hussein', 'CIA', 'Kay', 'US intelligence'}, Added: {'CIA'}, Dropped: set()
# Original: {'Saddam Hussein', 'Kay', 'US intelligence'}, Modified: {'US military', 'Kay', 'US intelligence agencies'}, Added: {'US military', 'US intelligence agencies'}, Dropped: {'Saddam Hussein', 'US intelligence'}
# Original: {'Tom Daschle'}, Modified: {'Tom Daschle'}, Added: set(), Dropped: set()
# Original: {'Tom Daschle'}, Modified: {'senate Democratic', 'Sen. Tom Daschle'}, Added: {'senate Democratic', 'Sen. Tom Daschle'}, Dropped: {'Tom Daschle'}
# Original: {'Sept . 11 , 2001', 'Monday'}, Modified: {'Sept. 11, 2001'}, Added: {'Sept. 11, 2001'}, Dropped: {'Sept . 11 , 2001', 'Monday'}
# Original: {'Sept . 11 , 2001', 'Monday'}, Modified: {'Sept. 11, 2001'}, Added: {'Sept. 11, 2001'}, Dropped: {'Sept . 11 , 2001', 'Monday'}
# Original: {'Mr Mugabe', 'MDC'}, Modified: {'government', 'Mugabe', 'Mr Mugabe', 'MDC'}, Added: {'government', 'Mugabe'}, Dropped: set()
# Original: {'Mr Mugabe', 'MDC'}, Modified: {'opposition', 'Mugabe', 'MDC'}, Added: {'opposition', 'Mugabe'}, Dropped: {'Mr Mugabe'}
# Original: {'police presence', 'school officials', 'Police'}, Modified: {'nypd', 'police', 'spokesman', '610', 'school district'}, Added: {'nypd', 'police', 'spokesman', '610', 'school district'}, Dropped: {'police presence', 'school officials', 'Police'}
# Original: {'police presence', 'school officials', 'Police'}, Modified: {'police', 'school officials', 'school district', 'Police'}, Added: {'police', 'school district'}, Dropped: {'police presence'}
# Original: {'Mr. Beer', 'child porn ring'}, Modified: {'Mr. Beer', 'child porn ring'}, Added: set(), Dropped: set()
# Original: {'Mr. Beer', 'child porn ring'}, Modified: {'Mr. Beer', 'child pornography ring'}, Added: {'child pornography ring'}, Dropped: {'child porn ring'}
# Original: {'Arnold Schwarzenegger', 'Richard Riordan'}, Modified: {'Schwarzenegger', 'Richard Riordan'}, Added: {'Schwarzenegger'}, Dropped: {'Arnold Schwarzenegger'}
# Original: {'Arnold Schwarzenegger', 'Richard Riordan'}, Modified: {'Arnold Schwarzenegger', 'Richard Riordan'}, Added: set(), Dropped: set()
# Original: {'Wagerup'}, Modified: {'Wagerup'}, Added: set(), Dropped: set()
# Original: {'Wagerup'}, Modified: {'local residents', 'Wagerup'}, Added: {'local residents'}, Dropped: set()
# Original: {'PeopleSoft', 'poison pill'}, Modified: {'PeopleSoft', 'poison pill', 'unseen suitors'}, Added: {'unseen suitors'}, Dropped: set()
# Original: {'PeopleSoft', 'poison pill'}, Modified: {'PeopleSoft', 'poison pill'}, Added: set(), Dropped: set()
# Original: {'I'}, Modified: {'I'}, Added: set(), Dropped: set()
# Original: {'I'}, Modified: {'I'}, Added: set(), Dropped: set()
# Original: {'Michigan-based development company', 'state Senate'}, Modified: {'-based development company', "Michigan's senate"}, Added: {'-based development company', "Michigan's senate"}, Dropped: {'Michigan-based development company', 'state Senate'}
# Original: {'Michigan-based development company', 'state Senate'}, Modified: {'Michigan-based development company', 'Legislature', 'Michigan Senate'}, Added: {'Legislature', 'Michigan Senate'}, Dropped: {'state Senate'}
# Original: {'New York Mets', 'Lastings Milledge'}, Modified: {'new york mets', 'Corey Kluber', 'Miami Marlins', 'New York Mets', 'Lastings Milledge', 'New york mts', 'Lakewood Ranch High School'}, Added: {'new york mets', 'Corey Kluber', 'Miami Marlins', 'New york mts', 'Lakewood Ranch High School'}, Dropped: set()
# Original: {'New York Mets', 'Lastings Milledge'}, Modified: {'Lakewood Ranch High School', 'Lastings Milledge', 'Mets'}, Added: {'Lakewood Ranch High School', 'Mets'}, Dropped: {'New York Mets'}
# Original: {'Lancet'}, Modified: {'Lancet'}, Added: set(), Dropped: set()
# Original: {'Lancet'}, Modified: {'Lancet'}, Added: set(), Dropped: set()
# Original: {'Washington-Baltimore Newspaper Guild', 'Michael Hill', 'Sun'}, Modified: {'Washington-Baltimore Newspaper Guild', 'Hill'}, Added: {'Hill'}, Dropped: {'Michael Hill', 'Sun'}
# Original: {'Washington-Baltimore Newspaper Guild', 'Michael Hill', 'Sun'}, Modified: {'Washington-Baltimore Newspaper Guild', 'Sun reporter'}, Added: {'Sun reporter'}, Dropped: {'Michael Hill', 'Sun'}
# Original: {'Coca-Cola'}, Modified: {'Coca-Cola'}, Added: set(), Dropped: set()
# Original: {'Coca-Cola'}, Modified: {'Coca-Cola'}, Added: set(), Dropped: set()
# Original: {'Defense Department', 'Hamdi'}, Modified: {'Defense Department', 'Hamdi'}, Added: set(), Dropped: set()
# Original: {'Defense Department', 'Hamdi'}, Modified: {'Defense Department', 'Hamdi', 'U. S. government'}, Added: {'U. S. government'}, Dropped: set()
# Original: {'Clijsters', 'Conchita Martínez'}, Modified: {'Clijsters', 'Conchita Martnez'}, Added: {'Conchita Martnez'}, Dropped: {'Conchita Martínez'}
# Original: {'Clijsters', 'Conchita Martínez'}, Modified: {'Clijsters', 'Conchita Martnez'}, Added: {'Conchita Martnez'}, Dropped: {'Conchita Martínez'}
# Original: {'dispatcher Ace Mealer', 'Cpl. James Crump', 'City Councilman Cedric Wilson', 'Officer Arnold Strickland'}, Modified: {'dispatcher Ace Mealer', 'Cpl. James Crump', 'Officer Arnold Strickland', 'Cedric Wilson'}, Added: {'Cedric Wilson'}, Dropped: {'City Councilman Cedric Wilson'}
# Original: {'dispatcher Ace Mealer', 'Cpl. James Crump', 'City Councilman Cedric Wilson', 'Officer Arnold Strickland'}, Modified: {'dispatcher Ace Mealer', 'Cpl. James Crump', 'City Councilman Cedric Wilson', 'Officer Arnold Strickland'}, Added: set(), Dropped: set()
# Original: set(), Modified: {'1981', 'Ronald Reagan'}, Added: {'1981', 'Ronald Reagan'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'he', 'British press'}, Modified: {'he', 'Home Office', 'British press', 'british government'}, Added: {'Home Office', 'british government'}, Dropped: set()
# Original: {'he', 'British press'}, Modified: {'he', 'BBC', 'British media'}, Added: {'BBC', 'British media'}, Dropped: {'British press'}
# Original: {'Lay'}, Modified: {'government', 'Lay', 'prosecutors'}, Added: {'government', 'prosecutors'}, Dropped: set()
# Original: {'Lay'}, Modified: {'Lay'}, Added: set(), Dropped: set()
# Original: {'I'}, Modified: {'I'}, Added: set(), Dropped: set()
# Original: {'I'}, Modified: {'I'}, Added: set(), Dropped: set()
# Original: {'president', 'Walker', 'NASA'}, Modified: {'president', 'Walker', 'NASA'}, Added: set(), Dropped: set()
# Original: {'president', 'Walker', 'NASA'}, Modified: {'president', 'Walker', 'NASA'}, Added: set(), Dropped: set()
# Original: {'BA'}, Modified: {'BA'}, Added: set(), Dropped: set()
# Original: {'BA'}, Modified: {'BA'}, Added: set(), Dropped: set()
# Original: {'Amnesty International'}, Modified: {'Amnesty International'}, Added: set(), Dropped: set()
# Original: {'Amnesty International'}, Modified: {'Amnesty International'}, Added: set(), Dropped: set()
# Original: {'Both'}, Modified: {'i', 'I', 'Both'}, Added: {'i', 'I'}, Dropped: set()
# Original: {'Both'}, Modified: {'Both'}, Added: set(), Dropped: set()
# Original: {'She', 'critically ill'}, Modified: {'she', 'She', 'hospital', 'critical condition', 'critically ill', 'heart valve'}, Added: {'hospital', 'critical condition', 'she', 'heart valve'}, Dropped: set()
# Original: {'She', 'critically ill'}, Modified: {'She', 'critical condition', 'her'}, Added: {'critical condition', 'her'}, Dropped: {'critically ill'}
# Original: {'BlueCore3-Multimedia'}, Modified: {'BlueCore3-Multimedia'}, Added: set(), Dropped: set()
# Original: {'BlueCore3-Multimedia'}, Modified: {'BlueCore3-Multimedia'}, Added: set(), Dropped: set()
# Original: {'police', 'Cruz', 'Braker'}, Modified: {'police', 'Cruz', 'Braker'}, Added: set(), Dropped: set()
# Original: {'police', 'Cruz', 'Braker'}, Modified: {'police', 'Cruz', 'Braker'}, Added: set(), Dropped: set()
# Original: {'state', 'police memorial', 'Gov. James E. McGreevey', 'World Trade Center Memorial', 'Micah Rasmussen'}, Modified: {'World Trade Center Memorial', 'Gov. James E. McGreey', 'state', 'police memorial'}, Added: {'Gov. James E. McGreey'}, Dropped: {'Gov. James E. McGreevey', 'Micah Rasmussen'}
# Original: {'state', 'police memorial', 'Gov. James E. McGreevey', 'World Trade Center Memorial', 'Micah Rasmussen'}, Modified: {'World Trade Center Memorial', 'police memorial', 'state', 'Micah Rasmussen'}, Added: set(), Dropped: {'Gov. James E. McGreevey'}
# Original: {'Stewart'}, Modified: {'Stewart'}, Added: set(), Dropped: set()
# Original: {'Stewart'}, Modified: {'ring', 'Stewart'}, Added: {'ring'}, Dropped: set()
# Original: {'Commission', 'Microsoft'}, Modified: {'Commission', 'Microsoft'}, Added: set(), Dropped: set()
# Original: {'Commission', 'Microsoft'}, Modified: {'Commission', 'Microsoft'}, Added: set(), Dropped: set()
# Original: {'State Court of Appeals'}, Modified: {'state court of appeals', 'State Court of Appeals'}, Added: {'state court of appeals'}, Dropped: set()
# Original: {'State Court of Appeals'}, Modified: {'state Court of Appeals'}, Added: {'state Court of Appeals'}, Dropped: {'State Court of Appeals'}
# Original: {"Standard & Poor 's 500 index"}, Modified: {'S&P 500 index'}, Added: {'S&P 500 index'}, Dropped: {"Standard & Poor 's 500 index"}
# Original: {"Standard & Poor 's 500 index"}, Modified: {'Standard & Poor 500'}, Added: {'Standard & Poor 500'}, Dropped: {"Standard & Poor 's 500 index"}
# Original: {'Powell', 'Hoffa'}, Modified: {'police', 'mr h offa', 'Powell', 'Hoffa'}, Added: {'police', 'mr h offa'}, Dropped: set()
# Original: {'Powell', 'Hoffa'}, Modified: {'former home', 'suspect', 'Powell', 'Hoffa'}, Added: {'suspect', 'former home'}, Dropped: set()
# Original: {'Federal Trade Commission', 'Another'}, Modified: {'Federal Trade Commission', 'ftc', 'Another'}, Added: {'ftc'}, Dropped: set()
# Original: {'Federal Trade Commission', 'Another'}, Modified: {'Federal Trade Commission', 'Another'}, Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'SCO'}, Modified: {'SCO', 'scotch.com'}, Added: {'scotch.com'}, Dropped: set()
# Original: {'SCO'}, Modified: {'SCO'}, Added: set(), Dropped: set()
# ...
# Original: {'New York Stock Exchange', 'National City'}, Modified: {'New York Stock Exchange', 'National City'}, Added: set(), Dropped: set()
# Original: {'FCC', 'Entrenched interests'}, Modified: {'FCC', 'Entrenched interests'}, Added: set(), Dropped: set()
# Original: {'FCC', 'Entrenched interests'}, Modified: {'FCC'}, Added: set(), Dropped: {'Entrenched interests'}
# Original: {'Methodist Church of Fiji'}, Modified: {'Methodist Church of Fiji'}, Added: set(), Dropped: set()
# Original: {'Methodist Church of Fiji'}, Modified: {'Methodist Church of Fiji'}, Added: set(), Dropped: set()
# Original: {'Schwarzenegger', 'congressional Republicans'}, Modified: {'Schwarzenegger', 'congressional Republicans'}, Added: set(), Dropped: set()
# Original: {'Schwarzenegger', 'congressional Republicans'}, Modified: {'House', 'Schwarzenegger', 'Senate'}, Added: {'House', 'Senate'}, Dropped: {'congressional Republicans'}
# Original: {'Southwest'}, Modified: {'Southwest'}, Added: set(), Dropped: set()
# Original: {'Southwest'}, Modified: {'Southwest'}, Added: set(), Dropped: set()
# Original: {'TCP / IP port 135', 'Microsoft'}, Modified: {'TCP / IP port 135', 'Microsoft'}, Added: set(), Dropped: set()
# Original: {'TCP / IP port 135', 'Microsoft'}, Modified: {'TCP/IP port 135', 'Microsoft'}, Added: {'TCP/IP port 135'}, Dropped: {'TCP / IP port 135'}
# Original: {'FBI headquarters', 'Leung', 'Smith'}, Modified: {'leung', 'Smith', 'Leung', 'FBI', 'fbi'}, Added: {'leung', 'fbi', 'FBI'}, Dropped: {'FBI headquarters'}
# Original: {'FBI headquarters', 'Leung', 'Smith'}, Modified: {'Leung', 'Smith', 'New York Times', 'FBI'}, Added: {'FBI', 'New York Times'}, Dropped: {'FBI headquarters'}
# Original: {'employers'}, Modified: {'employers', 'Bureau of Labor Statistics'}, Added: {'Bureau of Labor Statistics'}, Dropped: set()
# Original: {'employers'}, Modified: {'employers'}, Added: set(), Dropped: set()
# Original: {'Miss Stewart', 'Mr Comey'}, Modified: {'Miss Stewart', 'Mr Comey'}, Added: set(), Dropped: set()
# Original: {'Miss Stewart', 'Mr Comey'}, Modified: {'Miss Stewart', 'Mr Comey'}, Added: set(), Dropped: set()
# Original: {'scientists'}, Modified: {'u.s. department of energy', 'scientists'}, Added: {'u.s. department of energy'}, Dropped: set()
# Original: {'scientists'}, Modified: {'University of California, San Diego'}, Added: {'University of California, San Diego'}, Dropped: {'scientists'}
# Original: {'self-storage company', 'Authorities', "O 'Dell"}, Modified: {"O'dell", 'police', "O 'Dell", 'self-storage company', 'authorities'}, Added: {'police', 'authorities', "O'dell"}, Dropped: {'Authorities'}
# Original: {'self-storage company', 'Authorities', "O 'Dell"}, Modified: {'police', 'self-storage company', "O 'Dell", 'Pennsylvania'}, Added: {'police', 'Pennsylvania'}, Dropped: {'Authorities'}
# Original: {'Phil Condit', 'Boeing'}, Modified: {'Phil Condit', 'Boeing'}, Added: set(), Dropped: set()
# Original: {'Phil Condit', 'Boeing'}, Modified: {'Phil Condit', 'Boeing'}, Added: set(), Dropped: set()
# Original: {'four North Korean journalists', 'South Korean activists'}, Modified: {'North Korean journalists', 'South korean activists', 'main media centre'}, Added: {'North Korean journalists', 'South korean activists', 'main media centre'}, Dropped: {'four North Korean journalists', 'South Korean activists'}
# Original: {'four North Korean journalists', 'South Korean activists'}, Modified: {'four North Korean journalists', "North's government", 'South Korean activists'}, Added: {"North's government"}, Dropped: set()
# Original: {'Angela Stanford', 'Michelle Wie', 'GALLOWAY TOWNSHIP , N.J.', 'Annika Sorenstam'}, Modified: {'GALLOWAY TOWNSHIP, N.J.', 'Angela Stanford', 'Michelle Wie', 'Annika Sorenstam'}, Added: {'GALLOWAY TOWNSHIP, N.J.'}, Dropped: {'GALLOWAY TOWNSHIP , N.J.'}
# Original: {'Angela Stanford', 'Michelle Wie', 'GALLOWAY TOWNSHIP , N.J.', 'Annika Sorenstam'}, Modified: {'GALLOWAY TOWNSHIP, N.J.', 'Angela Stanford', 'Michelle Wie', 'Annika Sorenstam'}, Added: {'GALLOWAY TOWNSHIP, N.J.'}, Dropped: {'GALLOWAY TOWNSHIP , N.J.'}
# Original: {'Hitachi', 'Toshiba', 'Sharp', 'Samsung', 'Sony', 'Matsushita Electric', 'Royal Philips Electronics', 'NEC'}, Modified: {'Toshiba', 'Hitachi', 'Matsushita Electric', 'Royal Philips Electronics', 'NEC'}, Added: set(), Dropped: {'Samsung', 'Sony', 'Sharp'}
# Original: {'Hitachi', 'Toshiba', 'Sharp', 'Samsung', 'Sony', 'Matsushita Electric', 'Royal Philips Electronics', 'NEC'}, Modified: {'Toshiba-Hitachi', 'Toshiba', 'Hitachi', 'Sharp', 'Sony', 'Matsushita Electric', 'NEC'}, Added: {'Toshiba-Hitachi'}, Dropped: {'Royal Philips Electronics', 'Samsung'}
# Original: {'Global Crossing', 'Carl Griver', 'XO'}, Modified: {'Global Crossing', 'Global crossing', 'Carl Griver', 'XO'}, Added: {'Global crossing'}, Dropped: set()
# Original: {'Global Crossing', 'Carl Griver', 'XO'}, Modified: {'Global Crossing', 'company', 'Carl Griver', 'XO'}, Added: {'company'}, Dropped: set()
# Original: {'Roy Moore', 'Alabama Supreme Court'}, Modified: {'Roy Moore', 'Alabama woman', 'Alabama Supreme Court'}, Added: {'Alabama woman'}, Dropped: set()
# Original: {'Roy Moore', 'Alabama Supreme Court'}, Modified: {'Roy Moore', 'Alabama Supreme Court'}, Added: set(), Dropped: set()
# Original: {'Sumner', 'Halliburton', 'Altanmia'}, Modified: {'Halliburton', 'Sumner'}, Added: set(), Dropped: {'Altanmia'}
# Original: {'Sumner', 'Halliburton', 'Altanmia'}, Modified: {'Sumner', 'Halliburton', 'Altanmia'}, Added: set(), Dropped: set()
# Original: {'Snack Bar and Café'}, Modified: {'supper bar', 'bar', 'Snack Bar and Café'}, Added: {'supper bar', 'bar'}, Dropped: set()
# Original: {'Snack Bar and Café'}, Modified: {'restaurant', 'apartments', 'building'}, Added: {'restaurant', 'apartments', 'building'}, Dropped: {'Snack Bar and Café'}
# Original: {'Nasdaq Composite Index'}, Modified: {'Nasdaq Composite Index'}, Added: set(), Dropped: set()
# Original: {'Nasdaq Composite Index'}, Modified: {'Nasdaq Composite Index'}, Added: set(), Dropped: set()
# Original: {'injuries', 'hospital', 'police', 'surgery', 'teenager'}, Modified: {'injuries', 'hospital', 'police', 'teen', 'surgery', 'teenager'}, Added: {'teen'}, Dropped: set()
# Original: {'injuries', 'hospital', 'police', 'surgery', 'teenager'}, Modified: {'hospital', 'surgery', 'teenager', 'Police'}, Added: {'Police'}, Dropped: {'police', 'injuries'}
# Original: {'senior State Department official'}, Modified: {'senior State Department official'}, Added: set(), Dropped: set()
# Original: {'senior State Department official'}, Modified: {'senior State Department official', 'U.S. government'}, Added: {'U.S. government'}, Dropped: set()
# Original: {'Infospace', 'Yahoo', 'NTT / Verio'}, Modified: {'Infospace', 'Yahoo', 'NTT / Verio'}, Added: set(), Dropped: set()
# Original: {'Infospace', 'Yahoo', 'NTT / Verio'}, Modified: {'Infospace', 'Yahoo', 'NTT / Verio'}, Added: set(), Dropped: set()
# Original: {'First Essex'}, Modified: {'First Essex'}, Added: set(), Dropped: set()
# Original: {'First Essex'}, Modified: {'First Essex'}, Added: set(), Dropped: set()
# Original: {'Mark Longabaugh', 'league', 'Kempthorne'}, Modified: {'Mark Longabaugh', 'league', 'Kempthorne'}, Added: set(), Dropped: set()
# Original: {'Mark Longabaugh', 'league', 'Kempthorne'}, Modified: {'Mark Longabaugh', 'league', 'Kempthorne'}, Added: set(), Dropped: set()
# Original: {'Stanford', 'Sorenstam', 'Juli Inkster', 'Michelle Wie'}, Modified: {'Stanford', 'Sorenstam', 'Wie', 'Juli Inkster'}, Added: {'Wie'}, Dropped: {'Michelle Wie'}
# Original: {'Stanford', 'Sorenstam', 'Juli Inkster', 'Michelle Wie'}, Modified: {'Stanford', 'Sorenstam', 'Juli Inkster', 'Michelle Wie'}, Added: set(), Dropped: set()
# Original: {'Santa Clara County'}, Modified: set(), Added: set(), Dropped: {'Santa Clara County'}
# Original: {'Santa Clara County'}, Modified: set(), Added: set(), Dropped: {'Santa Clara County'}
# Original: {'law enforcement officials', 'person arrested'}, Modified: {'e-mail account', 'law enforcement officials', 'victim', 'person arrested', 'assassin', 'ip address'}, Added: {'assassin', 'ip address', 'victim', 'e-mail account'}, Dropped: set()
# Original: {'law enforcement officials', 'person arrested'}, Modified: {"U.S. attorney's office", 'The suspect'}, Added: {"U.S. attorney's office", 'The suspect'}, Dropped: {'law enforcement officials', 'person arrested'}
# Original: set(), Modified: {'he', 'The thief'}, Added: {'he', 'The thief'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: {'Commerce Department'}, Added: {'Commerce Department'}, Dropped: set()
# Original: {'Bush', 'commission'}, Modified: {'Bush', 'commission'}, Added: set(), Dropped: set()
# Original: {'Bush', 'commission'}, Modified: {'Bush', 'commission'}, Added: set(), Dropped: set()
# Original: {'Atkins'}, Modified: {'Atkins'}, Added: set(), Dropped: set()
# Original: {'Atkins'}, Modified: {'Atkins'}, Added: set(), Dropped: set()
# Original: {'I'}, Modified: {'he', 'I'}, Added: {'he'}, Dropped: set()
# Original: {'I'}, Modified: {'I'}, Added: set(), Dropped: set()
# Original: {'Pataki', 'Richard Kessel', 'Abraham', 'LIPA'}, Modified: {'Pataki', 'Richard Kessel', 'Abraham', 'LIPA'}, Added: set(), Dropped: set()
# Original: {'Pataki', 'Richard Kessel', 'Abraham', 'LIPA'}, Modified: {'Pataki', 'Richard Kessel', 'Abraham', 'LIPA'}, Added: set(), Dropped: set()
# Original: {'Mr McDonnell', 'Grant Thornton International'}, Modified: {'Mr mcDonnell', 'Mr McDonnell', 'Grant Thornton International', 'Grant thornton international', 'gti'}, Added: {'gti', 'Mr mcDonnell', 'Grant thornton international'}, Dropped: set()
# Original: {'Mr McDonnell', 'Grant Thornton International'}, Modified: {'Grant Thornton International', 'McDonnell'}, Added: {'McDonnell'}, Dropped: {'Mr McDonnell'}
# Original: {'Michael Newdow', 'Supreme Court'}, Modified: {'california atheist', 'Supreme Court', '9-year-old daughter'}, Added: {'california atheist', '9-year-old daughter'}, Dropped: {'Michael Newdow'}
# Original: {'Michael Newdow', 'Supreme Court'}, Modified: {'Michael Newdow', 'Supreme Court'}, Added: set(), Dropped: set()
# Original: {'federal government'}, Modified: {'federal government', 'states'}, Added: {'states'}, Dropped: set()
# Original: {'federal government'}, Modified: {'federal government'}, Added: set(), Dropped: set()
# Original: {'heart disease', 'he', 'researchers', 'pneumococcusleads'}, Modified: {'heart disease', 'researchers'}, Added: set(), Dropped: {'he', 'pneumococcusleads'}
# Original: {'heart disease', 'he', 'researchers', 'pneumococcusleads'}, Modified: {'He', 'cardiovascular disease', 'heart disease', 'he', 'heart attack', 'bacteriophage', 'pneumococcusleads'}, Added: {'heart attack', 'He', 'bacteriophage', 'cardiovascular disease'}, Dropped: {'researchers'}
# Original: {'King County Superior Court', 'Freitas'}, Modified: {'King County Superior Court', 'Judge Charles Mertel', 'Freitas'}, Added: {'Judge Charles Mertel'}, Dropped: set()
# Original: {'King County Superior Court', 'Freitas'}, Modified: {'King County Superior Court', 'Freitas'}, Added: set(), Dropped: set()
# Original: {'McKevitt', 'blood of innocent people'}, Modified: {'McKevitt', 'blood', 'McQuitt'}, Added: {'blood', 'McQuitt'}, Dropped: {'blood of innocent people'}
# Original: {'McKevitt', 'blood of innocent people'}, Modified: {'he', 'He', 'McKevitt'}, Added: {'he', 'He'}, Dropped: {'blood of innocent people'}
# Original: {'governor'}, Modified: {'legislature', 'senate', 'governor'}, Added: {'senate', 'legislature'}, Dropped: set()
# Original: {'governor'}, Modified: {'The governor'}, Added: {'The governor'}, Dropped: {'governor'}
# Original: {'British officer', 'Ministry of Defence'}, Modified: {'British officer', 'Ministry of Defence'}, Added: set(), Dropped: set()
# Original: {'British officer', 'Ministry of Defence'}, Modified: {'British officer', 'Ministry of Defence'}, Added: set(), Dropped: set()
# Original: {'Mr. Malik'}, Modified: {'Mr. malik', 'Mr. Malik', 'sahib'}, Added: {'Mr. malik', 'sahib'}, Dropped: set()
# Original: {'Mr. Malik'}, Modified: {'Mr. Malik', 'witness'}, Added: {'witness'}, Dropped: set()
# Original: {'Florida Sen. Bob Graham'}, Modified: {'Florida Sen. Bob Graham'}, Added: set(), Dropped: set()
# Original: {'Florida Sen. Bob Graham'}, Modified: {'polling firm', 'Sen. Bob Graham'}, Added: {'polling firm', 'Sen. Bob Graham'}, Dropped: {'Florida Sen. Bob Graham'}
# Original: {'Limbaugh'}, Modified: {'Limbaugh'}, Added: set(), Dropped: set()
# Original: {'Limbaugh'}, Modified: {'Limbaugh', 'judge'}, Added: {'judge'}, Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: {'PwC'}, Modified: {'PwC'}, Added: set(), Dropped: set()
# Original: {'PwC'}, Modified: {'PwC'}, Added: set(), Dropped: set()
# Original: {'police'}, Modified: {'police'}, Added: set(), Dropped: set()
# Original: {'police'}, Modified: {'police'}, Added: set(), Dropped: set()
# Original: {'He'}, Modified: {'he', 'He'}, Added: {'he'}, Dropped: set()
# Original: {'He'}, Modified: {'he', 'He'}, Added: {'he'}, Dropped: set()
# Original: {'QVC'}, Modified: {'qvc', 'QVC'}, Added: {'qvc'}, Dropped: set()
# Original: {'QVC'}, Modified: {'qvc', 'QVC'}, Added: {'qvc'}, Dropped: set()
# Original: {'New York Yankees', 'Eric Duncan', 'Seton Hall Prep'}, Modified: {'New York Yankees', 'Eric Duncan', 'Seton Hall Prep'}, Added: set(), Dropped: set()
# Original: {'New York Yankees', 'Eric Duncan', 'Seton Hall Prep'}, Modified: {'Eric Duncan', 'The Yankees', 'Seton Hall Prep'}, Added: {'The Yankees'}, Dropped: {'New York Yankees'}
# Original: {'authorities', 'Gehring'}, Modified: {'authorities', 'Gehring'}, Added: set(), Dropped: set()
# Original: {'authorities', 'Gehring'}, Modified: {'San Jose, Calif.', 'Gehring'}, Added: {'San Jose, Calif.'}, Dropped: {'authorities'}
# Original: {'Silver'}, Modified: {'my attorney', 'me', 'Silver', 'I'}, Added: {'me', 'I', 'my attorney'}, Dropped: set()
# Original: {'Silver'}, Modified: {'my counsel', 'Silver'}, Added: {'my counsel'}, Dropped: set()
# Original: {'Crews'}, Modified: {'crews'}, Added: {'crews'}, Dropped: {'Crews'}
# Original: {'Crews'}, Modified: {'Crews', 'crews'}, Added: {'crews'}, Dropped: set()
# Original: {'Nvidia'}, Modified: {'Nvidia'}, Added: set(), Dropped: set()
# Original: {'Nvidia'}, Modified: {'Nvidia'}, Added: set(), Dropped: set()
# Original: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission'}, Modified: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission'}, Added: set(), Dropped: set()
# Original: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission'}, Modified: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission (EEOC)'}, Added: {'Equal Employment Opportunity Commission (EEOC)'}, Dropped: {'Equal Employment Opportunity Commission'}
# Original: {'Assembly'}, Modified: {'senate', 'democrats', 'Democrats', 'Assembly', 'assembly'}, Added: {'assembly', 'senate', 'democrats', 'Democrats'}, Dropped: set()
# Original: {'Assembly'}, Modified: {'Assembly'}, Added: set(), Dropped: set()
# Original: {'Bethany Hamilton'}, Modified: {'hospital', 'Bethany Hamilton', 'stab wounds'}, Added: {'hospital', 'stab wounds'}, Dropped: set()
# Original: {'Bethany Hamilton'}, Modified: {'hospital', 'serious condition', 'Bethany Hamilton'}, Added: {'hospital', 'serious condition'}, Dropped: set()
# Original: {'AES Corp'}, Modified: {'AES Corp', 'US-based aes corp.', 'u.s. government'}, Added: {'US-based aes corp.', 'u.s. government'}, Dropped: set()
# Original: {'AES Corp'}, Modified: {'AES Corp.', 'bank'}, Added: {'AES Corp.', 'bank'}, Dropped: {'AES Corp'}
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# Original: set(), Modified: set(), Added: set(), Dropped: set()

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        print(f"Unextracted entities: {entities}")  # Print the unextracted entities
        extracted_entities = [{'text': entity['text'], 'label': entity['label']} for entity in entities]
        print(f"Extracted entities: {extracted_entities}")  # Print the extracted entities
        return extracted_entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set([item['text'] for item in original])
    modified_set = set([item['text'] for item in modified])
    added = modified_set - original_set
    dropped = original_set - modified_set
    print("original: ", original)
    print("modified: ", modified)
    print(f"Original: {original_set}, Modified: {modified_set}, Added: {added}, Dropped: {dropped}")
    return list(added), list(dropped)

# Main function
def main(dpsgd_file, ours_file, output_file, save_file):
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Analyze PII additions and drops
    dpsgd_added_records = []
    dpsgd_dropped_records = []
    ours_added_records = []
    ours_dropped_records = []

    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        added_dpsgd, dropped_dpsgd = compute_pii_changes_entailment(instr, dpsgd_out) #compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes_entailment(instr, ours_out) #compute_pii_changes(instr, ours_out)
        
        for added in added_dpsgd:
            dpsgd_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Added PII": added
            })
        
        for dropped in dropped_dpsgd:
            dpsgd_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "DPSGD Output": dpsgd_outputs[idx],
                "DPSGD PII Values": [item['text'] for item in dpsgd_out],
                "Dropped PII": dropped
            })
        
        for added in added_ours:
            ours_added_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Added PII": added
            })
        
        for dropped in dropped_ours:
            ours_dropped_records.append({
                "Index": idx,
                "Original Example": instructions[idx],
                "Original PII Values": [item['text'] for item in instr],
                "Our Output": ours_outputs[idx],
                "Our PII Values": [item['text'] for item in ours_out],
                "Dropped PII": dropped
            })

    # Save added and dropped records to CSV files
    path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"
    pd.DataFrame(dpsgd_added_records).to_csv(f"{path}/dpsgd_pii_added_2.csv", index=False)
    pd.DataFrame(dpsgd_dropped_records).to_csv(f"{path}/dpsgd_pii_dropped_2.csv", index=False)
    pd.DataFrame(ours_added_records).to_csv(f"{path}/ours_pii_added_2.csv", index=False)
    pd.DataFrame(ours_dropped_records).to_csv(f"{path}/ours_pii_dropped_2.csv", index=False)

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()


if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
    output_file = 'hallucinations_mrpc.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

    main(dpsgd_file, ours_file, output_file, save_file)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# original:  [{'start': 43, 'end': 47, 'text': 'PCCW', 'label': 'organization', 'score': 0.9979962110519409}, {'start': 77, 'end': 89, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9967117309570312}, {'start': 96, 'end': 106, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9980279803276062}, {'start': 163, 'end': 168, 'text': 'Mr So', 'label': 'person', 'score': 0.9798210859298706}]
# modified:  [{'start': 0, 'end': 4, 'text': 'PCCW', 'label': 'organization', 'score': 0.9982858300209045}, {'start': 32, 'end': 44, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9966384172439575}, {'start': 50, 'end': 60, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9978436231613159}, {'start': 115, 'end': 120, 'text': 'Mr So', 'label': 'person', 'score': 0.9780478477478027}]
# Original: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Modified: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 47, 'text': 'PCCW', 'label': 'organization', 'score': 0.9979962110519409}, {'start': 77, 'end': 89, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9967117309570312}, {'start': 96, 'end': 106, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9980279803276062}, {'start': 163, 'end': 168, 'text': 'Mr So', 'label': 'person', 'score': 0.9798210859298706}]
# modified:  [{'start': 0, 'end': 4, 'text': 'PCCW', 'label': 'organization', 'score': 0.9972479939460754}, {'start': 32, 'end': 44, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9963058233261108}, {'start': 74, 'end': 84, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9919503927230835}, {'start': 100, 'end': 105, 'text': 'Mr So', 'label': 'person', 'score': 0.9904425740242004}]
# Original: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Modified: {'PCCW', 'Alex Arena', 'Mike Butcher', 'Mr So'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 78, 'text': "world 's two largest automakers", 'label': 'organization', 'score': 0.7193154692649841}]
# modified:  [{'start': 178, 'end': 183, 'text': 'honda', 'label': 'organization', 'score': 0.9928907155990601}, {'start': 188, 'end': 194, 'text': 'nissan', 'label': 'organization', 'score': 0.989607036113739}]
# Original: {"world 's two largest automakers"}, Modified: {'nissan', 'honda'}, Added: {'nissan', 'honda'}, Dropped: {"world 's two largest automakers"}
# original:  [{'start': 47, 'end': 78, 'text': "world 's two largest automakers", 'label': 'organization', 'score': 0.7193154692649841}]
# modified:  [{'start': 0, 'end': 34, 'text': "The world's two largest automakers", 'label': 'organization', 'score': 0.725109338760376}, {'start': 156, 'end': 164, 'text': 'industry', 'label': 'organization', 'score': 0.7959831953048706}]
# Original: {"world 's two largest automakers"}, Modified: {'industry', "The world's two largest automakers"}, Added: {'industry', "The world's two largest automakers"}, Dropped: {"world 's two largest automakers"}
# original:  [{'start': 68, 'end': 110, 'text': 'Centers for Disease Control and Prevention', 'label': 'organization', 'score': 0.9378161430358887}, {'start': 166, 'end': 173, 'text': 'measles', 'label': 'medical condition', 'score': 0.9817723035812378}]
# modified:  [{'start': 0, 'end': 7, 'text': 'measles', 'label': 'medical condition', 'score': 0.8712401986122131}, {'start': 53, 'end': 95, 'text': 'Centers for Disease Control and Prevention', 'label': 'organization', 'score': 0.9548637866973877}, {'start': 129, 'end': 134, 'text': 'mumps', 'label': 'medical condition', 'score': 0.9380243420600891}]
# Original: {'Centers for Disease Control and Prevention', 'measles'}, Modified: {'Centers for Disease Control and Prevention', 'mumps', 'measles'}, Added: {'mumps'}, Dropped: set()
# original:  [{'start': 68, 'end': 110, 'text': 'Centers for Disease Control and Prevention', 'label': 'organization', 'score': 0.9378161430358887}, {'start': 166, 'end': 173, 'text': 'measles', 'label': 'medical condition', 'score': 0.9817723035812378}]
# modified:  [{'start': 104, 'end': 111, 'text': 'measles', 'label': 'medical condition', 'score': 0.984188437461853}]
# Original: {'Centers for Disease Control and Prevention', 'measles'}, Modified: {'measles'}, Added: set(), Dropped: {'Centers for Disease Control and Prevention'}
# original:  []
# modified:  [{'start': 181, 'end': 193, 'text': 'u.s. senator', 'label': 'person', 'score': 0.9628894329071045}]
# Original: set(), Modified: {'u.s. senator'}, Added: {'u.s. senator'}, Dropped: set()
# original:  []
# modified:  [{'start': 158, 'end': 182, 'text': 'National Weather Service', 'label': 'organization', 'score': 0.9993026256561279}]
# Original: set(), Modified: {'National Weather Service'}, Added: {'National Weather Service'}, Dropped: set()
# original:  [{'start': 47, 'end': 54, 'text': 'company', 'label': 'organization', 'score': 0.9576557874679565}]
# modified:  [{'start': 16, 'end': 23, 'text': 'company', 'label': 'organization', 'score': 0.9805471301078796}, {'start': 83, 'end': 92, 'text': 'spokesman', 'label': 'person', 'score': 0.5700386166572571}, {'start': 101, 'end': 108, 'text': 'company', 'label': 'organization', 'score': 0.9535563588142395}]
# Original: {'company'}, Modified: {'spokesman', 'company'}, Added: {'spokesman'}, Dropped: set()
# original:  [{'start': 47, 'end': 54, 'text': 'company', 'label': 'organization', 'score': 0.9576557874679565}]
# modified:  [{'start': 4, 'end': 11, 'text': 'company', 'label': 'organization', 'score': 0.983904242515564}, {'start': 98, 'end': 105, 'text': 'company', 'label': 'organization', 'score': 0.9841722846031189}]
# Original: {'company'}, Modified: {'company'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 65, 'text': 'settling companies', 'label': 'organization', 'score': 0.8575575351715088}, {'start': 118, 'end': 130, 'text': 'underwriters', 'label': 'organization', 'score': 0.7511562705039978}, {'start': 160, 'end': 162, 'text': 'he', 'label': 'person', 'score': 0.8680358529090881}]
# modified:  [{'start': 16, 'end': 34, 'text': 'settling companies', 'label': 'organization', 'score': 0.8589698076248169}, {'start': 87, 'end': 99, 'text': 'underwriters', 'label': 'organization', 'score': 0.7494745850563049}, {'start': 128, 'end': 130, 'text': 'he', 'label': 'person', 'score': 0.8790654540061951}]
# Original: {'he', 'settling companies', 'underwriters'}, Modified: {'he', 'settling companies', 'underwriters'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 65, 'text': 'settling companies', 'label': 'organization', 'score': 0.8575575351715088}, {'start': 118, 'end': 130, 'text': 'underwriters', 'label': 'organization', 'score': 0.7511562705039978}, {'start': 160, 'end': 162, 'text': 'he', 'label': 'person', 'score': 0.8680358529090881}]
# modified:  [{'start': 4, 'end': 22, 'text': 'settling companies', 'label': 'organization', 'score': 0.8063254356384277}, {'start': 66, 'end': 78, 'text': 'underwriters', 'label': 'organization', 'score': 0.6827563643455505}, {'start': 107, 'end': 109, 'text': 'he', 'label': 'person', 'score': 0.8873540759086609}]
# Original: {'he', 'settling companies', 'underwriters'}, Modified: {'he', 'settling companies', 'underwriters'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 63, 'text': 'Air Commodore Quaife', 'label': 'person', 'score': 0.9928297400474548}, {'start': 73, 'end': 80, 'text': 'Hornets', 'label': 'organization', 'score': 0.9748765230178833}]
# modified:  [{'start': 0, 'end': 20, 'text': 'Air Commodore Quaife', 'label': 'person', 'score': 0.996736466884613}, {'start': 30, 'end': 37, 'text': 'Hornets', 'label': 'organization', 'score': 0.9799281358718872}, {'start': 115, 'end': 124, 'text': 'Air Force', 'label': 'organization', 'score': 0.9867327809333801}]
# Original: {'Air Commodore Quaife', 'Hornets'}, Modified: {'Air Commodore Quaife', 'Air Force', 'Hornets'}, Added: {'Air Force'}, Dropped: set()
# original:  [{'start': 43, 'end': 63, 'text': 'Air Commodore Quaife', 'label': 'person', 'score': 0.9928297400474548}, {'start': 73, 'end': 80, 'text': 'Hornets', 'label': 'organization', 'score': 0.9748765230178833}]
# modified:  [{'start': 4, 'end': 11, 'text': 'Hornets', 'label': 'organization', 'score': 0.9121288061141968}, {'start': 40, 'end': 60, 'text': 'Air Commodore Quaife', 'label': 'person', 'score': 0.996775209903717}]
# Original: {'Air Commodore Quaife', 'Hornets'}, Modified: {'Air Commodore Quaife', 'Hornets'}, Added: set(), Dropped: set()
# original:  [{'start': 45, 'end': 62, 'text': 'Washington County', 'label': 'organization', 'score': 0.85312420129776}, {'start': 130, 'end': 147, 'text': 'health department', 'label': 'organization', 'score': 0.9932418465614319}]
# modified:  [{'start': 18, 'end': 21, 'text': 'man', 'label': 'person', 'score': 0.8634189367294312}, {'start': 84, 'end': 101, 'text': 'health department', 'label': 'organization', 'score': 0.9905162453651428}, {'start': 112, 'end': 115, 'text': 'man', 'label': 'person', 'score': 0.928851842880249}, {'start': 133, 'end': 136, 'text': 'man', 'label': 'person', 'score': 0.8186168670654297}]
# Original: {'health department', 'Washington County'}, Modified: {'health department', 'man'}, Added: {'man'}, Dropped: {'Washington County'}
# original:  [{'start': 45, 'end': 62, 'text': 'Washington County', 'label': 'organization', 'score': 0.85312420129776}, {'start': 130, 'end': 147, 'text': 'health department', 'label': 'organization', 'score': 0.9932418465614319}]
# modified:  [{'start': 4, 'end': 27, 'text': 'state health department', 'label': 'organization', 'score': 0.9814634323120117}, {'start': 47, 'end': 50, 'text': 'man', 'label': 'person', 'score': 0.9449897408485413}, {'start': 117, 'end': 132, 'text': 'West Nile virus', 'label': 'medical condition', 'score': 0.9629759788513184}]
# Original: {'health department', 'Washington County'}, Modified: {'state health department', 'West Nile virus', 'man'}, Added: {'state health department', 'West Nile virus', 'man'}, Dropped: {'health department', 'Washington County'}
# original:  [{'start': 43, 'end': 50, 'text': 'Moseley', 'label': 'person', 'score': 0.9983164072036743}, {'start': 57, 'end': 68, 'text': 'senior aide', 'label': 'person', 'score': 0.7576047778129578}]
# modified:  [{'start': 0, 'end': 7, 'text': 'Moseley', 'label': 'person', 'score': 0.9803726673126221}, {'start': 14, 'end': 25, 'text': 'senior aide', 'label': 'person', 'score': 0.5936526656150818}, {'start': 105, 'end': 110, 'text': 'Mosey', 'label': 'person', 'score': 0.8959947228431702}]
# Original: {'Moseley', 'senior aide'}, Modified: {'Moseley', 'senior aide', 'Mosey'}, Added: {'Mosey'}, Dropped: set()
# original:  [{'start': 43, 'end': 50, 'text': 'Moseley', 'label': 'person', 'score': 0.9983164072036743}, {'start': 57, 'end': 68, 'text': 'senior aide', 'label': 'person', 'score': 0.7576047778129578}]
# modified:  [{'start': 0, 'end': 7, 'text': 'Moseley', 'label': 'person', 'score': 0.9938790798187256}, {'start': 58, 'end': 62, 'text': 'NATO', 'label': 'organization', 'score': 0.6099788546562195}, {'start': 109, 'end': 120, 'text': 'senior aide', 'label': 'person', 'score': 0.9097801446914673}]
# Original: {'Moseley', 'senior aide'}, Modified: {'Moseley', 'NATO', 'senior aide'}, Added: {'NATO'}, Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 52, 'text': 'Consumers', 'label': 'person', 'score': 0.8792986869812012}, {'start': 117, 'end': 131, 'text': 'cable operator', 'label': 'organization', 'score': 0.8747848272323608}]
# modified:  [{'start': 12, 'end': 21, 'text': 'Consumers', 'label': 'person', 'score': 0.9136560559272766}, {'start': 86, 'end': 100, 'text': 'cable operator', 'label': 'organization', 'score': 0.8914967179298401}]
# Original: {'Consumers', 'cable operator'}, Modified: {'Consumers', 'cable operator'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 52, 'text': 'Consumers', 'label': 'person', 'score': 0.8792986869812012}, {'start': 117, 'end': 131, 'text': 'cable operator', 'label': 'organization', 'score': 0.8747848272323608}]
# modified:  [{'start': 4, 'end': 12, 'text': 'consumer', 'label': 'person', 'score': 0.9033538699150085}, {'start': 75, 'end': 88, 'text': 'cable company', 'label': 'organization', 'score': 0.9738474488258362}]
# Original: {'Consumers', 'cable operator'}, Modified: {'consumer', 'cable company'}, Added: {'consumer', 'cable company'}, Dropped: {'Consumers', 'cable operator'}
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  [{'start': 116, 'end': 128, 'text': 'RealNetworks', 'label': 'organization', 'score': 0.9982509016990662}]
# modified:  [{'start': 73, 'end': 85, 'text': 'RealNetworks', 'label': 'organization', 'score': 0.9978533387184143}]
# Original: {'RealNetworks'}, Modified: {'RealNetworks'}, Added: set(), Dropped: set()
# original:  [{'start': 116, 'end': 128, 'text': 'RealNetworks', 'label': 'organization', 'score': 0.9982509016990662}]
# modified:  [{'start': 37, 'end': 49, 'text': 'RealNetworks', 'label': 'organization', 'score': 0.9975851774215698}]
# Original: {'RealNetworks'}, Modified: {'RealNetworks'}, Added: set(), Dropped: set()
# original:  []
# modified:  [{'start': 0, 'end': 9, 'text': 'Hong Kong', 'label': 'address', 'score': 0.5030792355537415}, {'start': 45, 'end': 56, 'text': 'South Korea', 'label': 'organization', 'score': 0.5522444844245911}]
# Original: set(), Modified: {'South Korea', 'Hong Kong'}, Added: {'South Korea', 'Hong Kong'}, Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  [{'start': 61, 'end': 79, 'text': 'two of the victims', 'label': 'person', 'score': 0.8099934458732605}, {'start': 121, 'end': 124, 'text': 'two', 'label': 'person', 'score': 0.6868894696235657}, {'start': 190, 'end': 196, 'text': 'police', 'label': 'organization', 'score': 0.9881316423416138}]
# modified:  [{'start': 0, 'end': 18, 'text': 'two of the victims', 'label': 'person', 'score': 0.8381507992744446}, {'start': 59, 'end': 62, 'text': 'two', 'label': 'person', 'score': 0.7068020701408386}, {'start': 127, 'end': 133, 'text': 'police', 'label': 'organization', 'score': 0.9869863390922546}]
# Original: {'police', 'two of the victims', 'two'}, Modified: {'police', 'two of the victims', 'two'}, Added: set(), Dropped: set()
# original:  [{'start': 61, 'end': 79, 'text': 'two of the victims', 'label': 'person', 'score': 0.8099934458732605}, {'start': 121, 'end': 124, 'text': 'two', 'label': 'person', 'score': 0.6868894696235657}, {'start': 190, 'end': 196, 'text': 'police', 'label': 'organization', 'score': 0.9881316423416138}]
# modified:  [{'start': 0, 'end': 6, 'text': 'Police', 'label': 'organization', 'score': 0.9909754395484924}, {'start': 29, 'end': 40, 'text': 'two victims', 'label': 'person', 'score': 0.8493043780326843}, {'start': 74, 'end': 87, 'text': 'the other two', 'label': 'person', 'score': 0.6300342679023743}]
# Original: {'police', 'two of the victims', 'two'}, Modified: {'two victims', 'the other two', 'Police'}, Added: {'the other two', 'Police', 'two victims'}, Dropped: {'police', 'two of the victims', 'two'}
# original:  [{'start': 43, 'end': 50, 'text': 'Ballmer', 'label': 'person', 'score': 0.9984872341156006}, {'start': 91, 'end': 96, 'text': 'Linux', 'label': 'organization', 'score': 0.6998169422149658}, {'start': 112, 'end': 121, 'text': 'Microsoft', 'label': 'organization', 'score': 0.9946696162223816}]
# modified:  [{'start': 0, 'end': 9, 'text': 'Microsoft', 'label': 'organization', 'score': 0.9986897110939026}, {'start': 14, 'end': 27, 'text': 'Steve Ballmer', 'label': 'person', 'score': 0.9990530610084534}, {'start': 89, 'end': 98, 'text': 'Microsoft', 'label': 'organization', 'score': 0.9984776377677917}, {'start': 154, 'end': 163, 'text': 'microsoft', 'label': 'organization', 'score': 0.9906150102615356}, {'start': 167, 'end': 176, 'text': 'Microsoft', 'label': 'organization', 'score': 0.9978684186935425}]
# Original: {'Ballmer', 'Microsoft', 'Linux'}, Modified: {'Steve Ballmer', 'microsoft', 'Microsoft'}, Added: {'Steve Ballmer', 'microsoft'}, Dropped: {'Ballmer', 'Linux'}
# original:  [{'start': 43, 'end': 50, 'text': 'Ballmer', 'label': 'person', 'score': 0.9984872341156006}, {'start': 91, 'end': 96, 'text': 'Linux', 'label': 'organization', 'score': 0.6998169422149658}, {'start': 112, 'end': 121, 'text': 'Microsoft', 'label': 'organization', 'score': 0.9946696162223816}]
# modified:  [{'start': 0, 'end': 7, 'text': 'Ballmer', 'label': 'person', 'score': 0.9980173110961914}, {'start': 43, 'end': 48, 'text': 'Linux', 'label': 'organization', 'score': 0.7943288683891296}, {'start': 64, 'end': 73, 'text': 'Microsoft', 'label': 'organization', 'score': 0.9972580671310425}]
# Original: {'Ballmer', 'Microsoft', 'Linux'}, Modified: {'Ballmer', 'Microsoft', 'Linux'}, Added: set(), Dropped: set()
# original:  [{'start': 183, 'end': 192, 'text': 'officials', 'label': 'organization', 'score': 0.6243026852607727}]
# modified:  [{'start': 88, 'end': 108, 'text': 'spanish peacekeepers', 'label': 'person', 'score': 0.58917635679245}]
# Original: {'officials'}, Modified: {'spanish peacekeepers'}, Added: {'spanish peacekeepers'}, Dropped: {'officials'}
# original:  [{'start': 183, 'end': 192, 'text': 'officials', 'label': 'organization', 'score': 0.6243026852607727}]
# modified:  [{'start': 2, 'end': 15, 'text': 'charter plane', 'label': 'organization', 'score': 0.5518061518669128}, {'start': 86, 'end': 109, 'text': '62 Spanish peacekeepers', 'label': 'person', 'score': 0.5412359833717346}, {'start': 111, 'end': 120, 'text': 'officials', 'label': 'organization', 'score': 0.8050674200057983}]
# Original: {'officials'}, Modified: {'charter plane', 'officials', '62 Spanish peacekeepers'}, Added: {'charter plane', '62 Spanish peacekeepers'}, Dropped: set()
# original:  [{'start': 43, 'end': 69, 'text': 'Moroccan Interior Minister', 'label': 'person', 'score': 0.6171755194664001}, {'start': 70, 'end': 87, 'text': 'Al Mustapha Sahel', 'label': 'person', 'score': 0.9334837794303894}, {'start': 192, 'end': 207, 'text': 'Djihad Salafist', 'label': 'organization', 'score': 0.991950273513794}]
# modified:  [{'start': 0, 'end': 26, 'text': 'Moroccan Interior Minister', 'label': 'person', 'score': 0.6371689438819885}, {'start': 27, 'end': 44, 'text': 'Al Mustapha Sahel', 'label': 'person', 'score': 0.9870836734771729}, {'start': 160, 'end': 175, 'text': 'Djihad Salafist', 'label': 'organization', 'score': 0.993509829044342}]
# Original: {'Moroccan Interior Minister', 'Al Mustapha Sahel', 'Djihad Salafist'}, Modified: {'Moroccan Interior Minister', 'Al Mustapha Sahel', 'Djihad Salafist'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 69, 'text': 'Moroccan Interior Minister', 'label': 'person', 'score': 0.6171755194664001}, {'start': 70, 'end': 87, 'text': 'Al Mustapha Sahel', 'label': 'person', 'score': 0.9334837794303894}, {'start': 192, 'end': 207, 'text': 'Djihad Salafist', 'label': 'organization', 'score': 0.991950273513794}]
# modified:  [{'start': 105, 'end': 149, 'text': 'Moroccan Interior Minister Al Mustapha Sahel', 'label': 'person', 'score': 0.9383973479270935}, {'start': 205, 'end': 220, 'text': 'Djihad Salafist', 'label': 'organization', 'score': 0.9953256845474243}]
# Original: {'Moroccan Interior Minister', 'Al Mustapha Sahel', 'Djihad Salafist'}, Modified: {'Moroccan Interior Minister Al Mustapha Sahel', 'Djihad Salafist'}, Added: {'Moroccan Interior Minister Al Mustapha Sahel'}, Dropped: {'Moroccan Interior Minister', 'Al Mustapha Sahel'}
# original:  [{'start': 65, 'end': 76, 'text': 'David Chase', 'label': 'person', 'score': 0.9970607161521912}, {'start': 151, 'end': 154, 'text': 'HBO', 'label': 'organization', 'score': 0.9989192485809326}, {'start': 184, 'end': 198, 'text': 'Chris Albrecht', 'label': 'person', 'score': 0.9946061968803406}]
# modified:  [{'start': 21, 'end': 32, 'text': 'David Chase', 'label': 'person', 'score': 0.998281717300415}, {'start': 102, 'end': 105, 'text': 'HBO', 'label': 'organization', 'score': 0.9990723133087158}, {'start': 135, 'end': 149, 'text': 'Chris Albrecht', 'label': 'person', 'score': 0.9952855706214905}]
# Original: {'HBO', 'David Chase', 'Chris Albrecht'}, Modified: {'HBO', 'David Chase', 'Chris Albrecht'}, Added: set(), Dropped: set()
# original:  [{'start': 65, 'end': 76, 'text': 'David Chase', 'label': 'person', 'score': 0.9970607161521912}, {'start': 151, 'end': 154, 'text': 'HBO', 'label': 'organization', 'score': 0.9989192485809326}, {'start': 184, 'end': 198, 'text': 'Chris Albrecht', 'label': 'person', 'score': 0.9946061968803406}]
# modified:  [{'start': 20, 'end': 31, 'text': 'David Chase', 'label': 'person', 'score': 0.9992080330848694}, {'start': 112, 'end': 115, 'text': 'HBO', 'label': 'organization', 'score': 0.9991843104362488}, {'start': 133, 'end': 147, 'text': 'Chris Albrecht', 'label': 'person', 'score': 0.9847893714904785}]
# Original: {'HBO', 'David Chase', 'Chris Albrecht'}, Modified: {'HBO', 'David Chase', 'Chris Albrecht'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 50, 'text': 'two', 'label': 'person', 'score': 0.6247349977493286}, {'start': 74, 'end': 83, 'text': 'new board', 'label': 'organization', 'score': 0.7841373682022095}]
# modified:  [{'start': 0, 'end': 7, 'text': 'The two', 'label': 'person', 'score': 0.7538801431655884}, {'start': 35, 'end': 40, 'text': 'board', 'label': 'organization', 'score': 0.9862985014915466}, {'start': 106, 'end': 111, 'text': 'board', 'label': 'organization', 'score': 0.9922084212303162}, {'start': 134, 'end': 138, 'text': 'they', 'label': 'person', 'score': 0.5778678059577942}]
# Original: {'new board', 'two'}, Modified: {'The two', 'they', 'board'}, Added: {'The two', 'they', 'board'}, Dropped: {'new board', 'two'}
# original:  [{'start': 47, 'end': 50, 'text': 'two', 'label': 'person', 'score': 0.6247349977493286}, {'start': 74, 'end': 83, 'text': 'new board', 'label': 'organization', 'score': 0.7841373682022095}]
# modified:  [{'start': 0, 'end': 7, 'text': 'The two', 'label': 'person', 'score': 0.8278788328170776}, {'start': 79, 'end': 84, 'text': 'board', 'label': 'organization', 'score': 0.861796498298645}]
# Original: {'new board', 'two'}, Modified: {'The two', 'board'}, Added: {'The two', 'board'}, Dropped: {'new board', 'two'}
# original:  [{'start': 103, 'end': 108, 'text': 'judge', 'label': 'person', 'score': 0.8587037920951843}, {'start': 128, 'end': 149, 'text': 'crack cocaine kingpin', 'label': 'person', 'score': 0.5471610426902771}]
# modified:  [{'start': 50, 'end': 55, 'text': 'judge', 'label': 'person', 'score': 0.8261679410934448}, {'start': 75, 'end': 96, 'text': 'crack cocaine kingpin', 'label': 'person', 'score': 0.5347222089767456}]
# Original: {'judge', 'crack cocaine kingpin'}, Modified: {'judge', 'crack cocaine kingpin'}, Added: set(), Dropped: set()
# original:  [{'start': 103, 'end': 108, 'text': 'judge', 'label': 'person', 'score': 0.8587037920951843}, {'start': 128, 'end': 149, 'text': 'crack cocaine kingpin', 'label': 'person', 'score': 0.5471610426902771}]
# modified:  [{'start': 50, 'end': 55, 'text': 'judge', 'label': 'person', 'score': 0.8776175379753113}, {'start': 75, 'end': 96, 'text': 'crack cocaine kingpin', 'label': 'person', 'score': 0.5938261151313782}, {'start': 130, 'end': 146, 'text': 'California court', 'label': 'organization', 'score': 0.9593240022659302}]
# Original: {'judge', 'crack cocaine kingpin'}, Modified: {'California court', 'judge', 'crack cocaine kingpin'}, Added: {'California court'}, Dropped: set()
# original:  [{'start': 51, 'end': 53, 'text': 'he', 'label': 'person', 'score': 0.8294427990913391}, {'start': 63, 'end': 64, 'text': 'I', 'label': 'person', 'score': 0.6330057978630066}, {'start': 89, 'end': 91, 'text': 'we', 'label': 'person', 'score': 0.5075445771217346}]
# modified:  [{'start': 2, 'end': 3, 'text': 'I', 'label': 'person', 'score': 0.7827982902526855}, {'start': 27, 'end': 29, 'text': 'we', 'label': 'person', 'score': 0.7921562194824219}, {'start': 57, 'end': 59, 'text': 'he', 'label': 'person', 'score': 0.7942166328430176}, {'start': 69, 'end': 70, 'text': 'I', 'label': 'person', 'score': 0.8073312640190125}, {'start': 97, 'end': 99, 'text': 'we', 'label': 'person', 'score': 0.6905627250671387}, {'start': 126, 'end': 135, 'text': 'spokesman', 'label': 'person', 'score': 0.8855923414230347}]
# Original: {'he', 'we', 'I'}, Modified: {'he', 'spokesman', 'we', 'I'}, Added: {'spokesman'}, Dropped: set()
# original:  [{'start': 51, 'end': 53, 'text': 'he', 'label': 'person', 'score': 0.8294427990913391}, {'start': 63, 'end': 64, 'text': 'I', 'label': 'person', 'score': 0.6330057978630066}, {'start': 89, 'end': 91, 'text': 'we', 'label': 'person', 'score': 0.5075445771217346}]
# modified:  [{'start': 1, 'end': 2, 'text': 'I', 'label': 'person', 'score': 0.9216617941856384}, {'start': 46, 'end': 48, 'text': 'he', 'label': 'person', 'score': 0.8896887302398682}, {'start': 57, 'end': 58, 'text': 'I', 'label': 'person', 'score': 0.8731015920639038}]
# Original: {'he', 'we', 'I'}, Modified: {'he', 'I'}, Added: set(), Dropped: {'we'}
# original:  [{'start': 45, 'end': 60, 'text': 'Senator Clinton', 'label': 'person', 'score': 0.9988462924957275}]
# modified:  [{'start': 2, 'end': 17, 'text': 'Senator Clinton', 'label': 'person', 'score': 0.9997307658195496}, {'start': 125, 'end': 140, 'text': 'Senator Clinton', 'label': 'person', 'score': 0.9995869994163513}]
# Original: {'Senator Clinton'}, Modified: {'Senator Clinton'}, Added: set(), Dropped: set()
# original:  [{'start': 45, 'end': 60, 'text': 'Senator Clinton', 'label': 'person', 'score': 0.9988462924957275}]
# modified:  [{'start': 2, 'end': 17, 'text': 'Senator Clinton', 'label': 'person', 'score': 0.9982327222824097}, {'start': 129, 'end': 136, 'text': 'Clinton', 'label': 'person', 'score': 0.7029514908790588}]
# Original: {'Senator Clinton'}, Modified: {'Clinton', 'Senator Clinton'}, Added: {'Clinton'}, Dropped: set()
# original:  [{'start': 43, 'end': 57, 'text': 'Federal agents', 'label': 'organization', 'score': 0.9862686991691589}, {'start': 152, 'end': 174, 'text': 'construction companies', 'label': 'organization', 'score': 0.894903302192688}]
# modified:  [{'start': 0, 'end': 14, 'text': 'Federal agents', 'label': 'organization', 'score': 0.9897594451904297}, {'start': 89, 'end': 111, 'text': 'construction companies', 'label': 'organization', 'score': 0.9069351553916931}, {'start': 157, 'end': 171, 'text': 'federal agents', 'label': 'organization', 'score': 0.9876946210861206}, {'start': 263, 'end': 286, 'text': 'u.s. construction firms', 'label': 'organization', 'score': 0.5693396925926208}, {'start': 319, 'end': 324, 'text': 'thief', 'label': 'person', 'score': 0.8825424909591675}]
# Original: {'construction companies', 'Federal agents'}, Modified: {'thief', 'federal agents', 'construction companies', 'Federal agents', 'u.s. construction firms'}, Added: {'thief', 'u.s. construction firms', 'federal agents'}, Dropped: set()
# original:  [{'start': 43, 'end': 57, 'text': 'Federal agents', 'label': 'organization', 'score': 0.9862686991691589}, {'start': 152, 'end': 174, 'text': 'construction companies', 'label': 'organization', 'score': 0.894903302192688}]
# modified:  [{'start': 0, 'end': 14, 'text': 'Federal agents', 'label': 'organization', 'score': 0.9739564657211304}, {'start': 197, 'end': 223, 'text': 'U.S. Department of Justice', 'label': 'organization', 'score': 0.9765674471855164}]
# Original: {'construction companies', 'Federal agents'}, Modified: {'U.S. Department of Justice', 'Federal agents'}, Added: {'U.S. Department of Justice'}, Dropped: {'construction companies'}
# original:  [{'start': 55, 'end': 62, 'text': 'Comcast', 'label': 'organization', 'score': 0.9993353486061096}]
# modified:  [{'start': 0, 'end': 7, 'text': 'Comcast', 'label': 'organization', 'score': 0.9950515627861023}, {'start': 68, 'end': 75, 'text': 'comcast', 'label': 'organization', 'score': 0.9583232998847961}]
# Original: {'Comcast'}, Modified: {'comcast', 'Comcast'}, Added: {'comcast'}, Dropped: set()
# original:  [{'start': 55, 'end': 62, 'text': 'Comcast', 'label': 'organization', 'score': 0.9993353486061096}]
# modified:  [{'start': 11, 'end': 18, 'text': 'Comcast', 'label': 'organization', 'score': 0.9991942048072815}, {'start': 96, 'end': 103, 'text': 'comcast', 'label': 'organization', 'score': 0.9309396743774414}]
# Original: {'Comcast'}, Modified: {'comcast', 'Comcast'}, Added: {'comcast'}, Dropped: set()
# original:  [{'start': 43, 'end': 52, 'text': 'Schofield', 'label': 'person', 'score': 0.9959768652915955}, {'start': 57, 'end': 64, 'text': 'Toepfer', 'label': 'person', 'score': 0.9912437200546265}, {'start': 120, 'end': 130, 'text': "O 'Donnell", 'label': 'person', 'score': 0.9305346608161926}]
# modified:  [{'start': 0, 'end': 9, 'text': 'Schofield', 'label': 'person', 'score': 0.9955998659133911}, {'start': 14, 'end': 21, 'text': 'Toepfer', 'label': 'person', 'score': 0.987448513507843}, {'start': 77, 'end': 87, 'text': "O 'Donnell", 'label': 'person', 'score': 0.8746750950813293}]
# Original: {'Toepfer', "O 'Donnell", 'Schofield'}, Modified: {'Toepfer', "O 'Donnell", 'Schofield'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 52, 'text': 'Schofield', 'label': 'person', 'score': 0.9959768652915955}, {'start': 57, 'end': 64, 'text': 'Toepfer', 'label': 'person', 'score': 0.9912437200546265}, {'start': 120, 'end': 130, 'text': "O 'Donnell", 'label': 'person', 'score': 0.9305346608161926}]
# modified:  [{'start': 0, 'end': 9, 'text': 'Schofield', 'label': 'person', 'score': 0.9958657026290894}, {'start': 14, 'end': 21, 'text': 'Toepfer', 'label': 'person', 'score': 0.9913820624351501}, {'start': 78, 'end': 88, 'text': "O 'Donnell", 'label': 'person', 'score': 0.91285240650177}]
# Original: {'Toepfer', "O 'Donnell", 'Schofield'}, Modified: {'Toepfer', "O 'Donnell", 'Schofield'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 50, 'text': 'man', 'label': 'person', 'score': 0.841878354549408}, {'start': 98, 'end': 109, 'text': 'Cuban plane', 'label': 'organization', 'score': 0.5992344617843628}]
# modified:  [{'start': 4, 'end': 7, 'text': 'man', 'label': 'person', 'score': 0.8926396369934082}, {'start': 55, 'end': 66, 'text': 'Cuban plane', 'label': 'organization', 'score': 0.6144868731498718}]
# Original: {'Cuban plane', 'man'}, Modified: {'Cuban plane', 'man'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 50, 'text': 'man', 'label': 'person', 'score': 0.841878354549408}, {'start': 98, 'end': 109, 'text': 'Cuban plane', 'label': 'organization', 'score': 0.5992344617843628}]
# modified:  [{'start': 0, 'end': 7, 'text': 'The man', 'label': 'person', 'score': 0.8880147933959961}]
# Original: {'Cuban plane', 'man'}, Modified: {'The man'}, Added: {'The man'}, Dropped: {'Cuban plane', 'man'}
# original:  [{'start': 43, 'end': 58, 'text': 'Moroccan police', 'label': 'organization', 'score': 0.9923101663589478}, {'start': 124, 'end': 145, 'text': 'Djihad Salafist group', 'label': 'organization', 'score': 0.9663649201393127}, {'start': 150, 'end': 169, 'text': 'government official', 'label': 'person', 'score': 0.8185044527053833}]
# modified:  [{'start': 12, 'end': 27, 'text': 'Moroccan police', 'label': 'organization', 'score': 0.9932377338409424}, {'start': 92, 'end': 113, 'text': 'Djihad Salafist group', 'label': 'organization', 'score': 0.9698202013969421}, {'start': 117, 'end': 136, 'text': 'government official', 'label': 'person', 'score': 0.8458894491195679}]
# Original: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Modified: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 58, 'text': 'Moroccan police', 'label': 'organization', 'score': 0.9923101663589478}, {'start': 124, 'end': 145, 'text': 'Djihad Salafist group', 'label': 'organization', 'score': 0.9663649201393127}, {'start': 150, 'end': 169, 'text': 'government official', 'label': 'person', 'score': 0.8185044527053833}]
# modified:  [{'start': 0, 'end': 15, 'text': 'Moroccan police', 'label': 'organization', 'score': 0.9876617193222046}, {'start': 107, 'end': 128, 'text': 'Djihad Salafist group', 'label': 'organization', 'score': 0.9907982349395752}, {'start': 132, 'end': 151, 'text': 'government official', 'label': 'person', 'score': 0.796037495136261}]
# Original: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Modified: {'government official', 'Djihad Salafist group', 'Moroccan police'}, Added: set(), Dropped: set()
# original:  [{'start': 54, 'end': 97, 'text': 'circus trapeze artists turned vaudevillians', 'label': 'organization', 'score': 0.6637630462646484}, {'start': 100, 'end': 109, 'text': "O 'Connor", 'label': 'person', 'score': 0.9948081374168396}, {'start': 122, 'end': 136, 'text': 'Aug. 28 , 1925', 'label': 'date of birth', 'score': 0.9835250377655029}]
# modified:  [{'start': 0, 'end': 9, 'text': "O 'Connor", 'label': 'person', 'score': 0.9973451495170593}, {'start': 25, 'end': 68, 'text': 'circus trapeze artists turned vaudevillians', 'label': 'organization', 'score': 0.6614664793014526}, {'start': 180, 'end': 189, 'text': "o' Connor", 'label': 'person', 'score': 0.9973239898681641}, {'start': 216, 'end': 227, 'text': 'Chicago, il', 'label': 'address', 'score': 0.9085683226585388}, {'start': 252, 'end': 266, 'text': 'circus artists', 'label': 'organization', 'score': 0.593414306640625}]
# Original: {'Aug. 28 , 1925', "O 'Connor", 'circus trapeze artists turned vaudevillians'}, Modified: {"o' Connor", 'circus trapeze artists turned vaudevillians', 'circus artists', "O 'Connor", 'Chicago, il'}, Added: {'circus artists', "o' Connor", 'Chicago, il'}, Dropped: {'Aug. 28 , 1925'}
# original:  [{'start': 54, 'end': 97, 'text': 'circus trapeze artists turned vaudevillians', 'label': 'organization', 'score': 0.6637630462646484}, {'start': 100, 'end': 109, 'text': "O 'Connor", 'label': 'person', 'score': 0.9948081374168396}, {'start': 122, 'end': 136, 'text': 'Aug. 28 , 1925', 'label': 'date of birth', 'score': 0.9835250377655029}]
# modified:  [{'start': 0, 'end': 9, 'text': "O 'Connor", 'label': 'person', 'score': 0.9845712184906006}, {'start': 33, 'end': 46, 'text': 'Aug. 28, 1925', 'label': 'date of birth', 'score': 0.9824519753456116}, {'start': 134, 'end': 151, 'text': 'circus performers', 'label': 'organization', 'score': 0.5634294748306274}]
# Original: {'Aug. 28 , 1925', "O 'Connor", 'circus trapeze artists turned vaudevillians'}, Modified: {'Aug. 28, 1925', "O 'Connor", 'circus performers'}, Added: {'Aug. 28, 1925', 'circus performers'}, Dropped: {'Aug. 28 , 1925', 'circus trapeze artists turned vaudevillians'}
# original:  [{'start': 43, 'end': 56, 'text': 'Ricky Clemons', 'label': 'person', 'score': 0.999783456325531}, {'start': 76, 'end': 84, 'text': 'Missouri', 'label': 'organization', 'score': 0.9376887083053589}]
# modified:  [{'start': 0, 'end': 13, 'text': 'Ricky Clemons', 'label': 'person', 'score': 0.9996755123138428}, {'start': 32, 'end': 40, 'text': 'Missouri', 'label': 'organization', 'score': 0.960824191570282}]
# Original: {'Missouri', 'Ricky Clemons'}, Modified: {'Missouri', 'Ricky Clemons'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 56, 'text': 'Ricky Clemons', 'label': 'person', 'score': 0.999783456325531}, {'start': 76, 'end': 84, 'text': 'Missouri', 'label': 'organization', 'score': 0.9376887083053589}]
# modified:  [{'start': 0, 'end': 13, 'text': 'Ricky Clemons', 'label': 'person', 'score': 0.9996669292449951}, {'start': 40, 'end': 48, 'text': 'Missouri', 'label': 'organization', 'score': 0.5759573578834534}]
# Original: {'Missouri', 'Ricky Clemons'}, Modified: {'Missouri', 'Ricky Clemons'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 48, 'text': 'Dynes', 'label': 'person', 'score': 0.9989448189735413}, {'start': 85, 'end': 93, 'text': 'Atkinson', 'label': 'person', 'score': 0.9982426166534424}]
# modified:  [{'start': 0, 'end': 5, 'text': 'Dynes', 'label': 'person', 'score': 0.9987635612487793}, {'start': 41, 'end': 49, 'text': 'Atkinson', 'label': 'person', 'score': 0.9980584979057312}]
# Original: {'Dynes', 'Atkinson'}, Modified: {'Dynes', 'Atkinson'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 48, 'text': 'Dynes', 'label': 'person', 'score': 0.9989448189735413}, {'start': 85, 'end': 93, 'text': 'Atkinson', 'label': 'person', 'score': 0.9982426166534424}]
# modified:  [{'start': 0, 'end': 5, 'text': 'Dynes', 'label': 'person', 'score': 0.9925534129142761}, {'start': 48, 'end': 56, 'text': 'Atkinson', 'label': 'person', 'score': 0.995674192905426}, {'start': 77, 'end': 81, 'text': 'Dyne', 'label': 'person', 'score': 0.9957666397094727}]
# Original: {'Dynes', 'Atkinson'}, Modified: {'Dynes', 'Dyne', 'Atkinson'}, Added: {'Dyne'}, Dropped: set()
# original:  [{'start': 53, 'end': 61, 'text': 'Hurriyet', 'label': 'organization', 'score': 0.9395895004272461}, {'start': 116, 'end': 145, 'text': 'unnamed senior Iraqi official', 'label': 'person', 'score': 0.6874442100524902}]
# modified:  [{'start': 10, 'end': 18, 'text': 'Hurriyet', 'label': 'organization', 'score': 0.9476500749588013}, {'start': 73, 'end': 102, 'text': 'unnamed senior Iraqi official', 'label': 'person', 'score': 0.6559625864028931}]
# Original: {'Hurriyet', 'unnamed senior Iraqi official'}, Modified: {'Hurriyet', 'unnamed senior Iraqi official'}, Added: set(), Dropped: set()
# original:  [{'start': 53, 'end': 61, 'text': 'Hurriyet', 'label': 'organization', 'score': 0.9395895004272461}, {'start': 116, 'end': 145, 'text': 'unnamed senior Iraqi official', 'label': 'person', 'score': 0.6874442100524902}]
# modified:  [{'start': 59, 'end': 73, 'text': 'Iraqi official', 'label': 'person', 'score': 0.901123583316803}, {'start': 95, 'end': 103, 'text': 'Hurriyet', 'label': 'organization', 'score': 0.9496661424636841}]
# Original: {'Hurriyet', 'unnamed senior Iraqi official'}, Modified: {'Iraqi official', 'Hurriyet'}, Added: {'Iraqi official'}, Dropped: {'unnamed senior Iraqi official'}
# original:  [{'start': 123, 'end': 129, 'text': 'Thomas', 'label': 'person', 'score': 0.9992455244064331}]
# modified:  [{'start': 39, 'end': 41, 'text': 'we', 'label': 'person', 'score': 0.5206923484802246}, {'start': 138, 'end': 144, 'text': 'Thomas', 'label': 'person', 'score': 0.9985768795013428}]
# Original: {'Thomas'}, Modified: {'Thomas', 'we'}, Added: {'we'}, Dropped: set()
# original:  [{'start': 123, 'end': 129, 'text': 'Thomas', 'label': 'person', 'score': 0.9992455244064331}]
# modified:  [{'start': 0, 'end': 6, 'text': 'Thomas', 'label': 'person', 'score': 0.9986186027526855}, {'start': 16, 'end': 20, 'text': 'team', 'label': 'organization', 'score': 0.948327362537384}]
# Original: {'Thomas'}, Modified: {'team', 'Thomas'}, Added: {'team'}, Dropped: set()
# original:  [{'start': 144, 'end': 155, 'text': '136.03 / 14', 'label': 'train ticket number', 'score': 0.6844385266304016}]
# modified:  [{'start': 100, 'end': 110, 'text': '136.03/ 14', 'label': 'train ticket number', 'score': 0.7201855778694153}]
# Original: {'136.03 / 14'}, Modified: {'136.03/ 14'}, Added: {'136.03/ 14'}, Dropped: {'136.03 / 14'}
# original:  [{'start': 144, 'end': 155, 'text': '136.03 / 14', 'label': 'train ticket number', 'score': 0.6844385266304016}]
# modified:  []
# Original: {'136.03 / 14'}, Modified: set(), Added: set(), Dropped: {'136.03 / 14'}
# original:  [{'start': 43, 'end': 47, 'text': 'Snow', 'label': 'person', 'score': 0.9946135878562927}, {'start': 98, 'end': 110, 'text': 'Hans Redeker', 'label': 'person', 'score': 0.9978323578834534}, {'start': 150, 'end': 161, 'text': 'BNP Paribas', 'label': 'organization', 'score': 0.9979540109634399}]
# modified:  [{'start': 0, 'end': 4, 'text': 'Snow', 'label': 'person', 'score': 0.992435872554779}, {'start': 47, 'end': 59, 'text': 'Hans Redeker', 'label': 'person', 'score': 0.9982200264930725}, {'start': 98, 'end': 109, 'text': 'BNP Paribas', 'label': 'organization', 'score': 0.998772919178009}]
# Original: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Modified: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 47, 'text': 'Snow', 'label': 'person', 'score': 0.9946135878562927}, {'start': 98, 'end': 110, 'text': 'Hans Redeker', 'label': 'person', 'score': 0.9978323578834534}, {'start': 150, 'end': 161, 'text': 'BNP Paribas', 'label': 'organization', 'score': 0.9979540109634399}]
# modified:  [{'start': 0, 'end': 4, 'text': 'Snow', 'label': 'person', 'score': 0.9957048296928406}, {'start': 66, 'end': 78, 'text': 'Hans Redeker', 'label': 'person', 'score': 0.997557520866394}, {'start': 117, 'end': 128, 'text': 'BNP Paribas', 'label': 'organization', 'score': 0.9975237250328064}]
# Original: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Modified: {'Hans Redeker', 'BNP Paribas', 'Snow'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 52, 'text': 'women', 'label': 'person', 'score': 0.603574812412262}, {'start': 58, 'end': 73, 'text': 'victims of rape', 'label': 'person', 'score': 0.5577170252799988}, {'start': 149, 'end': 159, 'text': 'assailants', 'label': 'person', 'score': 0.6216209530830383}]
# modified:  [{'start': 4, 'end': 9, 'text': 'women', 'label': 'person', 'score': 0.5494513511657715}, {'start': 15, 'end': 30, 'text': 'victims of rape', 'label': 'person', 'score': 0.5728350281715393}, {'start': 106, 'end': 116, 'text': 'assailants', 'label': 'person', 'score': 0.6614325642585754}]
# Original: {'women', 'assailants', 'victims of rape'}, Modified: {'women', 'assailants', 'victims of rape'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 52, 'text': 'women', 'label': 'person', 'score': 0.603574812412262}, {'start': 58, 'end': 73, 'text': 'victims of rape', 'label': 'person', 'score': 0.5577170252799988}, {'start': 149, 'end': 159, 'text': 'assailants', 'label': 'person', 'score': 0.6216209530830383}]
# modified:  [{'start': 0, 'end': 9, 'text': 'The women', 'label': 'person', 'score': 0.6512141823768616}, {'start': 19, 'end': 31, 'text': 'rape victims', 'label': 'person', 'score': 0.6256987452507019}, {'start': 89, 'end': 101, 'text': 'perpetrators', 'label': 'person', 'score': 0.7953850030899048}]
# Original: {'women', 'assailants', 'victims of rape'}, Modified: {'perpetrators', 'rape victims', 'The women'}, Added: {'The women', 'rape victims', 'perpetrators'}, Dropped: {'women', 'assailants', 'victims of rape'}
# original:  [{'start': 45, 'end': 57, 'text': 'The National', 'label': 'organization', 'score': 0.9705143570899963}, {'start': 87, 'end': 90, 'text': 'AMP', 'label': 'organization', 'score': 0.9702448844909668}, {'start': 97, 'end': 100, 'text': 'AMP', 'label': 'organization', 'score': 0.9872826337814331}, {'start': 126, 'end': 133, 'text': 'Cicutto', 'label': 'person', 'score': 0.9989437460899353}]
# modified:  [{'start': 2, 'end': 14, 'text': 'The National', 'label': 'organization', 'score': 0.9923317432403564}, {'start': 44, 'end': 47, 'text': 'AMP', 'label': 'organization', 'score': 0.9832157492637634}, {'start': 51, 'end': 58, 'text': 'Cicutto', 'label': 'person', 'score': 0.9968896508216858}, {'start': 69, 'end': 72, 'text': 'AMP', 'label': 'organization', 'score': 0.9770320653915405}]
# Original: {'Cicutto', 'The National', 'AMP'}, Modified: {'Cicutto', 'The National', 'AMP'}, Added: set(), Dropped: set()
# original:  [{'start': 45, 'end': 57, 'text': 'The National', 'label': 'organization', 'score': 0.9705143570899963}, {'start': 87, 'end': 90, 'text': 'AMP', 'label': 'organization', 'score': 0.9702448844909668}, {'start': 97, 'end': 100, 'text': 'AMP', 'label': 'organization', 'score': 0.9872826337814331}, {'start': 126, 'end': 133, 'text': 'Cicutto', 'label': 'person', 'score': 0.9989437460899353}]
# modified:  [{'start': 2, 'end': 14, 'text': 'The National', 'label': 'organization', 'score': 0.9933130145072937}, {'start': 46, 'end': 49, 'text': 'AMP', 'label': 'organization', 'score': 0.9793285131454468}, {'start': 90, 'end': 97, 'text': 'Cicutto', 'label': 'person', 'score': 0.9978285431861877}, {'start': 116, 'end': 128, 'text': 'the National', 'label': 'organization', 'score': 0.9911994338035583}]
# Original: {'Cicutto', 'The National', 'AMP'}, Modified: {'Cicutto', 'the National', 'The National', 'AMP'}, Added: {'the National'}, Dropped: set()
# original:  [{'start': 60, 'end': 71, 'text': 'Mr. Rowland', 'label': 'person', 'score': 0.9949712753295898}, {'start': 118, 'end': 136, 'text': 'Commissioner Anson', 'label': 'person', 'score': 0.9952184557914734}]
# modified:  [{'start': 16, 'end': 27, 'text': 'Mr. Rowland', 'label': 'person', 'score': 0.9969782829284668}, {'start': 61, 'end': 79, 'text': 'Commissioner Anson', 'label': 'person', 'score': 0.9951980710029602}]
# Original: {'Mr. Rowland', 'Commissioner Anson'}, Modified: {'Mr. Rowland', 'Commissioner Anson'}, Added: set(), Dropped: set()
# original:  [{'start': 60, 'end': 71, 'text': 'Mr. Rowland', 'label': 'person', 'score': 0.9949712753295898}, {'start': 118, 'end': 136, 'text': 'Commissioner Anson', 'label': 'person', 'score': 0.9952184557914734}]
# modified:  [{'start': 26, 'end': 44, 'text': 'Commissioner Anson', 'label': 'person', 'score': 0.9924472570419312}, {'start': 68, 'end': 79, 'text': 'Mr. Rowland', 'label': 'person', 'score': 0.9967740178108215}]
# Original: {'Mr. Rowland', 'Commissioner Anson'}, Modified: {'Mr. Rowland', 'Commissioner Anson'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 49, 'text': 'Oracle', 'label': 'organization', 'score': 0.997576892375946}, {'start': 81, 'end': 91, 'text': 'PeopleSoft', 'label': 'organization', 'score': 0.9908075928688049}, {'start': 125, 'end': 135, 'text': 'PeopleSoft', 'label': 'organization', 'score': 0.9970180988311768}]
# modified:  [{'start': 0, 'end': 6, 'text': 'Oracle', 'label': 'organization', 'score': 0.9961252808570862}, {'start': 37, 'end': 47, 'text': 'Peoplesoft', 'label': 'organization', 'score': 0.9943535327911377}, {'start': 81, 'end': 91, 'text': 'PeopleSoft', 'label': 'organization', 'score': 0.995875895023346}, {'start': 99, 'end': 105, 'text': 'Oracle', 'label': 'organization', 'score': 0.9948935508728027}, {'start': 219, 'end': 229, 'text': 'peoplesoft', 'label': 'organization', 'score': 0.9972780346870422}, {'start': 234, 'end': 245, 'text': 'eric taylor', 'label': 'person', 'score': 0.9953592419624329}, {'start': 253, 'end': 263, 'text': 'PeopleSoft', 'label': 'organization', 'score': 0.9957413673400879}, {'start': 271, 'end': 277, 'text': 'Oracle', 'label': 'organization', 'score': 0.9900542497634888}]
# Original: {'PeopleSoft', 'Oracle'}, Modified: {'PeopleSoft', 'peoplesoft', 'Peoplesoft', 'eric taylor', 'Oracle'}, Added: {'Peoplesoft', 'eric taylor', 'peoplesoft'}, Dropped: set()
# ...
# original:  [{'start': 43, 'end': 52, 'text': 'Mr. Malik', 'label': 'person', 'score': 0.9955326318740845}]
# modified:  [{'start': 4, 'end': 11, 'text': 'witness', 'label': 'person', 'score': 0.7653349041938782}, {'start': 22, 'end': 31, 'text': 'Mr. Malik', 'label': 'person', 'score': 0.9948487877845764}, {'start': 121, 'end': 128, 'text': 'witness', 'label': 'person', 'score': 0.8484814763069153}]
# Original: {'Mr. Malik'}, Modified: {'Mr. Malik', 'witness'}, Added: {'witness'}, Dropped: set()
# original:  [{'start': 43, 'end': 66, 'text': 'Florida Sen. Bob Graham', 'label': 'person', 'score': 0.9886713027954102}]
# modified:  [{'start': 0, 'end': 23, 'text': 'Florida Sen. Bob Graham', 'label': 'person', 'score': 0.913303017616272}]
# Original: {'Florida Sen. Bob Graham'}, Modified: {'Florida Sen. Bob Graham'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 66, 'text': 'Florida Sen. Bob Graham', 'label': 'person', 'score': 0.9886713027954102}]
# modified:  [{'start': 0, 'end': 15, 'text': 'Sen. Bob Graham', 'label': 'person', 'score': 0.9976438879966736}, {'start': 96, 'end': 108, 'text': 'polling firm', 'label': 'organization', 'score': 0.9129678606987}]
# Original: {'Florida Sen. Bob Graham'}, Modified: {'polling firm', 'Sen. Bob Graham'}, Added: {'polling firm', 'Sen. Bob Graham'}, Dropped: {'Florida Sen. Bob Graham'}
# original:  [{'start': 75, 'end': 83, 'text': 'Limbaugh', 'label': 'person', 'score': 0.976860761642456}]
# modified:  [{'start': 32, 'end': 40, 'text': 'Limbaugh', 'label': 'person', 'score': 0.9872666001319885}]
# Original: {'Limbaugh'}, Modified: {'Limbaugh'}, Added: set(), Dropped: set()
# original:  [{'start': 75, 'end': 83, 'text': 'Limbaugh', 'label': 'person', 'score': 0.976860761642456}]
# modified:  [{'start': 48, 'end': 56, 'text': 'Limbaugh', 'label': 'person', 'score': 0.989713191986084}, {'start': 95, 'end': 100, 'text': 'judge', 'label': 'person', 'score': 0.5589265823364258}]
# Original: {'Limbaugh'}, Modified: {'Limbaugh', 'judge'}, Added: {'judge'}, Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 46, 'text': 'PwC', 'label': 'organization', 'score': 0.9973287582397461}]
# modified:  [{'start': 0, 'end': 3, 'text': 'PwC', 'label': 'organization', 'score': 0.9977123737335205}]
# Original: {'PwC'}, Modified: {'PwC'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 46, 'text': 'PwC', 'label': 'organization', 'score': 0.9973287582397461}]
# modified:  [{'start': 0, 'end': 3, 'text': 'PwC', 'label': 'organization', 'score': 0.9984549283981323}]
# Original: {'PwC'}, Modified: {'PwC'}, Added: set(), Dropped: set()
# original:  [{'start': 138, 'end': 144, 'text': 'police', 'label': 'organization', 'score': 0.9855329394340515}]
# modified:  [{'start': 89, 'end': 95, 'text': 'police', 'label': 'organization', 'score': 0.9887274503707886}]
# Original: {'police'}, Modified: {'police'}, Added: set(), Dropped: set()
# original:  [{'start': 138, 'end': 144, 'text': 'police', 'label': 'organization', 'score': 0.9855329394340515}]
# modified:  [{'start': 73, 'end': 79, 'text': 'police', 'label': 'organization', 'score': 0.9936320185661316}, {'start': 135, 'end': 141, 'text': 'police', 'label': 'organization', 'score': 0.9328665137290955}]
# Original: {'police'}, Modified: {'police'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 45, 'text': 'He', 'label': 'person', 'score': 0.9207821488380432}]
# modified:  [{'start': 0, 'end': 2, 'text': 'He', 'label': 'person', 'score': 0.9860921502113342}, {'start': 92, 'end': 94, 'text': 'he', 'label': 'person', 'score': 0.9743093848228455}, {'start': 150, 'end': 152, 'text': 'He', 'label': 'person', 'score': 0.9914964437484741}]
# Original: {'He'}, Modified: {'he', 'He'}, Added: {'he'}, Dropped: set()
# original:  [{'start': 43, 'end': 45, 'text': 'He', 'label': 'person', 'score': 0.9207821488380432}]
# modified:  [{'start': 0, 'end': 2, 'text': 'He', 'label': 'person', 'score': 0.9608153700828552}, {'start': 8, 'end': 10, 'text': 'he', 'label': 'person', 'score': 0.9377079606056213}]
# Original: {'He'}, Modified: {'he', 'He'}, Added: {'he'}, Dropped: set()
# original:  [{'start': 76, 'end': 79, 'text': 'QVC', 'label': 'national health insurance number', 'score': 0.9307908415794373}]
# modified:  [{'start': 0, 'end': 3, 'text': 'QVC', 'label': 'organization', 'score': 0.9579970240592957}, {'start': 66, 'end': 69, 'text': 'qvc', 'label': 'organization', 'score': 0.8980683088302612}]
# Original: {'QVC'}, Modified: {'qvc', 'QVC'}, Added: {'qvc'}, Dropped: set()
# original:  [{'start': 76, 'end': 79, 'text': 'QVC', 'label': 'national health insurance number', 'score': 0.9307908415794373}]
# modified:  [{'start': 37, 'end': 40, 'text': 'QVC', 'label': 'organization', 'score': 0.977660059928894}, {'start': 72, 'end': 75, 'text': 'qvc', 'label': 'organization', 'score': 0.887556791305542}]
# Original: {'QVC'}, Modified: {'qvc', 'QVC'}, Added: {'qvc'}, Dropped: set()
# original:  [{'start': 47, 'end': 63, 'text': 'New York Yankees', 'label': 'organization', 'score': 0.9958288073539734}, {'start': 83, 'end': 94, 'text': 'Eric Duncan', 'label': 'person', 'score': 0.9993703961372375}, {'start': 100, 'end': 115, 'text': 'Seton Hall Prep', 'label': 'organization', 'score': 0.5603610873222351}]
# modified:  [{'start': 4, 'end': 20, 'text': 'New York Yankees', 'label': 'organization', 'score': 0.996778666973114}, {'start': 40, 'end': 51, 'text': 'Eric Duncan', 'label': 'person', 'score': 0.9997438788414001}, {'start': 57, 'end': 72, 'text': 'Seton Hall Prep', 'label': 'organization', 'score': 0.9211987257003784}]
# Original: {'New York Yankees', 'Eric Duncan', 'Seton Hall Prep'}, Modified: {'New York Yankees', 'Eric Duncan', 'Seton Hall Prep'}, Added: set(), Dropped: set()
# original:  [{'start': 47, 'end': 63, 'text': 'New York Yankees', 'label': 'organization', 'score': 0.9958288073539734}, {'start': 83, 'end': 94, 'text': 'Eric Duncan', 'label': 'person', 'score': 0.9993703961372375}, {'start': 100, 'end': 115, 'text': 'Seton Hall Prep', 'label': 'organization', 'score': 0.5603610873222351}]
# modified:  [{'start': 0, 'end': 11, 'text': 'The Yankees', 'label': 'organization', 'score': 0.8232894539833069}, {'start': 20, 'end': 31, 'text': 'Eric Duncan', 'label': 'person', 'score': 0.9995859265327454}, {'start': 99, 'end': 114, 'text': 'Seton Hall Prep', 'label': 'organization', 'score': 0.9519963264465332}]
# Original: {'New York Yankees', 'Eric Duncan', 'Seton Hall Prep'}, Modified: {'Eric Duncan', 'The Yankees', 'Seton Hall Prep'}, Added: {'The Yankees'}, Dropped: {'New York Yankees'}
# original:  [{'start': 43, 'end': 50, 'text': 'Gehring', 'label': 'person', 'score': 0.9993354678153992}, {'start': 112, 'end': 123, 'text': 'authorities', 'label': 'organization', 'score': 0.9135472178459167}]
# modified:  [{'start': 0, 'end': 7, 'text': 'Gehring', 'label': 'person', 'score': 0.9987792372703552}, {'start': 68, 'end': 79, 'text': 'authorities', 'label': 'organization', 'score': 0.8843343257904053}]
# Original: {'authorities', 'Gehring'}, Modified: {'authorities', 'Gehring'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 50, 'text': 'Gehring', 'label': 'person', 'score': 0.9993354678153992}, {'start': 112, 'end': 123, 'text': 'authorities', 'label': 'organization', 'score': 0.9135472178459167}]
# modified:  [{'start': 0, 'end': 7, 'text': 'Gehring', 'label': 'person', 'score': 0.9983362555503845}, {'start': 110, 'end': 126, 'text': 'San Jose, Calif.', 'label': 'address', 'score': 0.7429385781288147}]
# Original: {'authorities', 'Gehring'}, Modified: {'San Jose, Calif.', 'Gehring'}, Added: {'San Jose, Calif.'}, Dropped: {'authorities'}
# original:  [{'start': 152, 'end': 158, 'text': 'Silver', 'label': 'person', 'score': 0.9985083937644958}]
# modified:  [{'start': 2, 'end': 3, 'text': 'I', 'label': 'person', 'score': 0.5794894695281982}, {'start': 103, 'end': 109, 'text': 'Silver', 'label': 'person', 'score': 0.9978669285774231}, {'start': 195, 'end': 197, 'text': 'me', 'label': 'person', 'score': 0.5070945620536804}, {'start': 202, 'end': 213, 'text': 'my attorney', 'label': 'person', 'score': 0.8159655928611755}]
# Original: {'Silver'}, Modified: {'my attorney', 'me', 'Silver', 'I'}, Added: {'me', 'I', 'my attorney'}, Dropped: set()
# original:  [{'start': 152, 'end': 158, 'text': 'Silver', 'label': 'person', 'score': 0.9985083937644958}]
# modified:  [{'start': 20, 'end': 30, 'text': 'my counsel', 'label': 'person', 'score': 0.5114021897315979}, {'start': 125, 'end': 131, 'text': 'Silver', 'label': 'person', 'score': 0.9989294409751892}]
# Original: {'Silver'}, Modified: {'my counsel', 'Silver'}, Added: {'my counsel'}, Dropped: set()
# original:  [{'start': 43, 'end': 48, 'text': 'Crews', 'label': 'organization', 'score': 0.6873902678489685}]
# modified:  [{'start': 0, 'end': 5, 'text': 'crews', 'label': 'organization', 'score': 0.5011976957321167}]
# Original: {'Crews'}, Modified: {'crews'}, Added: {'crews'}, Dropped: {'Crews'}
# original:  [{'start': 43, 'end': 48, 'text': 'Crews', 'label': 'organization', 'score': 0.6873902678489685}]
# modified:  [{'start': 0, 'end': 5, 'text': 'Crews', 'label': 'organization', 'score': 0.9032636880874634}, {'start': 127, 'end': 132, 'text': 'crews', 'label': 'organization', 'score': 0.916980504989624}]
# Original: {'Crews'}, Modified: {'Crews', 'crews'}, Added: {'crews'}, Dropped: set()
# original:  [{'start': 156, 'end': 162, 'text': 'Nvidia', 'label': 'organization', 'score': 0.9975214600563049}]
# modified:  [{'start': 109, 'end': 115, 'text': 'Nvidia', 'label': 'organization', 'score': 0.9980872273445129}]
# Original: {'Nvidia'}, Modified: {'Nvidia'}, Added: set(), Dropped: set()
# original:  [{'start': 156, 'end': 162, 'text': 'Nvidia', 'label': 'organization', 'score': 0.9975214600563049}]
# modified:  [{'start': 54, 'end': 60, 'text': 'Nvidia', 'label': 'organization', 'score': 0.9978713989257812}]
# Original: {'Nvidia'}, Modified: {'Nvidia'}, Added: set(), Dropped: set()
# original:  [{'start': 49, 'end': 55, 'text': 'Hughes', 'label': 'person', 'score': 0.9924081563949585}, {'start': 74, 'end': 83, 'text': 'Hernandez', 'label': 'person', 'score': 0.99100261926651}, {'start': 107, 'end': 146, 'text': 'Equal Employment Opportunity Commission', 'label': 'organization', 'score': 0.9831235408782959}]
# modified:  [{'start': 6, 'end': 12, 'text': 'Hughes', 'label': 'person', 'score': 0.9981061220169067}, {'start': 31, 'end': 40, 'text': 'Hernandez', 'label': 'person', 'score': 0.9948047995567322}, {'start': 63, 'end': 102, 'text': 'Equal Employment Opportunity Commission', 'label': 'organization', 'score': 0.974351167678833}, {'start': 104, 'end': 110, 'text': 'Hughes', 'label': 'person', 'score': 0.9974205493927002}, {'start': 125, 'end': 134, 'text': 'Hernandez', 'label': 'person', 'score': 0.9985408782958984}]
# Original: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission'}, Modified: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission'}, Added: set(), Dropped: set()
# original:  [{'start': 49, 'end': 55, 'text': 'Hughes', 'label': 'person', 'score': 0.9924081563949585}, {'start': 74, 'end': 83, 'text': 'Hernandez', 'label': 'person', 'score': 0.99100261926651}, {'start': 107, 'end': 146, 'text': 'Equal Employment Opportunity Commission', 'label': 'organization', 'score': 0.9831235408782959}]
# modified:  [{'start': 0, 'end': 6, 'text': 'Hughes', 'label': 'person', 'score': 0.998845100402832}, {'start': 29, 'end': 38, 'text': 'Hernandez', 'label': 'person', 'score': 0.9976322650909424}, {'start': 44, 'end': 53, 'text': 'Hernandez', 'label': 'person', 'score': 0.9976479411125183}, {'start': 85, 'end': 131, 'text': 'Equal Employment Opportunity Commission (EEOC)', 'label': 'organization', 'score': 0.942829966545105}]
# Original: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission'}, Modified: {'Hughes', 'Hernandez', 'Equal Employment Opportunity Commission (EEOC)'}, Added: {'Equal Employment Opportunity Commission (EEOC)'}, Dropped: {'Equal Employment Opportunity Commission'}
# original:  [{'start': 74, 'end': 82, 'text': 'Assembly', 'label': 'organization', 'score': 0.9880989193916321}]
# modified:  [{'start': 14, 'end': 23, 'text': 'Democrats', 'label': 'organization', 'score': 0.7689759731292725}, {'start': 31, 'end': 39, 'text': 'Assembly', 'label': 'organization', 'score': 0.9912309646606445}, {'start': 64, 'end': 73, 'text': 'democrats', 'label': 'organization', 'score': 0.6609213352203369}, {'start': 131, 'end': 137, 'text': 'senate', 'label': 'organization', 'score': 0.978678286075592}, {'start': 155, 'end': 163, 'text': 'assembly', 'label': 'organization', 'score': 0.9950107336044312}]
# Original: {'Assembly'}, Modified: {'senate', 'democrats', 'Democrats', 'Assembly', 'assembly'}, Added: {'assembly', 'senate', 'democrats', 'Democrats'}, Dropped: set()
# original:  [{'start': 74, 'end': 82, 'text': 'Assembly', 'label': 'organization', 'score': 0.9880989193916321}]
# modified:  [{'start': 4, 'end': 12, 'text': 'Assembly', 'label': 'organization', 'score': 0.9749914407730103}]
# Original: {'Assembly'}, Modified: {'Assembly'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 59, 'text': 'Bethany Hamilton', 'label': 'person', 'score': 0.9998797178268433}]
# modified:  [{'start': 0, 'end': 16, 'text': 'Bethany Hamilton', 'label': 'person', 'score': 0.9998600482940674}, {'start': 134, 'end': 150, 'text': 'Bethany Hamilton', 'label': 'person', 'score': 0.9998132586479187}, {'start': 176, 'end': 184, 'text': 'hospital', 'label': 'organization', 'score': 0.877307653427124}, {'start': 226, 'end': 237, 'text': 'stab wounds', 'label': 'medical condition', 'score': 0.9130819439888}]
# Original: {'Bethany Hamilton'}, Modified: {'hospital', 'Bethany Hamilton', 'stab wounds'}, Added: {'hospital', 'stab wounds'}, Dropped: set()
# original:  [{'start': 43, 'end': 59, 'text': 'Bethany Hamilton', 'label': 'person', 'score': 0.9998797178268433}]
# modified:  [{'start': 0, 'end': 16, 'text': 'Bethany Hamilton', 'label': 'person', 'score': 0.9998200535774231}, {'start': 116, 'end': 124, 'text': 'hospital', 'label': 'organization', 'score': 0.9867408871650696}, {'start': 158, 'end': 175, 'text': 'serious condition', 'label': 'medical condition', 'score': 0.6816263794898987}]
# Original: {'Bethany Hamilton'}, Modified: {'hospital', 'serious condition', 'Bethany Hamilton'}, Added: {'hospital', 'serious condition'}, Dropped: set()
# original:  [{'start': 87, 'end': 95, 'text': 'AES Corp', 'label': 'organization', 'score': 0.9965834021568298}]
# modified:  [{'start': 0, 'end': 8, 'text': 'AES Corp', 'label': 'organization', 'score': 0.9882976412773132}, {'start': 145, 'end': 163, 'text': 'US-based aes corp.', 'label': 'organization', 'score': 0.8002700805664062}, {'start': 278, 'end': 293, 'text': 'u.s. government', 'label': 'organization', 'score': 0.7111815810203552}]
# Original: {'AES Corp'}, Modified: {'AES Corp', 'US-based aes corp.', 'u.s. government'}, Added: {'US-based aes corp.', 'u.s. government'}, Dropped: set()
# original:  [{'start': 87, 'end': 95, 'text': 'AES Corp', 'label': 'organization', 'score': 0.9965834021568298}]
# modified:  [{'start': 39, 'end': 48, 'text': 'AES Corp.', 'label': 'organization', 'score': 0.9952580332756042}, {'start': 87, 'end': 91, 'text': 'bank', 'label': 'organization', 'score': 0.7424950003623962}]
# Original: {'AES Corp'}, Modified: {'AES Corp.', 'bank'}, Added: {'AES Corp.', 'bank'}, Dropped: {'AES Corp'}
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()
# original:  []
# modified:  []
# Original: set(), Modified: set(), Added: set(), Dropped: set()

# %%
# from transformers import pipeline

# # Load an entailment model
# entailment_model = pipeline("text-classification", model="facebook/bart-large-mnli")

# from transformers import pipeline

# # Initialize the entailment model pipeline
# entailment_pipeline = pipeline("text-classification", model="facebook/bart-large-mnli")

# def check_entailment(original_text, candidate_text):
#     """Check if candidate_text is entailed by original_text using the entailment model."""
#     print(f"\nComparing: \n\toriginal_text: {original_text} \n\tcandidate_text: {candidate_text}\n")
#     results = entailment_pipeline(f"{original_text} [SEP] {candidate_text}")
#     for result in results:
#         if result['label'] == 'ENTAILMENT' and result['score'] > 0.4:
#             print ("YES ENTAILMENT")
#             return True
#     print("NO ENTAILMENT")
#     return False

# # Updated function to compute changes using entailment
# def compute_pii_changes_entailment(original, modified):
#     added = []
#     dropped = []

#     original_texts = {item['text']: item for item in original}
#     modified_texts = {item['text']: item for item in modified}

#     # Check for dropped items using entailment
#     for orig_text in original_texts:
#         if not any(check_entailment(orig_text, mod_text) for mod_text in modified_texts):
#             dropped.append(orig_text)

#     # Check for added items using entailment
#     for mod_text in modified_texts:
#         if not any(check_entailment(mod_text, orig_text) for orig_text in original_texts):
#             added.append(mod_text)

#     return added, dropped

# # You can replace the compute_pii_changes function in your main function with compute_pii_changes_entailment

# %%
# from transformers import pipeline
# import pandas as pd

# # Load an entailment model
# entailment_model = pipeline("text-classification", model="facebook/bart-large-mnli")

# def check_entailment(original_text, candidate_text):
#     """Check if candidate_text is entailed by original_text using the entailment model."""
#     # Properly format the input to the model
#     print(f"\nComparing: \n\toriginal_text: {original_text} \n\tcandidate_text: {candidate_text}\n")
#     input_text = f"sentence1: {original_text} sentence2: {candidate_text}"
#     results = entailment_model(input_text)
    
#     # Process the output to determine entailment
#     entailment = next((item for item in results if item['label'] == 'ENTAILMENT'), None)
#     if entailment and entailment['score'] > 0.5:
#         print ("YES ENTAILMENT")
#         return True
#     print("NO ENTAILMENT")
#     return False

# def compute_pii_changes_entailment(original, modified):
#     """Computes added or dropped PII using entailment."""
#     added = []
#     dropped = []

#     # Check each text in modified against all texts in original for drops
#     for orig_text in original:
#         if not any(check_entailment(orig_text['text'], mod_text['text']) for mod_text in modified):
#             dropped.append(orig_text)

#     # Check each text in modified against all texts in original for additions
#     for mod_text in modified:
#         if not any(check_entailment(mod_text['text'], orig_text) for orig_text in original):
#             added.append(mod_text['text'])

#     return added, dropped


from transformers import pipeline

# Initialize the entailment model pipeline
entailment_model = pipeline("text-classification", model="facebook/bart-large-mnli")

def check_entailment(original_text, candidate_text):
    """Check if candidate_text is entailed by original_text using the entailment model."""
    # Ensure the input text format is correctly interpreted by the model
    premise = f"{original_text.strip()}."
    hypothesis = f"This text refers to {candidate_text.strip()}."
    input_text = f"sentence1: {premise} sentence2: {hypothesis}"
    print(f"\nComparing: \n\toriginal_text: {premise} \n\tcandidate_text: {hypothesis}\n")
    
    results = entailment_model(input_text)
    
    # Process the output to determine entailment
    for result in results:
        print(f"Label: {result['label']}, Score: {result['score']}")
        if result['label'].lower() == 'entailment' and result['score'] > 0.5:
            print("YES ENTAILMENT")
            return True
    print("NO ENTAILMENT")
    return False

# Example usage in a function to compute added or dropped entities using the improved entailment check
def compute_pii_changes_entailment(original, modified):
    added = []
    dropped = []

    for orig_text in original:
        if not any(check_entailment(orig_text['text'], mod_text['text']) for mod_text in modified):
            dropped.append(orig_text['text'])

    for mod_text in modified:
        if not any(check_entailment(mod_text['text'], orig_text['text']) for orig_text in original):
            added.append(mod_text['text'])

    return added, dropped

# Sample main function and data processing steps should be defined here (omitted for brevity)

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gliner import GLiNER

# Load the GLiNER PII model
model = GLiNER.from_pretrained("urchade/gliner_multi_pii-v1")

# Function to detect PII
def detect_pii(text, labels):
    try:
        entities = model.predict_entities(text, labels)
        print(f"Unextracted entities: {entities}")  # Print the unextracted entities
        extracted_entities = [{'text': entity['text'], 'label': entity['label']} for entity in entities]
        print(f"Extracted entities: {extracted_entities}")  # Print the extracted entities
        return extracted_entities
    except KeyError as e:
        print(f"KeyError: {e}")
        return []

# Define the PII labels
pii_labels = ["person", "organization", "phone number", "address", "passport number", "email", 
              "credit card number", "social security number", "health insurance id number", 
              "date of birth", "mobile phone number", "bank account number", "medication", 
              "cpf", "driver's license number", "tax identification number", "medical condition", 
              "identity card number", "national id number", "ip address", "email address", "iban", 
              "credit card expiration date", "username", "health insurance number", "registration number", 
              "student id number", "insurance number", "flight number", "landline phone number", "blood type", 
              "cvv", "reservation number", "digital signature", "social media handle", "license plate number", 
              "cnpj", "postal code", "passport number", "serial number", "vehicle registration number", 
              "credit card brand", "fax number", "visa number", "insurance company", "identity document number", 
              "transaction number", "national health insurance number", "cvc", "birth certificate number", 
              "train ticket number", "passport expiration date", "social_security_number"]

# Function to load data from JSON file
def load_data(filename):
    with open(filename, 'r') as file:
        data = json.load(file)
    return data

# Function to save PII detection results
def save_pii_results(data, filename):
    with open(filename, 'w') as file:
        json.dump(data, file)

# Function to load PII detection results
def load_pii_results(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        return None

# Function to count PII entities that are added or dropped
def compute_pii_changes(original, modified):
    original_set = set([item['text'] for item in original])
    modified_set = set([item['text'] for item in modified])
    added = modified_set - original_set
    dropped = original_set - modified_set
    print("original: ", original)
    print("modified: ", modified)
    print(f"Original: {original_set}, Modified: {modified_set}, Added: {added}, Dropped: {dropped}")
    return list(added), list(dropped)

# Main function

def main(dpsgd_file, ours_file, output_file, save_file, result_path):
    print("STARTS")
    # Load data
    dpsgd_data = load_data(dpsgd_file)
    ours_data = load_data(ours_file)

    # Extract instructions and outputs
    instructions = [item['instruction'] for item in dpsgd_data]
    dpsgd_outputs = [item['output'] for item in dpsgd_data]
    ours_outputs = [item['output'] for item in ours_data]

    print("INFO EXTRACTED")
    # Load or detect PII
    pii_results = load_pii_results(save_file)
    if not pii_results:
        print("\nGenerating PII File")
        pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
        pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
        pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

        pii_results = {
            "pii_instructions": pii_instructions,
            "pii_dpsgd_outputs": pii_dpsgd_outputs,
            "pii_ours_outputs": pii_ours_outputs
        }
        save_pii_results(pii_results, save_file)
    else:
        print("\nLoading Locally")
        pii_instructions = pii_results["pii_instructions"]
        pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
        pii_ours_outputs = pii_results["pii_ours_outputs"]

    # Initialize empty DataFrames for each type of record
    dpsgd_added_records = pd.DataFrame()
    dpsgd_dropped_records = pd.DataFrame()
    ours_added_records = pd.DataFrame()
    ours_dropped_records = pd.DataFrame()


    for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
        print("Processing index: ", idx)
        added_dpsgd, dropped_dpsgd = compute_pii_changes_entailment(instr, dpsgd_out) #compute_pii_changes(instr, dpsgd_out)
        added_ours, dropped_ours = compute_pii_changes_entailment(instr, ours_out) #compute_pii_changes(instr, ours_out)
        
        # Create DataFrames for the current batch
        current_dpsgd_added = pd.DataFrame([{
            "Index": idx,
            "Original Example": instructions[idx],
            "Original PII Values": [item['text'] for item in instr],
            "DPSGD Output": dpsgd_outputs[idx],
            "DPSGD PII Values": [item['text'] for item in dpsgd_out],
            "Added PII": added
        } for added in added_dpsgd])
        
        current_dpsgd_dropped = pd.DataFrame([{
            "Index": idx,
            "Original Example": instructions[idx],
            "Original PII Values": [item['text'] for item in instr],
            "DPSGD Output": dpsgd_outputs[idx],
            "DPSGD PII Values": [item['text'] for item in dpsgd_out],
            "Dropped PII": dropped
        } for dropped in dropped_dpsgd])
        
        current_ours_added = pd.DataFrame([{
            "Index": idx,
            "Original Example": instructions[idx],
            "Original PII Values": [item['text'] for item in instr],
            "Our Output": ours_outputs[idx],
            "Our PII Values": [item['text'] for item in ours_out],
            "Added PII": added
        } for added in added_ours])
        
        current_ours_dropped = pd.DataFrame([{
            "Index": idx,
            "Original Example": instructions[idx],
            "Original PII Values": [item['text'] for item in instr],
            "Our Output": ours_outputs[idx],
            "Our PII Values": [item['text'] for item in ours_out],
            "Dropped PII": dropped
        } for dropped in dropped_ours])

        # Concatenate current batch results to main DataFrames
        dpsgd_added_records = pd.concat([dpsgd_added_records, current_dpsgd_added], ignore_index=True)
        dpsgd_dropped_records = pd.concat([dpsgd_dropped_records, current_dpsgd_dropped], ignore_index=True)
        ours_added_records = pd.concat([ours_added_records, current_ours_added], ignore_index=True)
        ours_dropped_records = pd.concat([ours_dropped_records, current_ours_dropped], ignore_index=True)

        # Save after every batch to CSV
        dpsgd_added_records.to_csv(f"{result_path}/dpsgd_pii_added_incremental.csv", index=False)
        dpsgd_dropped_records.to_csv(f"{result_path}/dpsgd_pii_dropped_incremental.csv", index=False)
        ours_added_records.to_csv(f"{result_path}/ours_pii_added_incremental.csv", index=False)
        ours_dropped_records.to_csv(f"{result_path}/ours_pii_dropped_incremental.csv", index=False)

    # Prepare data for plotting
    freq_data = pd.DataFrame({
        "Method": ["DPSGD", "DPSGD", "Ours", "Ours"],
        "PII Type": ["Added", "Dropped", "Added", "Dropped"],
        "Count": [len(dpsgd_added_records), len(dpsgd_dropped_records), len(ours_added_records), len(ours_dropped_records)]
    })

    # Plot with seaborn
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))

    # Plotting bar chart
    ax = sns.barplot(x="Method", y="Count", hue="PII Type", data=freq_data, palette=['#5DADE2', '#E74C3C'])

    # Annotate bars with actual numbers
    for p in ax.patches:
        height = int(p.get_height())
        ax.annotate(format(height, 'd'),
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')

    plt.title("PII Additions and Drops")
    plt.ylabel("Count")
    plt.xlabel("Method")
    plt.legend(title="PII Type")
    plt.tight_layout()

    # Save plot as PDF
    plt.savefig(output_file, format='pdf', dpi=400)

    plt.show()
    
if __name__ == "__main__":
    # Test setup for fixed file paths
    dpsgd_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/dp_mrpc.json'
    ours_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/alpaca_eval/data/impossible_mrpc.json'
    output_file = 'hallucinations_mrpc.pdf'
    save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'

    result_path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"

    main(dpsgd_file, ours_file, output_file, save_file, result_path)
# Out:
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# /users/k/n/kngongiv/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# STARTS
# INFO EXTRACTED
#
# Loading Locally
# Processing index:  0
#
# Comparing:
# 	original_text: PCCW
# 	candidate_text: PCCW
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: PCCW
# 	candidate_text: Mike Butcher
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: PCCW
# 	candidate_text: Alex Arena
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: PCCW
# 	candidate_text: Mr So
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Mike Butcher
# 	candidate_text: PCCW
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Mike Butcher
# 	candidate_text: Mike Butcher
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Mike Butcher
# 	candidate_text: Alex Arena
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Mike Butcher
# 	candidate_text: Mr So
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Alex Arena
# 	candidate_text: PCCW
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Alex Arena
# 	candidate_text: Mike Butcher
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Alex Arena
# 	candidate_text: Alex Arena
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Alex Arena
# 	candidate_text: Mr So
#
# NO ENTAILMENT
#
# Comparing:
# 	original_text: Mr So
# 	candidate_text: PCCW
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 205
#     201 save_file = '/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc_pii.json'
#     203 result_path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"
# --> 205 main(dpsgd_file, ours_file, output_file, save_file, result_path)
#
# Cell In[7], line 110, in main(dpsgd_file, ours_file, output_file, save_file, result_path)
#     108 for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
#     109     print("Processing index: ", idx)
# --> 110     added_dpsgd, dropped_dpsgd = compute_pii_changes_entailment(instr, dpsgd_out) #compute_pii_changes(instr, dpsgd_out)
#     111     added_ours, dropped_ours = compute_pii_changes_entailment(instr, ours_out) #compute_pii_changes(instr, ours_out)
#     113     # Create DataFrames for the current batch
#
# Cell In[6], line 29, in compute_pii_changes_entailment(original, modified)
#      27 # Check each text in modified against all texts in original for drops
#      28 for orig_text in original:
# ---> 29     if not any(check_entailment(orig_text['text'], mod_text['text']) for mod_text in modified):
#      30         dropped.append(orig_text)
#      32 # Check each text in modified against all texts in original for additions
#
# Cell In[6], line 29, in <genexpr>(.0)
#      27 # Check each text in modified against all texts in original for drops
#      28 for orig_text in original:
# ---> 29     if not any(check_entailment(orig_text['text'], mod_text['text']) for mod_text in modified):
#      30         dropped.append(orig_text)
#      32 # Check each text in modified against all texts in original for additions
#
# Cell In[6], line 12, in check_entailment(original_text, candidate_text)
#      10 print(f"\nComparing: \n\toriginal_text: {original_text} \n\tcandidate_text: {candidate_text}\n")
#      11 input_text = f"sentence1: {original_text} sentence2: {candidate_text}"
# ---> 12 results = entailment_model(input_text)
#      14 # Process the output to determine entailment
#      15 entailment = next((item for item in results if item['label'] == 'ENTAILMENT'), None)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:156, in TextClassificationPipeline.__call__(self, inputs, **kwargs)
#     122 """
#     123 Classify the text(s) given as inputs.
#     124
#    (...)
#     153     If `top_k` is used, one such dictionary is returned per label.
#     154 """
#     155 inputs = (inputs,)
# --> 156 result = super().__call__(*inputs, **kwargs)
#     157 # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158 _legacy = "top_k" not in kwargs
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/pipelines/base.py:1243, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1235     return next(
#    1236         iter(
#    1237             self.get_iterator(
#    (...)
#    1240         )
#    1241     )
#    1242 else:
# -> 1243     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/pipelines/base.py:1250, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1248 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1249     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1250     model_outputs = self.forward(model_inputs, **forward_params)
#    1251     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1252     return outputs
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/pipelines/base.py:1150, in Pipeline.forward(self, model_inputs, **forward_params)
#    1148     with inference_context():
#    1149         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1150         model_outputs = self._forward(model_inputs, **forward_params)
#    1151         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1152 else:
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:187, in TextClassificationPipeline._forward(self, model_inputs)
#     185 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186     model_inputs["use_cache"] = False
# --> 187 return self.model(**model_inputs)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1902, in BartForSequenceClassification.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1897 if input_ids is None and inputs_embeds is not None:
#    1898     raise NotImplementedError(
#    1899         f"Passing input embeddings is currently not supported for {self.__class__.__name__}"
#    1900     )
# -> 1902 outputs = self.model(
#    1903     input_ids,
#    1904     attention_mask=attention_mask,
#    1905     decoder_input_ids=decoder_input_ids,
#    1906     decoder_attention_mask=decoder_attention_mask,
#    1907     head_mask=head_mask,
#    1908     decoder_head_mask=decoder_head_mask,
#    1909     cross_attn_head_mask=cross_attn_head_mask,
#    1910     encoder_outputs=encoder_outputs,
#    1911     inputs_embeds=inputs_embeds,
#    1912     decoder_inputs_embeds=decoder_inputs_embeds,
#    1913     use_cache=use_cache,
#    1914     output_attentions=output_attentions,
#    1915     output_hidden_states=output_hidden_states,
#    1916     return_dict=return_dict,
#    1917 )
#    1918 hidden_states = outputs[0]  # last hidden state
#    1920 eos_mask = input_ids.eq(self.config.eos_token_id).to(hidden_states.device)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1610, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1607 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1609 if encoder_outputs is None:
# -> 1610     encoder_outputs = self.encoder(
#    1611         input_ids=input_ids,
#    1612         attention_mask=attention_mask,
#    1613         head_mask=head_mask,
#    1614         inputs_embeds=inputs_embeds,
#    1615         output_attentions=output_attentions,
#    1616         output_hidden_states=output_hidden_states,
#    1617         return_dict=return_dict,
#    1618     )
#    1619 # If the user passed a tuple for encoder_outputs, we wrap it in a BaseModelOutput when return_dict=True
#    1620 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1216, in BartEncoder.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1208         layer_outputs = self._gradient_checkpointing_func(
#    1209             encoder_layer.__call__,
#    1210             hidden_states,
#    (...)
#    1213             output_attentions,
#    1214         )
#    1215     else:
# -> 1216         layer_outputs = encoder_layer(
#    1217             hidden_states,
#    1218             attention_mask,
#    1219             layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1220             output_attentions=output_attentions,
#    1221         )
#    1223     hidden_states = layer_outputs[0]
#    1225 if output_attentions:
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:669, in BartEncoderLayer.forward(self, hidden_states, attention_mask, layer_head_mask, output_attentions)
#     657 """
#     658 Args:
#     659     hidden_states (`torch.FloatTensor`): input to the layer of shape `(batch, seq_len, embed_dim)`
#    (...)
#     666         returned tensors for more detail.
#     667 """
#     668 residual = hidden_states
# --> 669 hidden_states, attn_weights, _ = self.self_attn(
#     670     hidden_states=hidden_states,
#     671     attention_mask=attention_mask,
#     672     layer_head_mask=layer_head_mask,
#     673     output_attentions=output_attentions,
#     674 )
#     675 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     676 hidden_states = residual + hidden_states
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:581, in BartSdpaAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     578 else:
#     579     # self_attention
#     580     key_states = self._shape(self.k_proj(hidden_states), -1, bsz)
# --> 581     value_states = self._shape(self.v_proj(hidden_states), -1, bsz)
#     583 if self.is_decoder:
#     584     # if cross_attention save Tuple(torch.Tensor, torch.Tensor) of all cross attention key/value_states.
#     585     # Further calls to cross_attention layer can then reuse all cross-attention
#    (...)
#     589     # can concat previous decoder key/value_states to current projected key/value_states (third "elif" case)
#     590     # if encoder bi-directional self-attention `past_key_value` is always `None`
#     591     past_key_value = (key_states, value_states)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/pytorch_envs/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# original:  [{'start': 43, 'end': 47, 'text': 'PCCW', 'label': 'organization', 'score': 0.9979962110519409}, {'start': 77, 'end': 89, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9967117309570312}, {'start': 96, 'end': 106, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9980279803276062}, {'start': 163, 'end': 168, 'text': 'Mr So', 'label': 'person', 'score': 0.9798210859298706}]
# modified:  [{'start': 0, 'end': 4, 'text': 'PCCW', 'label': 'organization', 'score': 0.9982858300209045}, {'start': 32, 'end': 44, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9966384172439575}, {'start': 50, 'end': 60, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9978436231613159}, {'start': 115, 'end': 120, 'text': 'Mr So', 'label': 'person', 'score': 0.9780478477478027}]
# Original: {'Mike Butcher', 'Mr So', 'Alex Arena', 'PCCW'}, Modified: {'Mike Butcher', 'Mr So', 'Alex Arena', 'PCCW'}, Added: set(), Dropped: set()
# original:  [{'start': 43, 'end': 47, 'text': 'PCCW', 'label': 'organization', 'score': 0.9979962110519409}, {'start': 77, 'end': 89, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9967117309570312}, {'start': 96, 'end': 106, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9980279803276062}, {'start': 163, 'end': 168, 'text': 'Mr So', 'label': 'person', 'score': 0.9798210859298706}]
# modified:  [{'start': 0, 'end': 4, 'text': 'PCCW', 'label': 'organization', 'score': 0.9972479939460754}, {'start': 32, 'end': 44, 'text': 'Mike Butcher', 'label': 'person', 'score': 0.9963058233261108}, {'start': 74, 'end': 84, 'text': 'Alex Arena', 'label': 'person', 'score': 0.9919503927230835}, {'start': 100, 'end': 105, 'text': 'Mr So', 'label': 'person', 'score': 0.9904425740242004}]
# Original: {'Mike Butcher', 'Mr So', 'Alex Arena', 'PCCW'}, Modified: {'Mike Butcher', 'Mr So', 'Alex Arena', 'PCCW'}, Added: set(), Dropped: set()

# %%
# def main(dpsgd_file, ours_file, output_file, save_file):
#     # Load data
#     dpsgd_data = load_data(dpsgd_file)
#     ours_data = load_data(ours_file)

#     # Extract instructions and outputs
#     instructions = [item['instruction'] for item in dpsgd_data]
#     dpsgd_outputs = [item['output'] for item in dpsgd_data]
#     ours_outputs = [item['output'] for item in ours_data]

#     # Load or detect PII
#     pii_results = load_pii_results(save_file)
#     if not pii_results:
#         pii_instructions = [detect_pii(text, pii_labels) for text in instructions]
#         pii_dpsgd_outputs = [detect_pii(text, pii_labels) for text in dpsgd_outputs]
#         pii_ours_outputs = [detect_pii(text, pii_labels) for text in ours_outputs]

#         pii_results = {
#             "pii_instructions": pii_instructions,
#             "pii_dpsgd_outputs": pii_dpsgd_outputs,
#             "pii_ours_outputs": pii_ours_outputs
#         }
#         save_pii_results(pii_results, save_file)
#     else:
#         pii_instructions = pii_results["pii_instructions"]
#         pii_dpsgd_outputs = pii_results["pii_dpsgd_outputs"]
#         pii_ours_outputs = pii_results["pii_ours_outputs"]

#     # Initialize data frames for saving CSV files incrementally
#     path = "/users/k/n/kngongiv/Research/private_llm_generation/dialog/evaluation/hallucination_results/mrpc"
#     dpsgd_added_records = pd.DataFrame()
#     dpsgd_dropped_records = pd.DataFrame()
#     ours_added_records = pd.DataFrame()
#     ours_dropped_records = pd.DataFrame()

#     for idx, (instr, dpsgd_out, ours_out) in enumerate(zip(pii_instructions, pii_dpsgd_outputs, pii_ours_outputs)):
#         added_dpsgd, dropped_dpsgd = compute_pii_changes(instr, dpsgd_out)
#         added_ours, dropped_ours = compute_pii_changes(instr, ours_out)
        
#         # Append current results to data frames
#         current_dpsgd_added = pd.DataFrame([{
#             "Index": idx,
#             "Original Example": instructions[idx],
#             "Original PII Values": [item['text'] for item in instr],
#             "DPSGD Output": dpsgd_outputs[idx],
#             "DPSGD PII Values": [item['text'] for item in dpsgd_out],
#             "Added PII": added
#         } for added in added_dpsgd])
        
#         current_dpsgd_dropped = pd.DataFrame([{
#             "Index": idx,
#             "Original Example": instructions[idx],
#             "Original PII Values": [item['text'] for item in instr],
#             "DPSGD Output": dpsgd_outputs[idx],
#             "DPSGD PII Values": [item['text'] for item in dpsgd_out],
#             "Dropped PII": dropped
#         } for dropped in dropped_dpsgd])
        
#         current_ours_added = pd.DataFrame([{
#             "Index": idx,
#             "Original Example": instructions[idx],
#             "Original PII Values": [item['text'] for item in instr],
#             "Our Output": ours_outputs[idx],
#             "Our PII Values": [item['text'] for item in ours_out],
#             "Added PII": added
#         } for added in added_ours])
        
#         current_ours_dropped = pd.DataFrame([{
#             "Index": idx,
#             "Original Example": instructions[idx],
#             "Original PII Values": [item['text'] for item in instr],
#             "Our Output": ours_outputs[idx],
#             "Our PII Values": [item['text'] for item in ours_out],
#             "Dropped PII": dropped
#         } for dropped in dropped_ours])

#         # Append current batch of results to respective data frames
#         dpsgd_added_records = dpsgd_added_records.append(current_dpsgd_added, ignore_index=True)
#         dpsgd_dropped_records = dpsgd_dropped_records.append(current_dpsgd_dropped, ignore_index=True)
#         ours_added_records = ours_added_records.append(current_ours_added, ignore_index=True)
#         ours_dropped_records = ours_dropped_records.append(current_ours_dropped, ignore_index=True)

#         # Save after every batch to CSV
#         dpsgd_added_records.to_csv(f"{path}/dpsgd_pii_added_incremental.csv", index=False

# )
#         dpsgd_dropped_records.to_csv(f"{path}/dpsgd_pii_dropped_incremental.csv", index=False)
#         ours_added_records.to_csv(f"{path}/ours_pii_added_incremental.csv", index=False)
#         ours_dropped_records.to_csv(f"{path}/ours_pii_dropped_incremental.csv", index=False)

#     # Final save to make sure all data is saved
#     dpsgd_added_records.to_csv(f"{path}/dpsgd_pii_added_final.csv", index=False)
#     dpsgd_dropped_records.to_csv(f"{path}/dpsgd_pii_dropped_final.csv", index=False)
#     ours_added_records.to_csv(f"{path}/ours_pii_added_final.csv", index=False)
#     ours_dropped_records.to_csv(f"{path}/ours_pii_dropped_final.csv", index=False)
