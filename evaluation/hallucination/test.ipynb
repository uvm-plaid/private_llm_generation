# %%
import pandas as pd 

file_path = '/users/k/n/kngongiv/Research/impossible_kd/SummKD-submission/evaluation/results_200.tsv'
df = pd.read_csv(file_path, delimiter='\t', quotechar='"')
df
# Out:
#     Index                                      Original_Text  \
# 0       0  anxiety affects quality of life in those livin...
# 1       1  small non - coding rnas are transcribed into m...
# 2       2  ohss is a serious complication of ovulation in...
# 3       3  congenital adrenal hyperplasia ( cah ) refers ...
# 4       4  type 1 diabetes ( t1d ) results from the destr...
# ..    ...                                                ...
# 95     95  chondroblastoma accounts for < 1% of all prima...
# 96     96  suicide is a grave public health issue with a ...
# 97     97  copd is characterized by persistent airway obs...
# 98     98  amphotericin b ( amb ) , an amphoteric polyene...
# 99     99  o - glycans have been found to play an importa...
#
#                               DPSGD_Predicted_Summary  \
# 0   , anxiety is associated with cognitive in d   ...
# 1   miras regulate the cell cycle, tumor and proli...
# 2    hs is  common in women, and the ofoss can be ...
# ...

# %%
file_path = '/users/k/n/kngongiv/Research/impossible_kd/SummKD-submission/evaluation/results_200.csv'
df = pd.read_csv(file_path, encoding='utf-8')

df
# Out:
#     Index                                      Original_Text  \
# 0       0  anxiety affects quality of life in those livin...
# 1       1  small non - coding rnas are transcribed into m...
# 2       2  ohss is a serious complication of ovulation in...
# 3       3  congenital adrenal hyperplasia ( cah ) refers ...
# 4       4  type 1 diabetes ( t1d ) results from the destr...
# ..    ...                                                ...
# 95     95  chondroblastoma accounts for < 1% of all prima...
# 96     96  suicide is a grave public health issue with a ...
# 97     97  copd is characterized by persistent airway obs...
# 98     98  amphotericin b ( amb ) , an amphoteric polyene...
# 99     99  o - glycans have been found to play an importa...
#
#                                              Option 1  \
# 0   , anxiety is associated with cognitive in d   ...
# 1   miras regulate the cell cycle, tumor and proli...
# 2    hs is  common in women, and the ofoss can be ...
# ...
